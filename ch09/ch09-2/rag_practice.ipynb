# %%
# deactivate
# PS C:\Aiprojects\ch09> python -m venv ch09_env     
# PS C:\Aiprojects\ch09> cd ..
# PS C:\Aiprojects> python -m venv ch09_env
# PS C:\Aiprojects> .\ch09_env\Scripts\activate 

# 기초 유틸리티 및 Pydantic v2 고정
# %pip install numpy==1.26.4 pydantic==2.10.6 SQLAlchemy==2.0.38

# PDF 및 파일 처리
# %pip install PyMuPDF==1.25.3 pypdf==5.3.0

# LangChain 핵심 패키지 (버전 간 호환성 최적화)
# # https://visualstudio.microsoft.com/visual-cpp-build-tools/  설치 필수 (vs c++ 개발용 체크)
# %pip install langchain==0.3.19 langchain-community==0.3.19 langchain-core==0.3.41 langchain-text-splitters==0.3.7 langsmith==0.3.11
# %pip install langchain-ollama==0.2.3 langchain-chroma==0.2.0 chromadb==0.5.23
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ----- ---------------------------------- 2.4/15.8 MB 11.7 MB/s eta 0:00:02
#      ------------ --------------------------- 5.0/15.8 MB 11.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 7.1/15.8 MB 11.5 MB/s eta 0:00:01
#      ------------------------ --------------- 9.7/15.8 MB 11.6 MB/s eta 0:00:01
#      ----------------------------- --------- 12.1/15.8 MB 11.6 MB/s eta 0:00:01
#      ----------------------------------- --- 14.4/15.8 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------- 15.8/15.8 MB 11.5 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\a\LLM\ch09venv\Scripts\python.exe C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258\vendored-meson\meson\meson.py setup C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258 C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258\.mesonpy-s7mj439j -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258\.mesonpy-s7mj439j\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258
#       Build dir: C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258\.mesonpy-s7mj439j
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `gcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang-cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `pgcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#
#       A full log can be found at C:\Users\a\AppData\Local\Temp\pip-install-0huy953v\numpy_78c41c21187a4b018aad0b3070409258\.mesonpy-s7mj439j\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting PyMuPDF==1.25.3
#   Downloading pymupdf-1.25.3-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting pypdf==5.3.0
#   Downloading pypdf-5.3.0-py3-none-any.whl.metadata (7.2 kB)
# Downloading pymupdf-1.25.3-cp39-abi3-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/16.5 MB 11.8 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.5 MB 7.5 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.5 MB 8.9 MB/s eta 0:00:02
#    --------------- ------------------------ 6.3/16.5 MB 7.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/16.5 MB 6.8 MB/s eta 0:00:02
#    ------------------ --------------------- 7.6/16.5 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.5 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.4/16.5 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 11.5/16.5 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 13.6/16.5 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.5 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 6.8 MB/s  0:00:02
# Downloading pypdf-5.3.0-py3-none-any.whl (300 kB)
# Installing collected packages: pypdf, PyMuPDF
#
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    ---------------------------------------- 0/2 [pypdf]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    -------------------- ------------------- 1/2 [PyMuPDF]
#    ---------------------------------------- 2/2 [PyMuPDF]
#
# Successfully installed PyMuPDF-1.25.3 pypdf-5.3.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting langchain==0.3.19
#   Downloading langchain-0.3.19-py3-none-any.whl.metadata (7.9 kB)
# Collecting langchain-community==0.3.19
#   Downloading langchain_community-0.3.19-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain-core==0.3.41
#   Downloading langchain_core-0.3.41-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters==0.3.7
#   Downloading langchain_text_splitters-0.3.7-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith==0.3.11
#   Downloading langsmith-0.3.11-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain==0.3.19)
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain==0.3.19)
#   Using cached sqlalchemy-2.0.49-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting requests<3,>=2 (from langchain==0.3.19)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting PyYAML>=5.3 (from langchain==0.3.19)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.3.19)
#   Using cached aiohttp-3.13.5-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain==0.3.19)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting numpy<3,>=1.26.2 (from langchain==0.3.19)
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core==0.3.41)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<25,>=23.2 (from langchain-core==0.3.41)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting typing-extensions>=4.7 (from langchain-core==0.3.41)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# INFO: pip is looking at multiple versions of langchain-text-splitters to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     The user requested langchain-core==0.3.41
#     langchain 0.3.19 depends on langchain-core<1.0.0 and >=0.3.35
#     langchain-text-splitters 0.3.7 depends on langchain-core<1.0.0 and >=0.3.45
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot install langchain-core==0.3.41, langchain-text-splitters==0.3.7 and langchain==0.3.19 because these package versions have conflicting dependencies.
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Collecting langchain-ollama==0.2.3
#   Downloading langchain_ollama-0.2.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-chroma==0.2.0
#   Downloading langchain_chroma-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting chromadb==0.5.23
#   Downloading chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.33 (from langchain-ollama==0.2.3)
#   Downloading langchain_core-0.3.84-py3-none-any.whl.metadata (3.2 kB)
# Collecting ollama<1,>=0.4.4 (from langchain-ollama==0.2.3)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain-chroma==0.2.0)
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting numpy<2.0.0,>=1.26.2 (from langchain-chroma==0.2.0)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\a\LLM\ch09venv\Scripts\python.exe C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1\vendored-meson\meson\meson.py setup C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1 C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1\.mesonpy-ocmfdx2e -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1\.mesonpy-ocmfdx2e\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1
#       Build dir: C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1\.mesonpy-ocmfdx2e
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `gcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang-cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `pgcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#
#       A full log can be found at C:\Users\a\AppData\Local\Temp\pip-install-54gklj6v\numpy_b2a7e652504b41dba217d8575a66b5b1\.mesonpy-ocmfdx2e\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from langchain_community.document_loaders import PyPDFLoader

# PDF 파일을 읽어서 텍스트 데이터를 추출합니다.
loader = PyPDFLoader('C:/Users/a/LLM/ch09/data/osan_city_plan.pdf')
data_nyc = loader.load()
print(data_nyc)
# Out:
# [Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 0, 'page_label': '1'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 1, 'page_label': '2'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 2, 'page_label': '3'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 3, 'page_label': '4'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 4, 'page_label': '5'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 5, 'page_label': '6'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 6, 'page_label': '7'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 7, 'page_label': '8'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 8, 'page_label': '9'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 9, 'page_label': '10'}, page_content=''), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 10, 'page_label': '11'}, page_content='제1장\n계획의 기조'), Document(metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 11, 'page_label': '12'}, page_content=''), ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 데이터를 1000자 단위로 나눕니다. overlap은 100자로 설정합니다.
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
all_splits = text_splitter.split_documents(data_nyc)

# %%
for i, split in enumerate(all_splits):
    print(f"Split {i+1}:------------------------------------\n")
    print(split)
# Out:
# Split 1:------------------------------------
#
# page_content='제1장
# 계획의 기조' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 10, 'page_label': '11'}
# Split 2:------------------------------------
#
# page_content='Ⅰ
# 계획의 개요' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 12, 'page_label': '13'}
# Split 3:------------------------------------
#
# page_content='1
# Ⅰ. 계획의 개요
#  계획의 배경 및 목적
# 1. 계획의 배경
# 가. 국내･외 도시환경 여건변화 대응
# v 정부의 저탄소 녹색성장을 위한 정책목표에 부합되도록 하며, 온실가스 저감 등
# 기후변화에 대응하기 위하여 공간구조, 교통체계, 환경의 보전과 관리 등 체계적
# 이고 포괄적 계획 수립
# v 분당선 연장, GTX 등 광역교통망의 확충 및 오산시의 도시공간구조 재편, 사회･
# 경제적 여건 및 도시환경의 여건변화를 반영한 도시의 장기발전방향 및 미래상을
# 제시하는 계획 필요
# 나. 상위계획 정책방향 반영
# v 제5차 국토종합계획(2020~2040), 경기도종합계획, 2020년 수도권광역도시계획(수
# 정) 등 국토 및 도시 관련정책이 지속적으로 변화됨에 따라 시대적 여건변화에 탄
# 력적으로 대응하는데 한계가 있음
# v 도시정책 및 도시여건변화로 인해 도시지표의 수정이 필요함에 따라 각 부문별 지표
# 및 도시구조, 인구규모 등을 재조정하여 장기적인 발전방향과 전략을 제시하는
# 도시기본계획 수립
# 다. 도시계획 패러다임의 변화
# v 안전도시, 저탄소 녹색성장, 도시재생, 지속가능한 도시, 스마트 도시 등 도시계획
# 패러다임 변화에 대응
# 라. 기 수립된 도시기본계획 재검토
# v 기 수립된 2020년 오산도시기본계획은 이러한 오산시 대내･외의 여건변화를 충분히
# 수용하지 못하고 있음
# v 새로운 관점에서 오산시의 문제점을 개선하고 미래지향적이며, 지속가능한 도시로
# 변모하기 위해서는 장기적 관점에서 지표가 되는 도시기본계획의 재검토가 요구
# 되고 있는 시점임' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 14, 'page_label': '15'}
# Split 4:------------------------------------
#
# page_content='2
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
# 2. 계획의 목적
# 가. 도시의 정체성 및 도시기능 재정립
# v 도시정체성을 구현하고 수도권 남부의 생동감 있는 도시기능을 수행할 수 있는
# 장기적 미래비전을 제시하고, 체계적이고 실현가능한 종합발전 가이드라인 수립
# v 주변 도시로의 도시 확산과 개발압력 등을 고려하여 도시공간구조, 생활권을 재설정
# 하고, 그에 따른 적정밀도의 인구배분계획 및 도시기반시설의 적정배치
# v 수도권 남부 중심도시로 수행할 수 있는 장기적인 미래비전 제시와 체계적이고 실현
# 가능한 종합발전 가이드라인 수립으로 도시정체성 재정립
# 나. 자족기능 확보와 미래 산업에 대비한 지역맞춤형 계획 수립
# v 도시기능의 다양화 일환으로 지식기반첨단산업 육성을 통해 도시의 자족기능 확보
# v 새로운 문화・관광 콘셉트를 확립하여 기존 문화・관광시설 확충 및 신규 문화・
# 관광인프라 구축 등 다양한 문화・관광기능 활성화
# v 4차산업을 대비한 지역맞춤형 산업거점을 조성하여 주거, 일자리, 복지, 여가,
# 문화, 교육 등을 유기적으로 연계
# 다. 구도심 활성화 및 주거환경 개선을 위한 도시재생계획 수립
# v 오산시의 경제적･사회적･문화적 활력 회복을 위하여 공공의 역할과 지원을 강화
# 함으로써 지역 공동체를 회복하고 도시의 경쟁력 제고
# v 물리적 공간 개선, 낙후된 주거환경 개선 등을 통한 구도심 활성화로 새로운 일자리
# 창출 및 신성장산업 발굴
# v 주공혼재지역에 대해 산업과 주거의 계획적인 분리로 산업환경과 쾌적한 주거환경
# 개선
# 라. 시민참여형 도시기본계획 수립
# v 과거 하향식 계획수립과 제한적인 시민참여에 의한 일방적 계획통보 방식에서
# 탈피하고 시민참여형 거버넌스 구축을 통한 상향식 계획 수립
# v 주민의 참여를 촉진함으로써 커뮤니티의 자치 역량을 강화하고 구성원들의 권리
# 의식과 효능감 배양' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 15, 'page_label': '16'}
# Split 5:------------------------------------
#
# page_content='3
# 3. 계획의 성격
# 가. 종합계획
# v 오산시의 물리적, 공간적 측면과 환경적, 경제적, 사회적 측면을 포괄하여 미래
# 변화에 대응하는 종합계획으로 지속가능한 국토관리를 위한 정책과 전략으로
# 구체화
# 나. 정책계획
# v 국토종합계획, 수도권정비계획, 수도권광역교통계획 등 관련 상위계획 내용을 수용
# 하여 오산시가 지향해야 할 바람직한 도시 미래상과 장기적인 발전방향을 제시
# 다. 전략계획
# v 도시행정의 바탕이 되는 오산시의 주요지표와 토지의 개발･보전, 기반시설의 확충
# 및 효율적인 도시관리전략을 제시하여 하위계획인 도시관리계획 등 관련계획의
# 기본이 되도록 함
# 라. 실천계획
# v 도시기본계획이 추구하고 있는 도시의 발전방향에 대한 지침적 성격과 함께 목표를
# 달성하기 위한 실천적 방안을 제시
# v 종합적인 계획내용 뿐만 아니라 각 부문별 계획이 상호 유기적으로 연계되도록 수립' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 16, 'page_label': '17'}
# Split 6:------------------------------------
#
# page_content='4
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
#  계획의 범위
# 1. 시간적 범위
# v 계획 기준연도 : 2016년
# v 계획 목표연도 : 2035년
# - 계획기간을 4단계로 구분하여 단계별 계획을 5년 단위로 수립
# 구 분 1단계 2단계 3단계 4단계 비 고
# 년 도 2016~2020년 2021~2025년 2026~2030년 2031~2035년 -
# < 단계별 계획 기간 >
# 2. 내용적 범위
# 구 분 계획내용
# 도시지표 및
# 생활권 설정
#  2035년 오산시 미래인구 예측 및 여건을 고려한 목표인구 산정
#  경제, 산업, 생활, 복지, 여가, 문화 등 환경지표 설정
#  자연, 사회, 인문, 생활여건 등 지역현황을 고려한 생활권 재편
#  목표인구를 기준으로 생활권별 인구배분
# 부
# 문
# 별
# 계
# 획
# 토지이용
#  도시공간구조와 연계된 토지이용계획 수립
#  토지이용현황 분석을 통하여 개발가능지를 추출하고 용도별 토지수요를
# 전망하는 한편 토지 수요를 충족하기 위한 계획의 방향 설정과 시가지화
# 할 지역과 보전할 지역을 구분
# 기반시설
#  도시기반시설의 정비와 확충방안, 분야별 현황분석과 전망을 통한
# 개선 목표와 전략을 강구
#  광역가로망 개선 및 체계적인 가로망 구축으로 도시간 연결성 강화
# 도심 및
# 주거환경
#  도심-구도심 간 지역균형발전을 도모하고 주거환경을 개선하여 원
# 도심 활성화전략 수립
#  도시재생전략계획의 방향을 제시해 줄 수 있도록 도시재생전략 및
# 정책방향 제시
# 환경보전
# 및 관리
#  주요환경부문에 대한 검토와 분석을 통하여 쾌적하고 효율적인 도시
# 공간 조성
#  에너지이용 효율화, 신재생에너지 사용유도 등을 통해 저탄소녹색도시
# 구현
# 경관 및
# 미관
#  도시경관과 미관조성에 대한 구체적인 방안과 지침을 제시하여 오산
# 시의 경관을 선진화하고 경관형성을 통한 오산시의 정체성을 확립
# 공원 및
# 녹지
#  수변축, 녹지축 등 보전축과 연계한 광역녹지체계 구축
#  장기미집행시설 해소와 더불어 규제완화를 통해 실행가능한 계획수립
# < 내용적 범위 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 17, 'page_label': '18'}
# Split 7:------------------------------------
#
# page_content='5
# 구 분 계획내용
# 부
# 문
# 별
# 계
# 획
# 방재 및
# 안전
#  기후변화에 대비한 종합적 도시재해 예방대책 수립
#  도시정보시스템을 통해 종합적 재해･재난 관리 컨트롤타워 구축
#  범죄예방환경설계(CPTED) 기법 도입을 통해 일상생활 속 안전기반
# 확충
# 경제･사회
# ･
# 문화
#  시민참여를 독려함으로써 주민자치 보편화･일상화 유도
#  수요자 중심의 시민안전망을 구축하고 통합적 복지체계 운영
# (표 계속)
# 3. 공간적 범위
# v 오산시 행정구역 면적 : 42.71㎢' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 18, 'page_label': '19'}
# Split 8:------------------------------------
#
# page_content='6
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
#  계획수립의 기본원칙
# v 계획의 종합성 제고
# - 토지이용・교통・환경 등 물적 공간구조와 경제・사회, 행정・재정 등 비물리적
# 분야 포함
# - 부문별 기초조사결과를 토대로 장래의 전망을 예측하여 창의적인 구상 수립
# - 시행의 과정과 여건변화에 탄력적으로 대응할 수 있도록 포괄적이며 개략적으로 수립
# v 관련계획간의 연계와 조화
# - 국토종합계획・광역도시계획 등 상위계획의 내용을 수용하고, 도시관리계획・
# 지구단위계획 등 하위계획의 수립 고려
# - 도시관리계획을 수립할 때 토지용도 분류의 지침이 되도록 용도지역의 지정에
# 필요한 기준 제시
# v 환경친화적 계획 수립
# - 환경적으로 건전하고 지속가능한 도시개발이 이루어질 수 있도록 자연환경・
# 경관・생태계・녹지공간 등의 정비・개량・보호 및 확충과 도시간의 연담화
# 방지 및 환경오염에 주력하여 계획
# - 자원절약형 개발 및 관리를 위하여 한계자원인 토지・물・에너지의 소비를 최소화
# 하거나 효율적으로 이용될 수 있도록 계획
# - 녹지축・생태계・우량농지, 임상이 양호한 임야, 양호한 자연환경과 수변지역 등
# 환경적으로 보전가치가 높고 경관이 뛰어난 지역은 보전
# v 계획의 차등화・단계화
# - 인구밀도, 토지이용 특성 및 주변환경 등을 종합적으로 고려하여 지역별로 차등화
# - 기반시설의 배치계획, 토지용도 등은 지역간 서로 연계되어 계획・관리될 수
# 있도록 계획
# - 각 부문별계획은 목표연도 및 단계별 최종연도로 작성하고 인구 및 주변 환경의
# 변화에 따라 탄력적으로 도시관리계획에 반영될 수 있도록 계획' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 19, 'page_label': '20'}
# Split 9:------------------------------------
#
# page_content='7
#  계획수립의 과정
# 1. 계획수립 절차
# ■ 계획수립 근거 : 「국토의 계획 및 이용에 관한 법률」 제18조
# ⦁도시현황 조사
# ⦁상위 및 관련계획 검토
# ⦁잠재력 및 제약조건 분석
# SWOT분석·도시잠재력 도출
# 도시미래상 정립 ⦁도시정책시민참여단 운영
# - 2016.9~2017.1 (4회)
# - 미래상·추진전략 제시
# ⦁단계별 지표전망 및 설정 도시지표 설정
# ⦁공간구조 대안설정
# ⦁기본방향, 발전전략 도시공간구조 구상·생활권 재편
# 부문별계획 국토계획평가 협의회
# (기준 및 방법 설정)
# ⦁인구배분계획
# ⦁토지이용계획
# ⦁도심 및 주거환경
# ⦁기반시설계획
# ⦁환경보전 및 관리
# ⦁경관·미관계획 국토계획평가 요청서
# 작성
# ⦁공청회, 주민공람
# ⦁시의회의견청취
# ⦁시 도시계획위원회 자문
# 시민의견 수렴 및 계획(안) 조정
# 도시기본계획(안) 작성
# 도시기본계획 승인신청 국토계획평가 요청서
# 제출
# ⦁관계 행정기관 협의
#   (경기도 및 중앙부처) 국토정책위원회 심의
# 경기도 도시계획위원회 심의
# (경기도지사)
# 도시기본계획 승인
# 도시기본계획 공고·열람
# (오산시청)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 20, 'page_label': '21'}
# Split 10:------------------------------------
#
# page_content='8
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
# 2. 추진경위
# v 2016. 06. 23. : 2035년 오산 도시기본계획 수립용역 착수
# v 2016. 11. 26. : 오산 도시정책 시민참여단 1차 회의
# v 2016. 12. 10. : 오산 도시정책 시민참여단 2차 회의
# v 2017. 01. 07. : 오산 도시정책 시민참여단 3차 회의
# v 2017. 01. 21. : 오산 도시정책 시민참여단 4차 회의
# v 2018. 01. 25. : 2035년 오산도시기본계획 수립(안) 중간보고 1차
# v 2018. 02. 01. : 1차 국토계획평가협의회
# v 2018. 03. 16. : 2차 국토계획평가협의회
# v 2018. 03. 27. : 2035년 오산도시기본계획 수립(안) 중간보고 2차
# v 2018. 04. 06. : 시 도시계획위원회 사전자문
# v 2018. 04. 16. ~ 20. : 시 의회의견 청취
# v 2018. 09. 04. : 공청회 - 전문가 및 주민의견 청취
# v 2018. 10. 01. ~ 10. : 시 관련부서 협의
# v 2018. 11. 09. : 오산시 도시계획위원회 자문
# v 2019. 04. 03. : 국토계획평가요청서 제출(오산시→국토교통부)
# v 2019. 05. 27. : 2035년 오산도시기본계획(안) 승인 신청(오산시→경기도)
# v 2019. 06. 03.~ 10. 10. : 경기도 관련부서 및 관계기관 협의
# v 2019. 07. 12. : 국토계획평가 국토정책위원회 국토계획평가분과위원회 심의
# v 2019. 12. 20. : 제17회 경기도 도시계획위원회 심의
# v 2020. 02. 07. : 제1회 도시기본계획 인구･토지이용 사전검토 소위원회 심의
# v 2020. 05. 08. : 제8회 경기도 도시계획위원회 심의
# v 2020. 06. 19. : 제17회 경기도 도시계획위원회 재심의
# v 2020. 09. 01. : 2035년 오산도시기본계획 승인' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 21, 'page_label': '22'}
# Split 11:------------------------------------
#
# page_content='Ⅱ
# 지역의 특성과 현황' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 22, 'page_label': '23'}
# Split 12:------------------------------------
#
# page_content='11
# Ⅱ. 지역의 특성과 현황
#  도시연혁
# 1. 시․군의 역사
# v 오산시는 600년경 고구려의 매홀군으로 불리었다는 기록이 남아있으며 그 이전의
# 원삼국시대와 선사시대에 관한 기록은 없음
# v 청동기 시대를 거쳐 원삼국시대에는 마한이 영토, 백제 근초고왕(346~375) 때에
# 백제의 영토가 되었다가 고구려 장수왕(394~491) 때 한강연안 및 경기도 전 지역이
# 고구려 남쪽의 영토가 됨
# v 18세기 말 이래 수원군 청호면, 성호면, 오산면 등으로 불리다가 1949년 화성군
# 오산면으로 행정구역이 바뀐 후 오산읍으로 거쳐 1989년 오산시로 승격
# v 1995년 평택군 진위면의 갈곶리, 고현리, 청호리 일부 편입을 통해 현재에 이름
# 연     대 연                      혁
# 600년대  고구려 매홀군
# 757년  신라 수성군(경덕왕 16년)
# 1310년  고려 수원부(충선왕 2년)
# 1899. 2. 1  수원부 4개면(청호, 문시, 산성, 초평)
# 1914. 4. 1  수원군 성호면
# 1941.10. 1  수원군 오산면(소화 16년 10. 1.)
# 1949. 8.15  수원군 오산면(24개리) [대통령령 제161호]
# 1960. 1. 1  화성군 오산읍으로 승격 [법률 제1175호]
# 1987. 1. 1  화성군 동탄면 금곡3리 편입 (45개리) [대통령령 제12007호]
# 1989. 1. 1  오산시로 승격 (6개동) [법률 제4050호]
# 1995. 4.20  평택군 진위면 갈곶, 고현, 청호리 일부편입
#  [대통령령 제14629호]
# 자료 :  오산시 통계연보, 2019
# < 오산시 연혁 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 24, 'page_label': '25'}
# Split 13:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 12
# 2. 행정구역 변천
# 가. 연도별 행정구역 변화추이
# v 오산시는 6개 행정동, 24개의 법정동으로 형성되어 있으며, 총면적 42.71㎢ 임
# 년별과 동별 면적(㎢) 행정동 법정동 통 반 소재지 비 고
# 2011 42.77 6 24(8) 271 1,837
# 2012 42.74 6 24(8) 280 1,848
# 2013 42.73 6 24(8) 287 1,908
# 2014 42.73 6 24(8) 287 1,908
# 2015 42.73 6 24(8) 287 1,908
# 2016 42.73 6 24(8) 289 1,918
# 2017 42.73 6 24(8) 303 2,081
# 2018 42.72 6 24(8) 326 2,214
# 2019 42.71 6 24(8) 326 2,214
# 중앙동 3.66 1 3 58 374 경기대로 307
# 대원동 6.20 1 6 93 610 오산로132번길 28
# 남촌동 6.05 1 7 43 240 청학로 55-5
# 신장동 7.02 1 5 75 604 문헌공로 45
# 세마동 13.31 1 5 36 252 독산성로 419
# 초평동 6.47 1 6 33 207 발안로 1308-9
# 주 :  법정동의 ( )는 중복 동수임
# 자료 : 2020년도 지방자치단체 행정구역 및 인구 현황(2019.12.31.)
# < 연도별 행정구역 현황 >
# 오산동 부산동 원동 궐동 청학동 가장동 금암동 수청동
# 은계동 내삼미동 외삼미동 양산동 세교동 지곶동 서랑동 서동
# 벌음동 두곡동 탑동 누읍동 가수동 고현동 청호동 갈곶동
# < 법정동(24개동) >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 25, 'page_label': '26'}
# Split 14:------------------------------------
#
# page_content='13
# 나. 행정동 경계
# v 오산시의 총면적은 42.71㎢로 우리나라 국토(100,295.35㎢)의 0.04%이고 경기도
# 면적(10,175.34㎢)의 0.42%를 차지
# 행 정 구 역 명
# 행정구역면적(㎢) 구성비(%) 비    고
# 시, 구, 군 읍, 면, 동
# 오산시
# 소    계 42.71 100.0
# 중 앙 동 3.66 8.6
# 대 원 동 6.20 14.5
# 남 촌 동 6.05 14.2
# 신 장 동 7.02 16.4
# 세 마 동 13.31 31.2
# 초 평 동 6.47 15.1
# 자료 : 2020년도 지방자치단체 행정구역 및 인구 현황(2019.12.31.)
# < 행정구역 >
# < 행정구역도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 26, 'page_label': '27'}
# Split 15:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 14
# 3. 도시계획 연혁
# 가. 도시계획구역 변천과정
# v 2013년 ‘2020년 오산도시기본계획 재수립’의 경기도 승인 이후 오산시의 도시계획면적은
# 42.76㎢임
# 구  분 고   시   번   호 내              용
# 1965년 건・고 제1825호  계획구역 결정(면적 : 22.975㎢)
# 1968년 건・ 고 제488호  도시계획 일부변경
# 1970년 건・고 제7호  도시계획구역 변경
# 1971년 건・ 고 제669호  도시계획구역 변경(면적 : 51.585㎢)
# 1972년 건・ 고 제231호  도시계획변경 결정
# 1973년 건・ 고 제214호  토지구획정리사업에 관한 계획결정
# 1975년 건・고 제2호  도시계획구역 변경결정(면적 : 10.62㎢)
# 1976년 건・ 고 제194호  도시계획구역 재정비(면적 : 10.654㎢)
# 1986년 건・ 고 제133호  도시계획재정비
# 1993년 건 ・고 제59호  도시계획재정비(용도지역 결정)
# 1994년 건교부 승인  2011년 도시기본계획 승인(28.675㎢)
# 1995년 대통령령 제14629호  행정구역개편(평택군 진위면 갈곶, 고현, 청호리
# 오산시 편입)
# 1995년 건 ・고 제96-116호  도시계획재정비 결정(28.675㎢)
# 1995년 오산시고 95-36호  오산도시계획지적고시(28.675㎢)
# 2000년 건교부 승인  2016년 도시기본계획 승인(42.757㎢)
# 2002년 건 ・고 제2002-203호  도시계획구역 변경
# 2003년 건 ・고 제2003-129호  오산도시관리계획(재정비) 결정(도 권한사항)
# 2003년 오・ 고 제2003-43호  오산도시관리계획(재정비) 결정(시 권한사항)
# 2007년 오 ・공 제2007-753호  2020년 도시기본계획 승인
# 2009년 오 ・공 제2009-286호  2020년 도시기본계획(변경) 승인
# 2009년 오・ 고 제2009-41호  2015년 도시관리계획(재정비) 결정(시 권한사항)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 27, 'page_label': '28'}
# Split 16:------------------------------------
#
# page_content='2009년 오 ・공 제2009-286호  2020년 도시기본계획(변경) 승인
# 2009년 오・ 고 제2009-41호  2015년 도시관리계획(재정비) 결정(시 권한사항)
# 2009년 경 ・고 제2009-456호  2015년 도시관리계획(재정비) 결정(도 권한사항)
# 2013년 오 ・공 제2013-548호  2020년 도시기본계획 재수립 승인
# (면적 : 42.757㎢)
# 2016년 오・ 고 제2016-23호  2020년 관리계획(재정비)결정(시 권한사항)
# 2017년 경・ 고 제2017-19호  2020년 관리계획(재정비)결정(도 권한사항)
# 2017년 오・ 고 제2017-1303호  2020년 기본계획 일부변경 승인
# < 도시계획연혁 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 27, 'page_label': '28'}
# Split 17:------------------------------------
#
# page_content='15
#  도시의 세력권
# 1. 지리적 위치
# v 수도권 서남부에 위치한 오산시는 동쪽으로는 화성시 동탄동, 서쪽으로는 화성시
# 정남면, 남쪽으로는 평택시 진위면, 북쪽으로는 화성시 병점동에 접하고 있음
# v 지형은 북동과 서남으로 폭이 짧고, 서북과 남동으로 폭이 길며 도청소재지인 수원과
# 16.9Km 떨어져있으며 철도, 고속도로, 국도가 통과하는 산업, 교통의 요충지임
# 시청소재지 단 경도와 위도의 극점 연 장 거 리
# 지 명 극 점
# 경기도 오산시
# 성호대로 141
# 동단 오산시 원동 북위 37° 08' 24"
# 동경 127° 06' 21"
# 동서간 9.8㎞
# 남북간 8.2㎞
# 서단 오산시 서랑동 북위 37° 10' 24"
# 동경 126° 59' 07"
# 남단 오산시 갈곶동 북위 37° 07' 27"
# 동경 127° 04' 00"
# 북단 오산시 양산동 북위 37° 11' 55"
# 동경 127° 01' 12"
# 자료 : 오산시 통계연보, 2019
# < 경・위도상 위치 >
# < 지리적 위치도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 28, 'page_label': '29'}
# Split 18:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 16
# 2. 도시 세력권
# 가. 행정권
# v 일반 행정권이 미치는 범위는 오산시 행정구역 전 지역(42.71㎢)으로서,  6개 행정동
# (24개 법정동)으로 구성되어 있음
# v 도시계획의 수립 및 집행으로 관리하는 행정권역 역시 행정구역(42.71㎢)과 동일함
# 나. 경제권
# v 출퇴근 고용인구, 공급원료, 소비상품, 시장이용권 등 유통 및 상업시설, 금융시설
# 이용권이 해당
# v 오산을 중심으로 반경 10㎞ 권내에 입지하고 있는 수원, 화성, 평택, 용인시 등이 속함
# 다. 사회․문화권
# v 학교, 병원, 도서관, 박물관 등 문화시설, 체육시설 등 생활서비스 시설을 이용하는
# 지역적 범위인 사회적 영향권역
# v 경제권과 비슷한 영역을 나타내고 있으며, 상품소비권은 화성, 수원에 의존도가
# 강함
# v 오산시를 포함하여 화성시 병점동, 동탄동, 정남면, 평택시 진위면, 용인시 남사면
# 일원을 사회문화권으로 설정
# 라. 환경권
# v 자연환경 보전을 위한 녹지축, 수계축을 중심으로 오산시 주변의 화성시, 평택시,
# 용인시를 환경권으로 설정
# - 녹지축 : 노적봉~양산봉~여계산~반월봉~필봉으로 이어지는 녹지축과 여계산에서
# 수목원과 중앙공원으로 연계되는 녹지축 설정
# - 수계축 : 맑은 물 공급과 생태환경 보전을 위하여 황구지천의 물줄기가 흐르는
# 화성시, 오산천의 상류인 수원시를 범위로 포함' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 29, 'page_label': '30'}
# Split 19:------------------------------------
#
# page_content='17
#  도시의 현황과 특성
# 1. 자연환경
# 가. 지형 및 경사도
# v 오산시는 대체로 서고동저지형으로 도시형태는 비교적 낮은 산세에 의한 소분지와
# 소평야 지대를 형성하고 있음
# v 오산천을 중심으로 동측으로는 평탄지, 서측으로 평탄지와 얕은 구릉지를 형성
# 하고 있으며, 북측으로는 반월봉(118m), 양산봉(180m), 세마대(208m)를 중심
# 으로 구릉지를 형성하고 있음
# v 표고는 50m이하가 계획구역 면적 42.71㎢ 중 72.1％(30.81㎢)를 점유
# (단위 : ㎢, %)
# 구    분 계 50m 이하 50~70m 70~100m 100m 이상
# 면    적 42.71 30.81 6.76 3.69 1.45
# 구 성 비 100.0 72.1 15.8 8.7 3.4
# 주 : 1/25,000상에서 구적, GIS분석
# < 표고분석 >
#                < 표고분석도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 30, 'page_label': '31'}
# Split 20:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 18
# v 경사는 전체적으로 완만하며 경사도 10％이하의 지역이 63.8%를 차지하고 있어
# 계획구역의 개발잠재력은 풍부하다고 판단
# (단위 : ㎢, %)
# 구    분 계 10% 이하 10~20% 20~30% 30% 이상
# 면    적 42.71 27.26 8.53 3.98 2.94
# 구 성 비 100.0 63.8 20.0 9.3 6.9
# 주 : 1/25,000상에서 구적, GIS분석
# < 경사분석 >
#              < 경사분석도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 31, 'page_label': '32'}
# Split 21:------------------------------------
#
# page_content='19
# 나. 수계
# v 오산시는 지정하천 총 20개소(L=30.125km)가 위치하고 있으며, 그 중 국가하천
# 2개소 L=8.26km, 지방하천 3개소 L=5.40km, 소하천 15개소16.465km로 구성되
# 어 있음
# v 오산천은 북동방향에서 오산시로 유입하여 기존 시가지 중심을 남북으로 관통하여
# 원동천, 역말천, 금암천, 궐동천, 죽미령천, 대호천, 작은말천, 가서천, 부산천,
# 서동천, 가장천을 유입하여 남서방향으로 유하하면서 평택시의 진위천과 합류함
# v 황구지천은 오산시 서북측과 화성시를 경계부로 관류하면서 삼미천, 문시천, 외삼미천,
# 양산1천, 양산2천, 서랑천 및 지곶천 등을 유입하여 상위 하천인 진위천과 합류
#   < 수계분석도 >
# 자료 : 오산시 자연재해저감종합계획, 2019. 12' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 32, 'page_label': '33'}
# Split 22:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 20
# 하천
# 등급 하천명
# 구  간 하천
# 연장
# (㎞)
# 유로
# 연장
# (㎞)
# 유역
# 면적
# (㎢)
# 비고기 점 종 점
# 총계(20개소) 53.195
# <30.125> 113.23 463.13
# 국가
# 하천
# 오산천 경기도 용인시 기흥구,
# 화성시 동탄면 경계
# 경기도 평택시 서탄면
# 진위천(국가) 합류점
# 15.03
# <4.36> 30.44 150.52
# 황구
# 지천
# 경기도 화성시 황계동
# 신대황교 지점
# 경기도 평택시
# 서탄면
# 진위천
# (국가) 합류점
# 16.30
# <3.90> 35.12 259.70
# 소  계 31.33
# <8.26> 65.56 610.22
# 지방
# 하천
# 삼미천 경기도 오산시
# 양산동
# 경기도 화성시 병점동
# 황구지천(국가) 합류점 1.04 5.01 9.38
# 가장천 경기도 오산시
# 서동
# 경기도 오산시 누읍동
# 오산천(국가) 합류점 2.73 5.38 6.75
# 궐리천 경기도 오산시
# 수청동
# 경기도 오산시 귈동
# 오산천(국가) 합류점 1.63 4.79 6.37
# 소  계 5.40 15.18 22.50
# 자료 : < >는 오산시 관내 하천연장 및 기·종점 측점
# 주 : 오산시 소하천종합계획, 2017. 7
# < 국가·지방하천 현황 및 개요 >
# v 소하천은 15개소로 총연장은 16.465㎞로서 지방하천으로 합류하나 양산 1, 2천,
# 서랑천 등은 국가하천인 황구지천으로 유입하며, 대호천, 부산천, 원동천, 역말천
# 등은 오산천으로 유입함
# 하천
# 등급 하천명
# 구  간 하천
# 연장
# (㎞)
# 유로
# 연장
# (㎞)
# 유역
# 면적
# (㎢)
# 비고
# 기 점 종 점
# 소
# 하
# 천
# 금암천 오산시 금암동 236-14오산시 수청동 282-140.657 2.66 3.03
# 대호천 오산시 궐동 575-10 오산시 궐동 578 0.376 2.57 1.87
# 부산천 오산시 부산동 764 오산시 부산동 160-2 1.465 2.32 0.99
# 원동천 오산시 원동 729-2 오산시 원동 729-11 1.173 2.26 2.05
# 역말천 오산시 원동 706-4 오산시 원동 121-6 1.112 2.07 1.21' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 33, 'page_label': '34'}
# Split 23:------------------------------------
#
# page_content='원동천 오산시 원동 729-2 오산시 원동 729-11 1.173 2.26 2.05
# 역말천 오산시 원동 706-4 오산시 원동 121-6 1.112 2.07 1.21
# 서동천 오산시 서동 549 오산시 서동 637-4 1.061 1.83 0.94
# 문시천 오산시 외삼미동 609 오산시 양산동 5 2.872 3.64 6.42
# 외삼미천 오산시 외삼미동 545-21 오산시 외삼미동 492-6 0.811 1.68 1.32
# 양산1천 오산시 양산동 산19-3 오산시 양산동 490-119 1.000 1.17 0.58
# 양산2천 오산시 양산동 662 오산시 양산동 662-3 0.700 1.28 0.46
# 서랑천 오산시 서랑동 산23-2 오산시 서랑동 289-20 1.487 5.02 4.97
# 지곶1천 오산시 지곶동 534-10 오산시 지곶동 534-1 1.649 2.73 3.4
# 지곶2천 오산시 지곶동 534-26 오산시 지곶동 387-6 0.714 1.02 1.32
# 지곶3천 오산시 지곶동 534-21 오산시 지곶동 534-17 0.549 0.97 0.49
# 내삼미천 오산시 내삼미동 704-3 오산시 내삼미동 708-8 0.839 1.27 1.36
# 소  계 16.465 32.49 30.41
# 자료 : 오산시 소하천종합계획, 2017. 7
# < 소하천 현황 및 개요 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 33, 'page_label': '34'}
# Split 24:------------------------------------
#
# page_content='21
# 다. 기후
# v 경기도 중남부의 내륙 중심지에 위치하여 대륙성 기후의 영향을 받아 비교적 온화한
# 기후 분포를 형성하고 있으며, 한서의 차가 적은 지역으로 농업에 적합한 기후조건임
# v 과거 10년간(09~18년) 평균기온은 12.6℃이며 '18년 월별 최고기온은 8월의 33.
# 5℃이며 최저기온은 1월의 –7.8℃이며, 과거 10년간(09~18년) 평균일조시간은
# 2,346.8시간으로 나타남
# v 과거 10년간(09~18년) 연평균강수량은 1,340.1㎜이고 '18년 기준 강수량은 1,293.1㎜
# 로 전년대비 낮은 강수량을 보이고 있음
# v 주풍향은 북서풍으로 평균 풍속은 1.8m/sec 임
#   구분
# 년도
# 기    온 (℃) 강수량
# (㎜)
# 상대
# 습도
# 평균
# (%)
# 일조
# 시간
# (hr)
# 최심
# 적설
# (㎝)
# 천 기 일 수 (일) 평균
# 풍속
# (m/
# sec)
# 평균 최고 최저 맑음 흐림 비 눈
# 2009 12.6 17.9 8.0 1,541.2 71 2,282.8 7.2 107 86 87 18 1.7
# 2010 12.2 17.1 7.9 1,470.6 73 2,027.9 19.5 93 123 130 29 1.8
# 2011 11.8 16.8 7.4 1,975.9 70 2,146.5 9.2 110 108 108 23 1.7
# 2012 12.1 17.2 7.7 1,748.3 69 2,291.6 10.5 96 84 110 29 1.8
# 2013 12.3 17.5 7.8 1,240.1 72 2,310.2 7.8 107 88 115 26 1.7
# 2014 13.1 18.6 8.5 1,029.1 68 2,372.7 5.5 103 90 97 27 2.1
# 2015 13.5 19.0 8.8 751.1 68 2,450.3 8.2 101 86 107 28 1.8
# 2016 13.6 19.1 9.0 1,023.4 68 2,367.2 3.7 77 86 101 35 1.8
# 2017 12.6 18.3 7.8 1,328.6 67 2,606.1 7.1 122 77 109 28 1.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 34, 'page_label': '35'}
# Split 25:------------------------------------
#
# page_content='2017 12.6 18.3 7.8 1,328.6 67 2,606.1 7.1 122 77 109 28 1.8
# 2018 12.7 18.5 7.9 1,293.1 67 2,605.5 7.9 112 81 145 21 1.8
# 평균 12.6 18.0 8.08 1,340.1 69.3 2,346.8 8.6 102.8 90.9 110.9 26.4 1.8
# 자료 : 오산시 통계연보, 2019
# < 기상개황 및 천기일수 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 34, 'page_label': '35'}
# Split 26:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 22
# 구 분
# 기    온 (℃)
# 강수량
# (㎜)
# 상대
# 습도
# 평균
# (%)
# 일조
# 시간
# (hr)
# 최심
# 적설
# (㎝)
# 천 기 일 수 (일) 평균
# 풍속
# (m/
# sec)평균 최고 최저 맑음 흐림 비 눈
# 1월 -3.6 1.3 -7.8 7.9 57 194.1 6.4 11 5 8 7 1.8
# 2월 -1.6 4.3 -6.8 29.1 54 201.3 7.9 11 3 7 6 2.0
# 3월 7.9 14.2 2.9 86.0 69 212.2 1.6 8 6 12 1 2.1
# 4월 12.6 19.3 6.8 128.8 65 219.2 - 11 10 13 - 2.0
# 5월 17.9 23.7 12.6 196.4 73 219.3 - 8 10 19 - 2.0
# 6월 22.6 28.7 17.9 107.0 72 229.2 - 4 12 13 - 1.9
# 7월 27.5 32.5 23.5 222.7 75 255.2 - 8 7 17 - 1.8
# 8월 28.4 33.5 24.6 218.6 72 234.8 - 5 8 18 - 2.1
# 9월 21.1 26.2 16.8 61.7 71 212.3 - 9 8 13 - 1.9
# 10월 12.6 19.1 7.2 132.7 73 240.8 - 12 3 12 - 1.4
# 11월 7.7 14.2 2.6 78.1 71 186.7 2.4 13 6 6 1 1.3
# 12월 -0.3 5.2 -5.1 24.1 56 200.4 4.9 12 3 7 6 1.7
# 자료 : 오산시 통계연보, 2019
# < 월평균 기상개황 및 천기일수 현황(′18) >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 35, 'page_label': '36'}
# Split 27:------------------------------------
#
# page_content='23
# 라. 생태/식생
# 1) 국토환경성평가지도
# 자료 : 국토환경성평가지도(https://ecvam.neins.go.kr), 2019년 기준
# < 국토환경성평가지도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 36, 'page_label': '37'}
# Split 28:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 24
# 2) 생태자연도
# 자료 : 환경공간정보서비스(https://egis.me.go.kr ), 2019년 기준
# < 생태자연도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 37, 'page_label': '38'}
# Split 29:------------------------------------
#
# page_content='25
# 2. 인구현황
# 가. 인구변화추이
# 1) 성별인구 및 가구
# v 2018년 12월말 기준으로 오산시의 총인구는 233,730명으로 경기도 인구(2018년
# 기준 약 13,490,000명)의 약 1.7%를 차지하고 있음
# v 2018년 12월말 기준으로 오산시 가구수는 89,860가구(세대)로 2009년 62,410가구
# (세대)의 약 1.4배로 증가하였으며, 가구당 구성원은 2.60인/가구(세대)로 나타남
# v 인구밀도는 54.7인/㏊며, 행정동별로 살펴보면 대원동이 110.6인/㏊로 가장 높으며,
# 중앙동 100.2인/㏊, 신장동 89.7인/㏊, 남촌동 44.3인/㏊, 초평동이 25.3인/㏊이
# 며, 세마동이 19.1인/㏊으로 가장 낮음
# v 오산시의 인구변화추이는 과거 10년간('09∼'18) 연평균 4.8%씩 증가추세를 보이고 있음
# 구 분
# 인 구 (인)
# 가구(호)합계 내국인 외국인남 여
# 2009 163,448 81,570 78,164 3,714 62,410
# 2010 186,382 93,054 89,462 3,866 70,714
# 2011 198,514 98,983 94,909 4,622 74,807
# 2012 205,900 102,396 97,895 5,609 77,951
# 2013 211,559 105,145 100,315 6,099 79,951
# 2014 216,230 106,843 101,722 7,665 81,146
# 2015 216,524 105,966 100,862 9,696 81,033
# 2016 219,294 107,056 101,600 10,638 82,581
# 2017 225,309 109,620 103,817 11,872 85,445
# 2018 233,730 113,237 106,833 13,660 89,860
# 중앙동 35,771 16,778 16,484 2,509 12,751
# 대원동 67,161 32,882 31,220 3,059 25,245
# 남촌동 26,250 11,937 8,723 5,590 12,891' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 38, 'page_label': '39'}
# Split 30:------------------------------------
#
# page_content='대원동 67,161 32,882 31,220 3,059 25,245
# 남촌동 26,250 11,937 8,723 5,590 12,891
# 신장동 61,888 30,295 30,101 1,492 23,191
# 세마동 26,184 13,178 12,410 596 9,553
# 초평동 16,476 8,167 7,895 414 6,229
# 연평균증가율 4.8% 4.9%
# 인구밀도 54.7인/ha
# 가구당 인구 2.60인/가구
# 자료 : 오산시 통계연보, 2019 / 행정안전부 외국인 통계자료
# < 연도별 인구 및 가구 추이 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 38, 'page_label': '39'}
# Split 31:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 26
# 2) 연령별 및 성별 인구구조
# v 2018년도 오산시 인구는 남자가 여자에 비해 약 6.4천명 가까이 많아 남녀의 성비는
# 106.0%를 보임
# v 0~59세까지의 인구에서는 남자가 여자에 비해 많았으나 60세 이상의 인구에서는 여자가
# 남자에 비해 더 많은 인구가 거주하고 있음
# v 35~39세의 인구가 10.8%로 가장 많은 비율을 차지하고 있음
# v 0~14세 인구 38,679인(17.6%)와 65세 이상 인구 18,589인(8.4%)의 비생산 연령층은
# 전체인구의 26%를 차지하고 있으며 경제활동가능인구는 전체인구의 74%임
# 5   세
# 계급별
# 인 구 구 성 비
# 남 여 남 여
# 총계 220,070 113,237 106,833 100.0 100.0 100.0
# 0세~4세 11,896 6,116 5,780 5.4 5.4 5.4
# 5세~9세 14,246 7,315 6,931 6.5 6.5 6.5
# 10세~14세 12,537 6,453 6,084 5.7 5.7 5.7
# 15세~19세 12,471 6,435 6,036 5.7 5.7 5.6
# 20세~24세 13,668 7,116 6,552 6.2 6.3 6.1
# 25세~29세 15,225 8,322 6,903 6.9 7.3 6.5
# 30세~34세 16,730 8,780 7,950 7.6 7.8 7.4
# 35세~39세 23,768 12,495 11,273 10.8 11.0 10.6
# 40세~44세 20,867 11,126 9,741 9.5 9.8 9.1
# 45세~49세 19,854 10,470 9,384 9.0 9.2 8.8
# 50세~54세 16,148 8,361 7,787 7.3 7.4 7.3
# 55세~59세 14,094 7,275 6,819 6.4 6.4 6.4
# 60세~64세 9,977 4,940 5,037 4.5 4.4 4.7
# 65세~69세 6,144 2,949 3,195 2.8 2.8 3.0
# 70세~74세 4,799 2,199 2,600 2.2 1.9 2.4' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 39, 'page_label': '40'}
# Split 32:------------------------------------
#
# page_content='65세~69세 6,144 2,949 3,195 2.8 2.8 3.0
# 70세~74세 4,799 2,199 2,600 2.2 1.9 2.4
# 75세~79세 3,884 1,613 2,271 1.8 1.4 2.1
# 80세이상 3,762 1,272 2,490 1.7 1.1 2.3
# 자료 : 오산시 통계연보, 2019
# 주 : 외국인 제외
# < 연령별(5세 계급) 및 성별 인구 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 39, 'page_label': '40'}
# Split 33:------------------------------------
#
# page_content='27
# 3) 인구이동 및 전출․전입
# v 2018년 말 기준 오산시의 전입인구는 38,577인, 전출인구는 33,151인으로 나타남
# v 최근 10년간 인구의 전입·전출률을 비교해 보면 2009년 전입·전출률이 각각
# 23.8%, 19.1%였으나 2018년 전입·전출률은 23.8%, 20.5%로 전입률은 유사하나
# 전출률은 높아졌으며 2018년까지는 전입인구가 전출인구보다 많은 것으로 나타났지만
# 2015년에는 전출인구가 많은 것으로 나타남
# (단위 : 인)
# 구 분 총 이동 시군내
# 이 동
# 시군간 이동(도내) 시도간 이동 순이동전 입 전 출 전 입 전 출 전 입 전 출
# 2009 38,553 30,998 9,745 17,755 13,395 11,053 7,858 7,555
# 2010 52,285 32,405 11,924 28,499 12,461 11,862 8,020 19,880
# 2011 41,302 32,561 11,160 19,393 12,824 10,749 8,577 8,741
# 2012 33,373 29,539 8,625 14,546 12,505 10,202 8,409 3,834
# 2013 33,296 30,280 10,013 14,496 12,339 8,787 7,928 3,016
# 2014 30,527 29,673 9,346 12,627 12,451 8,554 7,876 854
# 2015 28,913 32,629 8,165 12,216 16,920 8,532 7,544 -3,716
# 2016 27,623 27,507 7,391 11,697 12,769 8,535 7,347 116
# 2017 32,136 28,682 9,535 13,809 12,209 8,792 6,938 3,454
# 2018 38,577 33,151 11,695 17,353 14,492 9,529 6,964 5,426
# 자료 : 오산시 통계연보, 2019
# 주 : 주민등록전출,입 신고에 의한 자료이며 시도내 이동은 전입인구 기준, 국외이동은 제외
# < 인구이동 >
# 4) 인구밀도' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 40, 'page_label': '41'}
# Split 34:------------------------------------
#
# page_content='자료 : 오산시 통계연보, 2019
# 주 : 주민등록전출,입 신고에 의한 자료이며 시도내 이동은 전입인구 기준, 국외이동은 제외
# < 인구이동 >
# 4) 인구밀도
# v 지난 10년간 오산시의 면적은 거의 변화가 없는 반면 인구는 1.4배의 증가를 보여
# 오산시의 인구밀도도 2009년 3,824인/㎢에서 2018년 5,471인/㎢로 큰 폭의
# 상승을 보임
# 구 분 면적(㎢) 인구(인) 인구밀도(인/㎢)
# 2009 42.77 163,498         3,824
# 2010 42.77 186,382         4,358
# 2011 42.77 198,714         4,646
# 2012 42.74 205,900         4,818
# 2013 42.73 211,559         4,951
# 2014 42.73 216,230         5,060
# 2015 42.73 216,524         5,067
# 2016 42.73 219,294         5,132
# 2017 42.73 225,309         5,273
# 2018 42.72 233,730         5,471
# 자료 : 오산시 통계연보, 2019
# < 인구밀도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 40, 'page_label': '41'}
# Split 35:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 28
# 3. 토지이용 현황
# 가. 지목별 현황
# v 지목별로는 임야가 전체의 24.4%인 10,409천㎡를 차지하고 있어 가장 큰 비율을 보이고
# 있으며 그 뒤로 대지가 19.2%인 8,215천㎡, 답이 13.0%인 5,539천㎡, 도로가
# 12.4%인 5,291천㎡, 전이 8.4%인 3,604㎡의 면적을 차지하는 것으로 나타남
# v 2010년 이후 토지이용변화를 살펴보면 전, 답, 임야 등의 면적은 감소하였으나
# 대지, 공장용지, 도로, 공원 등의 면적은 증가하는 추세를 보임
# (단위 : 천㎡)
# 구 분 합 계 전 답 과수원 목장용지 임 야 대 지
# 2010 42,770 5,327 8,412 243 112 13,326 5,692
# 2011 42,770 4,803 7,382 235 108 12,696 5,902
# 2012 42,737 4,151 6,778 235 104 11,676 6,873
# 2013 42,732 3,895 6,371 218 101 11,416 7,298
# 2014 42,734 3,844 6,137 224 101 11,139 7,311
# 2015 42,731 3,816 6,083 220 101 11,034 7,383
# 2016 42,727 3,813 6,000 215 110 10,978 7,469
# 2017 42,726 3,760 5,849 203 99 10,900 7,668
# 2018 42,722 3,724 5,713 202 99 10,662 7,908
# 2019 42,707 3,604 5,539 192 97 10,409 8,215
# 오산동 2,182 72 150 7 2 12 813
# 부산동 2,379 265 364 6 - 655 476
# 원 동 3,834 255 398 - - 915 1,135
# 궐 동 2,130 195 312 5- 493 574
# 청학동 1,105 54 151 - - 279 92
# 가장동 2,044 111 93 -1 449 154
# 금암동 2,086 63 73 - - 378 521' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 41, 'page_label': '42'}
# Split 36:------------------------------------
#
# page_content='청학동 1,105 54 151 - - 279 92
# 가장동 2,044 111 93 -1 449 154
# 금암동 2,086 63 73 - - 378 521
# 수청동 1,603 67 31 - - 135 508
# 은계동 545 19 7- - 122 179
# 내삼미동 2,488 234 232 11 - 656 514
# 외삼미동 2,424 154 386 1 2 432 596
# 양산동 3,694 351 535 - 3 1,776 337
# 세교동 2,306 192 322 - 3 247 591
# 지곶동 3,458 349 419 9 15 1,615 298
# 서랑동 1,856 188 169 - 26 800 71
# 서 동 2,050 306 473 1 25 668 204
# 벌음동 931 303 198 22 2 172 81
# 두곡동 706 94 239 -3 215 68
# 탑 동 631 65 209 - 14 109 63
# 누읍동 1,277 75 197 1 1 42 169
# 가수동 967 76 251 - - 159 149
# 고현동 433 39 42 20 - 19 143
# 청호동 442 16 141 4 - 4 178
# 갈곶동 1,136 61 147 105 - 57 301
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 41, 'page_label': '42'}
# Split 37:------------------------------------
#
# page_content='29
# (단위 : 천㎡)
# 구 분 공장용지 학교용지 주차장 주유소용지 창고용지 도로 철도용지
# 2010 1,920 683 58 57 201 2,966 315
# 2011 1,880 707 71 60 276 4,324 547
# 2012 1,878 824 117 60 277 4,783 547
# 2013 1,842 862 148 66 328 4,984 542
# 2014 2,226 862 161 64 337 5,101 547
# 2015 2,285 862 167 67 338 5,122 546
# 2016 2,293 862 169 66 338 5,133 546
# 2017 2,293 876 167 73 339 5,160 545
# 2018 2,305 890 183 74 351 5,224 545
# 2019 2,409 894 188 76 355 5,291 545
# 오산동 127 61 11 6 62 333 99
# 부산동 27 41 4 4 93 290 -
# 원 동 138 118 14 8 44 593 -
# 궐 동 71 24 10 -8 274 36
# 청학동 122 235 - 1 - 77 6
# 가장동 733 - 8 1 14 224 -
# 금암동 - 70 6 - - 345 -
# 수청동 7 63 35 8 - 297 65
# 은계동 - - - - 3 59 -
# 내삼미동 57 14 10 11 8 448 77
# 외삼미동 119 11 78 22 363 156
# 양산동 18 126 12 1 4 286 -
# 세교동 155 43 36 4 2 321 88
# 지곶동 208 20 4 2 3 326 -
# 서랑동 18 - - - 1 250 -
# 서 동 46 - 9 2 3 91 -
# 벌음동 26 - 3 5 4 58 -
# 두곡동 8 - 16 2 1 43 -
# 탑 동 - - - - 1 84 -
# 누읍동 254 12 1 1 19 153 -
# 가수동 118 28 - 4 - 68 -
# 고현동 43 15 1 1 - 92 -
# 청호동 4 - - 1 1 67 -
# 갈곶동 110 13 1 6 62 149 18
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 42, 'page_label': '43'}
# Split 38:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 30
# (단위 : 천㎡)
# 구 분 하천 제방 구거 유지 양어장 수도용지 공원
# 2010 879 166 743 240 - 11 259
# 2011 877 163 733 237 - 11 308
# 2012 875 161 692 237 - 24 1,099
# 2013 867 161 681 258 - 24 1,240
# 2014 160 867 667 270 - 24 1,298
# 2015 864 160 660 270 - 24 1,298
# 2016 862 164 653 270 - 24 1.303
# 2017 864 163 648 292 - 24 1.324
# 2018 863 163 646 289 - 24 1.369
# 2019 872 163 644 289 - 24 1,417
# 오산동 149 25 30 - - - 21
# 부산동 9 2 44 3 - - 48
# 원 동 - 2 82 21 - - 48
# 궐 동 22 3 25 - - 8 24
# 청학동 37 9 - - - - -
# 가장동 - - 11 16 - 3 152
# 금암동 1 - 9 - - - 423
# 수청동 41 - 4 14 - - 178
# 은계동 93 15 23 - - 1 1
# 내삼미동 2 2 16 8 - - 130
# 외삼미동 1 3 12 1 - - 57
# 양산동 108 22 64 1 - - 33
# 세교동 2 - 38 6 - 12 189
# 지곶동 1 1 71 17 - - 64
# 서랑동 84 23 59 130 - - -
# 서 동 18 6 49 50 - - -
# 벌음동 11 1 20 - - - -
# 두곡동 3 - 9 - - - -
# 탑 동 29 - 14 18 - - -
# 누읍동 177 28 19 4 - - 14
# 가수동 53 20 7 - - - 2
# 고현동 - - 3 - - - 11
# 청호동 1 - 13 - - - 9
# 갈곶동 30 1 22 - - - 13
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 43, 'page_label': '44'}
# Split 39:------------------------------------
#
# page_content='31
# (단위 : 천㎡)
# 구 분 체육용지 유원지 종교용지 사적지 묘 지 잡종지 미복구
# 2010 135 - 100 - 145 780 -
# 2011 132 305 100 - 142 771 -
# 2012 132 305 108 - 124 766 -
# 2013 135 305 113 - 120 766 -
# 2014 126 305 117 - 118 728 -
# 2015 126 305 118 - 118 764 -
# 2016 126 305 120 - 118 795 -
# 2017 126 305 125 - 118 796 -
# 2018 126 305 129 - 118 801 -
# 2019 129 305 133 - 117 800 -
# 오산동 70 - 8 - - 124 -
# 부산동 17 - 1 - 1 29 -
# 원 동 1 - 13 - - 49 -
# 궐 동 - - 16 - 2 28 -
# 청학동 - - 12 - - 30 -
# 가장동 - - 2 - 20 52 -
# 금암동 - 171 3 - 23 - -
# 수청동 3 134 5 - - 8 -
# 은계동 7 - 5 - - 11 -
# 내삼미동 - - 5 - 7 46 -
# 외삼미동 23 - 14 - 7 49 -
# 양산동 - - 3 - - 14 -
# 세교동 8 - 7 - 9 31 -
# 지곶동 - - 5 - 19 12 -
# 서랑동 - - - - - 37 -
# 서 동 - - 3 - 2 94 -
# 벌음동 - - 5 - 6 14 -
# 두곡동 - - - - - 5 -
# 탑 동 - - 1 - 21 3 -
# 누읍동 - - 2 - - 108 -
# 가수동 - - - - - 32 -
# 고현동 - - - - - 4 -
# 청호동 - - - - - 3 -
# 갈곶동 - - 23 - - 17 -
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 44, 'page_label': '45'}
# Split 40:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 32
# < 지목별 토지이용 현황 >
#                    자료 : 오산시 자연재해저감종합계획, 2019. 12' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 45, 'page_label': '46'}
# Split 41:------------------------------------
#
# page_content='33
# 나. 용도지역·지구 현황
# v 오산시는 전제면적 42.75㎢ 1) 중 28.23㎢(66.0%)가 녹지지역으로 지정되어 있어
# 가장 큰 비중을 차지하고 있으며, 주거지역이 11.07㎢(25.9%), 공업지역이 2.37㎢
# (5.5%), 상업지역이 1.08㎢(2.5%)를 차지하고 있음
# v 오산시의 주거지역은 넓어지고 있으나 녹지지역은 점차 감소하고 공업지역과 상업
# 지역은 거의 변화가 없음
# v 용도지구 현황을 살펴보면 오산시는 현재 고도지구가 0.56㎢, 자연취락지구가 0.69
# ㎢, 특정용도제한지구가 0.12㎢ 지정되어 있음
# (단위 : ㎢)
# 구 분
# 계 획
# 구 역
# 면 적
# 용  도  지  역
# 합 계
# 주  거  지  역
# 소 계
# 전용주거지역 일반주거지역
# 준주거
# 1종전용 2종전용 1종주거 2종주거 3종주거
# 2018 42.75 42.75 11.07 0.15 - 3.08 3.58 3.25 1.01
# 자료 : 오산시 통계연보, 2019
# < 용도지역별 면적 >
# (단위 : ㎢)
# 구 분
# 용  도  지  역
# 상 업 지 역 공 업 지 역 녹 지 지 역
# 미
# 지정소계 중심
# 상업
# 일반
# 상업
# 근린
# 상업
# 유통
# 산업
# 소계 전용
# 공업
# 일반
# 공업
# 준
# 공업 소계 보전
# 녹지
# 자연
# 녹지
# 생산
# 녹지
# 2018 1.08 - 1.03 0.05 - 2.37 - 2.30 0.07 28.23 4.28 20.76 3.19 -
# 자료 : 오산시 통계연보, 2019
# < 용도지역별 면적 – 계속 >
# (단위 : ㎢)
# 구 분 합 계 고도지구 특정용도
# 제한지구
# 취 락 지 구
# 소 계 자 연 집 단
# 2018 1.37 0.56 0.12 0.69 0.69 -
# 자료 : 오산시 통계연보, 2019
# < 용도지구별 면적 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 46, 'page_label': '47'}
# Split 42:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 34
#
# < 용도지역 현황도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 47, 'page_label': '48'}
# Split 43:------------------------------------
#
# page_content='35
# 4. 도시생활 현황
# 가. 주택
# 1) 유형별 주택현황
# v 2018년 말 기준 오산시의 주택수는 총 94,402호이며, 이 중 단독주택 24,778호,
# 아파트 61,907호, 연립주택 2,140호, 다세대주택 5,577호로 나타남
# v 주택 수는 전체적으로 증가하는 추세임.
# (단위 : 호수)
# 구 분 합 계 단 독 주 택 아파트 연립주택 다세대주택 비거주용 건물내
# 주택다가구주택
# 2014 76,753 20,288 17,151 51,182 1,941 3,342 -
# 2015 78,848 21,366 18,152 51,405 2,013 4,064 -
# 2016 80,798 22,660 19,306 51,447 2,038 4,653 -
# 2017 87,149 23,860 20,435 55,993 2,086 5,210 -
# 2018 94,402 24,778 21,268 61,907 2,140 5,577 -
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 국토교통부 추계자료로 작성
#      2) 국토해양부 새로운 산정방식 적용, 다가구 단독주택 산정방식이 변경(동→호)
#      3) 2013년 서식변경(비거주용 건물내주택 항목 삭제)
#      4) 단독주택은 영업겸용단독 및 비거주용건물내 주택을 포함
# < 유형별 주택 현황 >
# 2) 규모별 주택현황
# (단위 : 호수)
# 구 분 합 계 단독주택 아파트 연립주택 다세대주택 비거주용
# 건물내
# 2018년 74,893 5,095 60,089 1,562 7,602 545
# 20㎡이하 2,517 21 590 - 1,892 14
# 20~40㎡ 8,632 133 5,346 59 3,072 22
# 40~60㎡ 25,076 390 21,511 1,089 2,027 59
# 60~85㎡ 27,396 844 25,499 387 580 86
# 85~100㎡ 1,700 441 1,170 - 25 64
# 100~130㎡ 5,729 528 5,054 27 - 120
# 130~165㎡ 1,337 590 659 -6 82' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 48, 'page_label': '49'}
# Split 44:------------------------------------
#
# page_content='85~100㎡ 1,700 441 1,170 - 25 64
# 100~130㎡ 5,729 528 5,054 27 - 120
# 130~165㎡ 1,337 590 659 -6 82
# 165~230㎡ 779 463 260 - - 56
# 230㎡초과 1,727 1,685 - - - 42
# 자료 : 오산시 통계연보, 2019
# 주 : 2007년 계량단위  표준화 방침에 의거 평 → ㎡로 환산표기(㎡ * 0.3025=평)
# < 규모별 주택 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 48, 'page_label': '49'}
# Split 45:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 36
# 3) 무주택가구
# v 2018년 통계청 주택소유통계 기준으로 오산시의 총가구수는 83,469가구이며, 주택
# 소유가구수는 42,126가구, 무주택가구수는 41,343가구로 조사됨
# (단위 : 가구)
# 구 분 총가구(일반가구) 주택소유 가구 무주택 가구
# 전국 19,979,188 11,233,906 8,745,282
# 경기도 4,751,497 2,642,084 2,109,413
# 오산시 83,469 42,126 41,343
# 자료 : 통계청 주택소유통계, 2018
# 주 :  1) 2018년 기준
#      2) 일반가구 - 가족으로 이루어진 가구, 가족과 5인이하의 남남이 함께 사는 가구, 1인가구, 가족이 아닌
# 남남끼리 사는 5인 이하의 가구
# < 주택소유 및 무주택 가구수현황 >
# 4) 주택보급률
# v 2018년말 기준 오산시의 주택보급률은 102.6%로 나타남
# v 최근 5년간 주택보급률을 살펴보면, 2014년 92.4%를 보인 이후 점차 증가 추세를
# 보임
# (단위 : 세대, 호수, %)
# 구 분 가구수 주택수 보급률
# 2014 83,096 76,753 92.4
# 2015 82,980 78,848 95.0
# 2016 84,565 80,798 95.6
# 2017 87,498 87,149 99.6
# 2018 97,497 94,402 102.6
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 일반가구를 대상으로 집계(비혈연가구, 1인가구 포함)
#      단, 집단가구(6인이상 비혈연가구, 기숙사, 사회시설 등) 및 외국인 가구는 제외
#      참고사항 : 국토해양부 새로운 산정방식 적용, 다가구 단독주택 산정방식이 변경(동 →호), 2005년부터~
# 게재
#      자료 : 통계청「인구주택총조사보고서」, 국토해양부 추계자료(기타년도)
# < 주택 보급률 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 49, 'page_label': '50'}
# Split 46:------------------------------------
#
# page_content='37
# 나. 공원·녹지
# 1) 공원
# 가) 공원현황
# v 2016년 12월 기준으로 오산시는 113개소의 공원이 도시계획시설로 결정되었으며
# 이 중 소공원은 13개소, 어린이공원 55개소, 근린공원 25개소, 주제공원 20개소 등
# 총면적 3.19㎢임
# v 2020도시기본계획상 공원 총면적이 4.06㎢로 계획되었으나, 2016년 기준 오산 도
# 시관리계획 결정(변경)을 반영하여 공원면적이 3.19㎢로 감소됨
# v 오산시행정구역 42.71㎢ 중 공원이 도시계획시설로 결정되어 있는 면적은 7.5%를
# 차지함
# v 2016년 오산시 인구(216,524명)를 기준으로 1인당 공원면적 기준은 14.75㎡이나
# 향후 도시기본계획 완공시점인 2020년 기준 302,000인 일 때 1인당 공원면적은
# 감소할 것으로 예상됨
# (단위 : 개소, ㎢)
# 구 분
# 2020도시기본계획(변경) 2016년 공원지정현황
# 개소 면적 개소 면적
# 총 계 111 4.06 113 3.19
# 소공원 9 0.02 13 0.03
# 어린이공원 50 0.14 55 0.15
# 근린공원 38 2.16 25 1.42
# 주제공원 13 1.09 20 1.59
# 중앙공원 1 0.65 - -
# 인구 302,000인 216,524인
# 1인당
# 공원면적(㎡) 13.44㎡ 14.75㎡
# 자료 : 2020년 오산 공원녹지 기본계획(변경), 도시공원 통계(2018.12)
# 주 : 2016년 인구(외국인은 행정안전부 2016년 기준 인구)
# < 공원지정현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 50, 'page_label': '51'}
# Split 47:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 38
# 나) 공원조성현황
# v 2016년 기준으로 오산시는 113개소의 공원이 도시계획시설로 결정되었으며 이중
# 소공원은 13개소, 어린이공원 55개소, 근린공원 25개소, 주제공원 20개소 등 총면적
# 3,193,151㎡임
# v 1인당 공원면적은 도시공원 전체면적 기준 14.75㎡/인으로 「도시공원 및 녹지 등에
# 관한 법률」상 도시지역 안의 도시공원 확보기준 면적 6㎡/인을 상회함
# v 2020오산도시관리계획(재정비) 결정사항을 반영하여 2020도시기본계획상 총면적
# 4,056,979㎡에서 3,193,151㎡로 감소함
# v 또한, 결정된 도시공원 면적의 64.9%(2,071,147㎡)가 조성되어, 조성된 도시공원
# 기준 1인당 공원면적은 9.57㎡/인으로 나타남
# - 도시기본계획 수립 시 고려하지 않는 소공원과 어린이공원 제외 시 결정 공원 기준
# 1인당 공원면적은 13.89㎡/인이며, 조성된 공원 기준 8.71㎡/인임
# (단위 : ㎡, %)
# 규  모
# 결정 공원 조성 공원
# 비  고
# 시설수 면  적 구성비 시설수 면  적 조성률
# 계 113 3,193,151 100.0 106 2,071,147 64.9
# 근린공원 25 1,421,953 44.5 21 1,171,844 82.4
# 어린이공원 55 152,885 4.8 55 152,885 100.0
# 소공원 13 33,084 1.0 13 33,084 100.0
# 역사공원 5 1,095,976 34.3 4 325,506 29.7
# 문화공원 3 251,080 7.9 2 161,865 64.5
# 수변공원 9 166,490 5.2 9 166,490 100.0
# 체육공원 3 71,683 2.3 2 59,473 83.0
# 1인당
# 공원면적
# (216,524인)
# 14.75㎡/인 9.57㎡/인 도 시 공 원  전 체
# 13.89㎡/인 8.71㎡/인 소 공 원･어 린 이
# 공 원  제 외
# 자료 : 2020 오산도시관리계획 보고서(2016)
# < 공원지정 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 51, 'page_label': '52'}
# Split 48:------------------------------------
#
# page_content='39
# 2) 녹지
# 가) 녹지현황
# v 오산시의 녹지현황은 완충녹지 190개소 850,347㎡, 경관녹지 23개소, 48,822㎡,
# 연결녹지 2개소, 18,620㎡로 도시계획시설이 결정되어 있음
# (단위 : ㎡, %)
# 녹지구분
# 결정 녹지 조성 녹지
# 비  고
# 시설수 면  적 구성비 시설수 면  적 조성률
# 계 215 917,789 100.0 206 655,711 71.4
# 완충녹지 190 850,347 92.7 181 588,269 69.2
# 경관녹지 23 48,822 5.3 23 48,822 100.0
# 연결녹지 2 18,620 2.0 2 18,620 100.0
# 자료 : 2020 오산 도시관리계획 보고서(2016)
# < 녹지지정 현황 >
# 다. 상·하수도
# 1) 상수도
# v 2018년 말 오산시 상수도현황을 보면 급수지역내 인구에 대한 보급률은 100.0%로
# 나타남
# v 1일 급수량은 70,421㎥/일이며 1인1일 급수량은 307.0ℓ의 수준으로 나타남
# v 시설용량은 2018년 기준 ‘오산시 수도정비기본계획(변경), 2018.01‘ 상 133,000㎥/일임
# 구 분 급수 도시 내
# 총인구 급수인구 보급률
# (%)
# 시설용량
# (㎥/일)
# 급수량
# (㎥/일)
# 1일1인당
# 급수량(ℓ)
# 2014 215,819 215,008 99.6 86,000 64,008 298
# 2015 214,909 214,909 100.0 133,000 64,747 301
# 2016 216,699 216,699 100.0 133,000 65,072 300
# 2017 221,865 221,865 100.0 133,000 66,240 299
# 2018 229,520 229,520 100.0 133,000 70,421 307
# 자료 : 오산시 수도정비기본계획(변경), (오산시 고시 제 2018-7호)
# < 상수도 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 52, 'page_label': '53'}
# Split 49:------------------------------------
#
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 40
# 2) 하수도
# v 2018년 기준 총인구 229,520인이며, 하수처리인구는 225,248인으로 하수도 보급률은
# 98.1%임
# v 하수처리시설로는 현재 오산 제1 하수처리장(76,000㎥/일), 오산 제2 하수처리장
# (64,000㎥/일), 세마하수처리장(8,300㎥/일)이 있음
# 구 분 총인구 하수처리인구 하수처리구역
# 외 인구 보급률(%) 비고
# 2014 215,819 212,930 2,889 98.7
# 2015 214,909 212,471 2,438 98.9
# 2016 216,699 214,287 2,412 98.9
# 2017 221,865 219,388 2,477 98.9
# 2018 229,520 225,248 4,272 98.1
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 2015년 전체서식 변경   2) 총인구(주민등록+외국인)
# < 하수도 현황 >
# 라. 의료․보건․사회복지
# v 오산시에는 2018년 기준 종합병원 3곳, 병원 6곳, 의원 101곳, 특수병원 1곳, 요
# 양병원 5곳, 치과병(의)원 69곳, 한의원 33곳, 보건소 1곳의 의료시설이 있음
# v 오산시에는 한국병원이 가장 큰 규모의 병원으로 나타남
# (단위 : 개소)
# 구 분 합계 종합병원 병원 의원 특수병원요양병원 치과병
# (의)원 한의원 보건소
# 병원수 219 3 6 101 1 5 69 33 1
# 병상수 2,807 682 512 223 464 867 - 18 -
# 자료 : 오산시 통계연보, 2019
# 주1 : 병원 중 군인병원 제외
# 주2 : 특수병원에 정신병원, 결핵병원, 나병원 포함
# 주3 : 요양병원 중 노인전문병원은 제외
# < 의료시설 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 53, 'page_label': '54'}
# Split 50:------------------------------------
#
# page_content='41
# v 오산시 사회복지시설은 총 439개소로 보육시설이 262개소로 가장 많으며, 노인
# 복지시설 133개소, 아동청소년 복지시설이 18개소, 장애인 복지시설이 15개소,
# 가정 복지시설이 3개소, 기타 복지시설 8개소가 있음
# (단위 : 개소, 인)
# 구 분 계 노인 장애인 아동
# 청소년 보육 가정 기타
# 시설수 439 133 15 18 262 3 8
# ...
# Split 500:------------------------------------
#
# page_content='444
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
#  재정 및 투자부문
# 1. 재정현황
# 가. 재정운영 여건
# v 세입여건은 신규주택 건설 및 인구증가에 따른 지방세 증가가 예상되며, 국세 증
# 가에 따른 이전재원 증가가 전망됨
# v 세출여건은 시민중심 행복도시 구현을 위한 역량 집중, 복지정책 확대에 따른 지
# 방비 부담 등 큰 폭의 재정수요가 증가될 전망임
# 나. 재정규모
# v 오산시 세입은 9,282억 원, 세출은 5,673억 원이며, 잉여액은 3,609억원임
# v 연평균 증가율은 세입 18.6%, 세출 12.2%로 나타남
# (단위 : 억 원)
# 구분
# 예산현액 세 입(A) 세 출(B) 잉 여(A-B)
# 계 일반 특별 계 일반 특별 계 일반 특별 계 일반 특별
# 2013년 4,396 3,433 963 4,815 3,853 962 3,521 2,969 552 1,294 884 410
# 2014년 4,776 3,876 900 4,908 4,023 885 3,428 3,002 426 1,480 1,021 459
# 2015년 5,597 4,547 1,050 5,785 4,673 1,112 3,965 3,461 504 1,820 1,212 608
# 2016년 6,408 5,221 1,187 6,613 5,324 1,290 4,401 3,873 528 2,212 1,451 761
# 2017년 7,752 6,297 1,455 7,983 6,453 1,530 4,563 3,991 572 3,420 2,461 958
# 2018년 9,020 7,152 1,868 9,282 7,275 2,007 5,674 4,895 779 3,608 2,380 1,228
# 자료 : 오산시 통계연보, 2019
# < 재정규모 추이 >
# 다. 일반회계 세입구조
# v 일반회계 세입은 총 7,275억 원으로 보조금 1,538억 원, 지방세 1,317억 원이며, 연평균
# 증가율 17.8%로 증가한 것으로 조사됨
# (단위 : 백만원)
# 구분 합 계 지방세 세외수입 지방교부세 조정교부금
# (재정보전금) 보조금 지방채 보전수입 등
# 내부거래' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 457, 'page_label': '458'}
# Split 501:------------------------------------
#
# page_content='증가율 17.8%로 증가한 것으로 조사됨
# (단위 : 백만원)
# 구분 합 계 지방세 세외수입 지방교부세 조정교부금
# (재정보전금) 보조금 지방채 보전수입 등
# 내부거래
# 2013년 385,357  88,349 123,939 53,382 25,631 94,056 - -
# 2014년 402,356 95,960 21,076 58,041 31,122 106,186 - 89,971
# 2015년 467,266 103,642 33,806 67,741 40,926 116,270 - 104,880
# 2016년 532,392 118,261 26,273 83,842 47,831 132,801 - 123,384
# 2017년 645,262 130,034 31,342 104,020 65,574 166,175 - 148,117
# 2018년 727,508 131,721 32,083 90,246 70,446 153,801 - 249,211
# 자료 : 오산시 통계연보, 2019
# < 일반회계 세입구조 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 457, 'page_label': '458'}
# Split 502:------------------------------------
#
# page_content='445
# 라. 일반회계 세출구조
# v 일반회계 세출은 총 4,895억 원으로 그 중 사회복지와 수송 및 교통이 각각 1,846억 원,
# 736억 원으로 가장 크게 나타남
# (단위 : 백만원)
# 구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 합계 296,936 300,167 346,094 387,294 399,120 489,459
# 일반공공행정 31,229 31,006 37,915 39,953 32,275 38,709
# 공공질서
# 및안전 8,679 7,135 5,724 9,904 7,453 10,997
# 교육 11,788 13,977 13,205 15,698 18,748 26,215
# 문화및관광 19,719 16,623 12,604 17,176 24,415 23,393
# 환경보호 30,135 22,777 28,331 26,750 22,226 43,311
# 사회복지 107,741 117,940 147,710 153,803 151,161 184,577
# 보건 7,778 8,956 10,675 10,635 11,958 12,689
# 농림해양수산 3,827 4,206 3,532 3,666 5,071 5,813
# 산업,중소기업 2,522 1,504 2,063 2,819 4,056 2,862
# 수송및교통 33,261 31,150 36,947 48,749 62,867 73,586
# 국토및
# 지역개발 3,590 5,328 5,582 11,941 11,743 15,112
# 과학기술 - - - - - -
# 예비비 - - - - - -
# 기타 36,667 39,565 41,805 46,201 47,148 52,195
# 자료 : 오산시 통계연보, 2019
# < 일반회계 세출구조 >
# 마. 특별회계 현황
# v 특별회계 규모는 총 1,868억 원으로 공기업특별회계 1,219억 원, 기타특별회계 649억
# 원으로 나타남
# (단위 : 백만원)
# 구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 예 산 96,332  89,988 105,016 118,706 145,531 186,806' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 458, 'page_label': '459'}
# Split 503:------------------------------------
#
# page_content='구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 예 산 96,332  89,988 105,016 118,706 145,531 186,806
# 세 입 96,188 88,468 111,240 128,952 153,042 200,670
# 세 출 55,224 42,597 50,406 52,819 57,224 77,855
# 자료 : 오산시 통계연보, 2019
# < 특별회계 결산 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 458, 'page_label': '459'}
# Split 504:------------------------------------
#
# page_content='446
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# 2. 재정계획
# 가. 기본방향
# ■ 국가재정운영계획과의 연계성 확보
# v 국가재정운용계획에서 제시하는 중･장기 중점재원 투자방향, 주요 사업계획을
# 반영하여 국가와 시의 재정적 연계성 확보
# v 국가정책방향 하에서 오산시의 실정과 특성에 부합하는 비전과 정책을 실현할 수
# 있도록 재정운용계획을 수립
# ■ 시정방향과 충실히 연계
# v 교육, 복지, 일자리 등 주민숙원사업, 핵심사업, 계속사업 등을 충실히 반영한 계획 수립
# ■ 자주재원 확충 및 합리적인 재원배분 등의 자구노력 강화
# v 한정된 재원을 효율적으로 활용하기 위하여 합리적으로 재원을 배분하고,
# 채무전액 상환, 복지예산 등 재정수요 증가에 따라 이전재원, 자주재원 확충
# 등의 자구노력 강화
# v 재정투자사업에 대한 사전심사강화로 효율성이 낮은 사업 사전차단
# ■ 지방예산･회계의 투명성 및 효율성 확보
# v 경상적 경비 절약 및 증가 억제를 통한 절감 재원을 투자 사업에 배분
# v 행사･축제예산 및 민간 이전경비에 대한 성과평가를 통하여 사업지원 여부 검토
# 나. 재정여건 전망
# 1) 세입규모추정
# v 오산시의 세입규모는 「오산시 통계연보(2016)」의 추계와 「오산시 중기지방재
# 정계획(2018-2022)」상 세입전망(연평균 1.73%)를 적용하여 목표연도인 2035
# 년 세입규모는 897,411백만원에 이를 것으로 전망됨
# v 각종 개발계획 등에 따른 시너지효과로 인구유입 증가 등 지방세수 확대가 예상
# v 총 재정수입 중 자체재원은 317,780백만원(35.4%), 의존재원은 444,366백만원
# (49.5%)이 될 것으로 예상됨' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 459, 'page_label': '460'}
# Split 505:------------------------------------
#
# page_content='447
# (단위: 백만원, %)
# 구 분 2018년 2019년 2020년 2021년 2022년 2023년 2024년 2025년 2026년
# 계 671,655684,037667,457691,581718,114730,532743,166756,017769,091
# 자
# 체
# 재
# 원
# 소계 212,307 219,007 227,360 240,553 254,290 258,687 263,161 267,711 272,341
# 지방세 132,921 137,658 142,581 147,687 152,991 155,637 158,329 161,066 163,852
# 세외수입 79,386 81,349 84,779 92,866 101,299 103,050 104,832 106,645 108,489
# 의
# 존
# 재
# 원
# 소계 328,256 351,877 339,180 347,293 355,584 361,733 367,989 374,353 380,826
# 지방교부세 110,348 118,656 124,937 127,306 129,722 131,965 134,247 136,569 138,930
# 조정교부금 60,287 61,493 62,723 63,977 65,257 66,385 67,534 68,701 69,889
# 국고보조금 100,473 108,880 109,760 111,836 114,886 116,873 118,894 120,950 123,042
# 지특보조금 8,387 9,073 1,303 2,738 3,263 3,320 3,377 3,436 3,495
# 기금보조금 7,988 10,834 789 794 800 814 828 842 857
# 도비보조금 40,773 42,941 39,668 40,642 41,656 42,376 43,109 43,855 44,613
# 보전수입 등 131,092 113,153 100,917 103,735 108,240 110,112 112,016 113,953 115,924
# 자료 : 2018~2022 오산시 중기지방재정계획
# < 세입추정 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 506:------------------------------------
#
# page_content='자료 : 2018~2022 오산시 중기지방재정계획
# < 세입추정 >
# 구 분 2027년 2028년 2029년 2030년 2031년 2032년 2033년 2034년 2035년 구성비
# 계 782,391795,920809,684823,686837,930852,420867,160882,156897,411 100.0
# 자
# 체
# 재
# 원
# 소계 277,051 281,842 286,716 291,674 296,717 301,849 307,068 312,378 317,780 35.4
# 지방세 166,685 169,568 172,500 175,483 178,517 181,605 184,745 187,940 191,190 21.3
# 세외수입 110,366 112,274 114,216 116,191 118,200 120,244 122,323 124,438 126,590 14.1
# 의
# 존
# 재
# 원
# 소계
# 387,412 394,111 400,926 407,859 414,913 422,087 429,387 436,812 444,366 49.5
# 지방교부세 141,333 143,777 146,263 148,793 151,366 153,983 156,646 159,355 162,111 18.0
# 조정교부금 71,098 72,327 73,578 74,850 76,145 77,462 78,801 80,164 81,550 9.1
# 국고보조금 125,170 127,334 129,536 131,776 134,055 136,373 138,731 141,130 143,571 16.0
# 지특보조금 3,555 3,617 3,679 3,743 3,808 3,873 3,941 4,009 4,078 0.5
# 기금보조금 871 887 902 917 933 949 966 982 999 0.1
# 도비보조금 45,385 46,169 46,968 47,780 48,606 49,447 50,302 51,172 52,057 5.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 507:------------------------------------
#
# page_content='도비보조금 45,385 46,169 46,968 47,780 48,606 49,447 50,302 51,172 52,057 5.8
# 보전수입 등 117,928 119,967 122,042 124,153 126,230 128,484 130,705 132,966 135,265 15.1
# 자료 : 2018~2022 오산시 중기지방재정계획
# (표 계속)
# 2) 세출규모추정
# v 목표연도의 일반회계 세출규모는 기존 분야별 투자 수요의 개략적 비율을 적용
# 하되, 각종 개발사업 등을 고려하여 추정
# v 오산시의 세출규모는 「오산시 중기지방재정계획(2018-2022)」상 세출전망(연평균
# 1.73%)를 적용하여 2035년 세출규모는 897,411백만원에 이를 것으로 전망됨' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 508:------------------------------------
#
# page_content='448
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# v 일반공공행정, 공공질서 및 안전, 교육에 대한 투자수요는 지속적으로 감소될
# 것으로 전망됨
# (단위: 백만원, %)
# 구 분 2018년 2019년 2020년 2021년 2022년 2023년 2024년 2025년 2026년
# 계 671,655684,036667,456691,582718,115730,534743,168756,017769,091
# 일반공공행정 62,369 69,722 61,475 51,077 45,116 45,896 46,690 47,497 48,319
# 공공질서 및 안전 20,302 28,470 19,890 15,947 16,397 16,680 16,969 17,262 17,561
# 교육 26,905 22,725 25,835 29,783 22,907 23,303 23,706 24,116 24,533
# 문화 및 관광 26,821 34,613 22,329 28,449 34,339 34,933 35,537 36,151 36,776
# 환경보호 102,219 96,338 101,430 109,618 117,567 119,600 121,669 123,773 125,913
# 사회복지 190,842 193,502 201,778 206,309 203,586 207,107 210,688 214,332 218,038
# 보건 14,845 15,011 15,209 15,444 15,685 15,957 16,233 16,513 16,799
# 농림해양수산 5,106 5,150 5,257 5,429 5,525 5,621 5,718 5,817 5,917
# 산업·중소기업 2,278 2,068 2,229 2,485 2,505 2,548 2,592 2,637 2,682
# 수송 및 교통 98,160 88,372 73,539 78,510 87,540 89,054 90,594 92,160 93,754
# 국토 및 지역개발 24,455 28,056 11,782 12,466 13,390 13,621 13,857 14,096 14,340' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 509:------------------------------------
#
# page_content='국토 및 지역개발 24,455 28,056 11,782 12,466 13,390 13,621 13,857 14,096 14,340
# 예비비 40,664 40,831 64,053 69,210 83,209 84,648 86,112 87,601 89,116
# 기타 56,689 59,178 62,650 66,855 70,349 71,566 72,803 74,062 75,343
# 자료 : 2018~2022 오산시 중기지방재정계획
# < 세출추정 >
# 구 분 2027년 2028년 2029년 2030년 2031년 2032년 2033년 2034년 2035년 구성비
# 계 782,389795,918809,684823,685837,930852,421867,162882,155897,413100.0
# 일반공공행정 49,154 50,004 50,869 51,749 52,644 53,554 54,480 55,422 56,381 6.3
# 공공질서 및 안전17,864 18,173 18,488 18,807 19,133 19,463 19,800 20,142 20,491 2.3
# 교육 24,957 25,388 25,827 26,274 26,728 27,191 27,661 28,139 28,626 3.2
# 문화 및 관광 37,412 38,059 38,717 39,387 40,068 40,761 41,466 42,183 42,912 4.8
# 환경보호 128,090 130,305 132,559 134,851 137,183 139,555 141,969 144,424 146,921 16.3
# 사회복지 221,808 225,644 229,546 233,516 237,554 241,662 245,841 250,092 254,417 28.3
# 보건 17,089 17,385 17,685 17,991 18,302 18,619 18,941 19,268 19,602 2.2
# 농림해양수산 6,020 6,124 6,230 6,337 6,447 6,559 6,672 6,787 6,905 0.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 510:------------------------------------
#
# page_content='농림해양수산 6,020 6,124 6,230 6,337 6,447 6,559 6,672 6,787 6,905 0.8
# 산업·중소기업 2,729 2,776 2,824 2,873 2,922 2,973 3,024 3,077 3,130 0.3
# 수송 및 교통 95,375 97,024 98,702 100,409 102,145 103,912 105,709 107,537 109,396 12.2
# 국토및지역개발 14,588 14,840 15,097 15,358 15,624 15,894 16,169 16,448 16,733 1.9
# 예비비 90,657 92,225 93,820 95,442 97,093 98,772 100,480 102,217 103,985 11.6
# 기타 76,646 77,971 79,320 80,691 82,087 83,506 84,950 86,419 87,914 9.8
# 자료 : 2018~2022 오산시 중기지방재정계획
# (표 계속)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 511:------------------------------------
#
# page_content='449
# 다. 도시재정 증진을 위한 재원조달 방안
# 1) 민간참여를 유도하여 시의 재정 보완
# v 자치단체의 재정과 국고보조만으로 시민복지를 위한 도시기반시설 투자가 어려우
# 므로 민간부문을 적극 활용하여 지역개발의 재원수요 절감
# v 개발사업에 따른 이익을 합리적·적극적으로 환수하여 재원조달을 제고하고, 민간
# 개발사업 시 인센티브 제공을 통해 세수의 적극적 유치
# v 관(官)과 민(民)이 특정사업에 소요되는 비용을 공동 분담하여 관의 행정력과 민의
# 창의력으로 투자효과를 극대화하는 제3섹터 활성화
# 2) 세외수입의 발굴
# v 상하수도, 대중교통, 병원, 폐기물처리 등 일반행정방식에 의해 운영되고 있는 단
# 위기업적 성격의 사업을 수익자 부담원칙에 의한 독립채산 경영방식으로 전환
# v 지역 내 관광자원의 사업화를 통해 세수입 증대
# 3) 유사·중복사업의 통·폐합
# v 지방재정의 책임성을 확보하고 건전한 운용을 위하여 부서·유관기관간 협의를 통해
# 유사·중복사업은 통·폐합하는 등의 방법 강구
# v 사업 및 집행이 확정된 사업들을 검토하여 향후 투자가 중단되지 않고 사업이
# 마무리되도록 유도
# 4) 재정구조 개편을 통한 자주재원 확충
# v 지방세수 확충을 위해 지방세원(지방세, 세외수입) 발굴 연구, 국세·지방세 개편을
# 위한 중·장기 실행계획 수립 및 추진
# v 공무원 및 민간전문가로 구성된 체납징수 총괄반 구성, 체납징수 공무원 사법권한
# 강화, 국세 및 지방세 관리프로그램간 연계 추진 등 체납 징수 총괄(지방세, 세외
# 수입) 전담반 운영
# v 장기적 채무관리계획(일반채무, 우발채무 등) 수립 및 중장기 투자 계획과 연계한
# 지방채 발행 등 지방채·통합관리기금 투자자금 확충
# v 재정사업들의 정기 및 수시점검을 통한 예산낭비 방지를 위해 공무원 및 민간
# 전문가로 구성된 예산낭비방지센터 운영' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 462, 'page_label': '463'}
# Split 512:------------------------------------
#
# page_content='450
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# 3. 실천전략
# 가. 합리적인 세원관리
# v 재산세제는 과세표 현실화를 감안 과세시가표준액을 현실과 일치하도록 조정
# v 국고보조금 및 도비보조금의 확대를 위하여 오산시 정책을 국가정책에 맞춰 상호
# 보완
# 나. 민간자본의 적극유치를 통한 재정 보완
# v 도로·교량사업, 주택지개발사업, 산업단지개발사업, 도시재생활성화사업, 관광지·
# 유원지 개발사업 등 공익성과 수익성을 동시에 갖고 사업에 대한 민간자본 참여
# 적극 유도
# v 민간투자법에 의한 사회기반시설(도로, 철도, 수자원, 정보통신, 에너지, 환경·문
# 화·관광·체육, 교육, 주택시설 등)에 대한 민간투자 적극 유치
# 다. 시민참여 예산제 운영
# v 홍보강화, 예산학교 운영 등을 통해 행정의 일방적 주도가 아닌 시민과의 긍정적
# 협력관계 형성
# v 자체적인 심의기준을 통한 우선순위 사업 선정과 사업 검토로 자체역량 강화
# v 예산 제안의 다양화 및 참여계층 확대(청소년, 여성 참여 확대)
# 라. 투자방식의 변화 유도
# v 공공서비스에 대한 가격보조를 지양하고 지원이 필요한 계층에 대해서는 직접지원
# 방식으로 전환
# v 사회적 일자리 지원을 통하여 고령화에 따른 복지지출의 과도한 증가는 방지하고
# 근로연계복지로의 체계로 전환하여 근로친화적인 환경 조성
# 마. 재정운영의 건전성 도모
# v 단계별 투자 우선순위를 합리적으로 선정하여 재정운영을 개선
# v 중기지방재정계획과 예산사전배분제도의 정착으로 재정운영의 책임성과 투명성을
# 제고' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 463, 'page_label': '464'}
# Split 513:------------------------------------
#
# page_content='451
# 4. 단계별 투자계획
# 가. 투자우선의 원칙
# v 도시미래상과 목표에 부합하며, 지역개발의 파급효과가 큰 사업을 전략사업으로
# 정하여 우선적으로 투자
# v 전략사업의 원활한 시행 및 국비지원 가능성 증대를 위해 정부정책과 부합 및
# 연계성이 큰 사업을 우선적으로 투자
# v 지역주민의 삶의 질 향상과 지역주민의 요구에 부합하는 사업에 투자
# v 오산시의 신･구도심간 불균형을 해소하기 위한 상생발전 및 주변도시와 상생발전
# 할 수 있는 사업에 투자
# v 부정적인 영향을 최소화하고, 긍정적인 시너지효과를 극대화 할 수 있는 사업에 투자
# v 도시공간구조의 효율적 개편과 관련이 큰 사업에 투자
# v 도시규모에 비해 절대적으로 부족한 기반시설사업에 우선적 투자
# < 투자 우선순위 결정을 위한 고려사항 >
# 나. 재원배분 계획
# v 도시기본계획에서 제시되는 정책 및 전략사업에 대한 재원배분계획이 필요한 바,
# 공공성과 수익성의 정도에 따라 공공성과 민간의 역할 설정
# v 민간부문의 참여가 강조될 경우, 공공은 민간참여를 유인할 수 있는 방식을 선택하여
# 재원을 투자
# v 오산시의 세입구조로는 2035년까지 투자해야 할 주요 핵심사업의 재원 확보에 한계가
# 있는 바, 공공과 민간의 역할을 설정하고 민자유치, 국비 및 도비 등의 다각적 재원
# 확충방안을 모색하되, 부족액에 대해서는 기채를 방행하는 방안 강구
# v 재원 확보를 통한 전략사업의 원활한 수행을 도모하고 단계별 대응전략 수립' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 464, 'page_label': '465'}

# %%
print(type(all_splits[0]))
# all_splits에 담긴 요소들이 어떤 데이터 타입인지 출력 해보자.
# 랭체인에서는 외부 문서를 Document 객체를 이용해 저장한다.
# Document 클래스는 텍스트 데이터와 관련 메타데이터를 저장하고 관리하는 기본단위임
# page_content 속성에 텍스트 데이터를, Metadate 속성에 해당 메타 데이터를 저장하여 문서를 효과적으로 처리 함
# Out:
# <class 'langchain_core.documents.base.Document'>

# %%
loader_seoul = PyPDFLoader('C:/Users/a/LLM/ch09/data/osan_city_plan.pdf')
data_seoul = loader_seoul.load()
seoul_splits = text_splitter.split_documents(data_seoul)
for i, split in enumerate(seoul_splits):
    print(f"Split {i+1}:------------------------------------")
    print(split)

# 아래 결과를 확인 해보면 페이지단위로 청크가 끊어 져 있음
# 각 청크를 오버랩을 포함하여 빠지는 일이 없도록 해야 한다.
# 이처럼 문장이 페이지 경계에서 끊어지는 문제가 발생한다면 오버랩이 되도록 하는 코드를 추가해야 한다.
# Out:
# Split 1:------------------------------------
# page_content='제1장
# 계획의 기조' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 10, 'page_label': '11'}
# Split 2:------------------------------------
# page_content='Ⅰ
# 계획의 개요' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 12, 'page_label': '13'}
# Split 3:------------------------------------
# page_content='1
# Ⅰ. 계획의 개요
#  계획의 배경 및 목적
# 1. 계획의 배경
# 가. 국내･외 도시환경 여건변화 대응
# v 정부의 저탄소 녹색성장을 위한 정책목표에 부합되도록 하며, 온실가스 저감 등
# 기후변화에 대응하기 위하여 공간구조, 교통체계, 환경의 보전과 관리 등 체계적
# 이고 포괄적 계획 수립
# v 분당선 연장, GTX 등 광역교통망의 확충 및 오산시의 도시공간구조 재편, 사회･
# 경제적 여건 및 도시환경의 여건변화를 반영한 도시의 장기발전방향 및 미래상을
# 제시하는 계획 필요
# 나. 상위계획 정책방향 반영
# v 제5차 국토종합계획(2020~2040), 경기도종합계획, 2020년 수도권광역도시계획(수
# 정) 등 국토 및 도시 관련정책이 지속적으로 변화됨에 따라 시대적 여건변화에 탄
# 력적으로 대응하는데 한계가 있음
# v 도시정책 및 도시여건변화로 인해 도시지표의 수정이 필요함에 따라 각 부문별 지표
# 및 도시구조, 인구규모 등을 재조정하여 장기적인 발전방향과 전략을 제시하는
# 도시기본계획 수립
# 다. 도시계획 패러다임의 변화
# v 안전도시, 저탄소 녹색성장, 도시재생, 지속가능한 도시, 스마트 도시 등 도시계획
# 패러다임 변화에 대응
# 라. 기 수립된 도시기본계획 재검토
# v 기 수립된 2020년 오산도시기본계획은 이러한 오산시 대내･외의 여건변화를 충분히
# 수용하지 못하고 있음
# v 새로운 관점에서 오산시의 문제점을 개선하고 미래지향적이며, 지속가능한 도시로
# 변모하기 위해서는 장기적 관점에서 지표가 되는 도시기본계획의 재검토가 요구
# 되고 있는 시점임' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 14, 'page_label': '15'}
# Split 4:------------------------------------
# page_content='2
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
# 2. 계획의 목적
# 가. 도시의 정체성 및 도시기능 재정립
# v 도시정체성을 구현하고 수도권 남부의 생동감 있는 도시기능을 수행할 수 있는
# 장기적 미래비전을 제시하고, 체계적이고 실현가능한 종합발전 가이드라인 수립
# v 주변 도시로의 도시 확산과 개발압력 등을 고려하여 도시공간구조, 생활권을 재설정
# 하고, 그에 따른 적정밀도의 인구배분계획 및 도시기반시설의 적정배치
# v 수도권 남부 중심도시로 수행할 수 있는 장기적인 미래비전 제시와 체계적이고 실현
# 가능한 종합발전 가이드라인 수립으로 도시정체성 재정립
# 나. 자족기능 확보와 미래 산업에 대비한 지역맞춤형 계획 수립
# v 도시기능의 다양화 일환으로 지식기반첨단산업 육성을 통해 도시의 자족기능 확보
# v 새로운 문화・관광 콘셉트를 확립하여 기존 문화・관광시설 확충 및 신규 문화・
# 관광인프라 구축 등 다양한 문화・관광기능 활성화
# v 4차산업을 대비한 지역맞춤형 산업거점을 조성하여 주거, 일자리, 복지, 여가,
# 문화, 교육 등을 유기적으로 연계
# 다. 구도심 활성화 및 주거환경 개선을 위한 도시재생계획 수립
# v 오산시의 경제적･사회적･문화적 활력 회복을 위하여 공공의 역할과 지원을 강화
# 함으로써 지역 공동체를 회복하고 도시의 경쟁력 제고
# v 물리적 공간 개선, 낙후된 주거환경 개선 등을 통한 구도심 활성화로 새로운 일자리
# 창출 및 신성장산업 발굴
# v 주공혼재지역에 대해 산업과 주거의 계획적인 분리로 산업환경과 쾌적한 주거환경
# 개선
# 라. 시민참여형 도시기본계획 수립
# v 과거 하향식 계획수립과 제한적인 시민참여에 의한 일방적 계획통보 방식에서
# 탈피하고 시민참여형 거버넌스 구축을 통한 상향식 계획 수립
# v 주민의 참여를 촉진함으로써 커뮤니티의 자치 역량을 강화하고 구성원들의 권리
# 의식과 효능감 배양' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 15, 'page_label': '16'}
# Split 5:------------------------------------
# page_content='3
# 3. 계획의 성격
# 가. 종합계획
# v 오산시의 물리적, 공간적 측면과 환경적, 경제적, 사회적 측면을 포괄하여 미래
# 변화에 대응하는 종합계획으로 지속가능한 국토관리를 위한 정책과 전략으로
# 구체화
# 나. 정책계획
# v 국토종합계획, 수도권정비계획, 수도권광역교통계획 등 관련 상위계획 내용을 수용
# 하여 오산시가 지향해야 할 바람직한 도시 미래상과 장기적인 발전방향을 제시
# 다. 전략계획
# v 도시행정의 바탕이 되는 오산시의 주요지표와 토지의 개발･보전, 기반시설의 확충
# 및 효율적인 도시관리전략을 제시하여 하위계획인 도시관리계획 등 관련계획의
# 기본이 되도록 함
# 라. 실천계획
# v 도시기본계획이 추구하고 있는 도시의 발전방향에 대한 지침적 성격과 함께 목표를
# 달성하기 위한 실천적 방안을 제시
# v 종합적인 계획내용 뿐만 아니라 각 부문별 계획이 상호 유기적으로 연계되도록 수립' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 16, 'page_label': '17'}
# Split 6:------------------------------------
# page_content='4
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
#  계획의 범위
# 1. 시간적 범위
# v 계획 기준연도 : 2016년
# v 계획 목표연도 : 2035년
# - 계획기간을 4단계로 구분하여 단계별 계획을 5년 단위로 수립
# 구 분 1단계 2단계 3단계 4단계 비 고
# 년 도 2016~2020년 2021~2025년 2026~2030년 2031~2035년 -
# < 단계별 계획 기간 >
# 2. 내용적 범위
# 구 분 계획내용
# 도시지표 및
# 생활권 설정
#  2035년 오산시 미래인구 예측 및 여건을 고려한 목표인구 산정
#  경제, 산업, 생활, 복지, 여가, 문화 등 환경지표 설정
#  자연, 사회, 인문, 생활여건 등 지역현황을 고려한 생활권 재편
#  목표인구를 기준으로 생활권별 인구배분
# 부
# 문
# 별
# 계
# 획
# 토지이용
#  도시공간구조와 연계된 토지이용계획 수립
#  토지이용현황 분석을 통하여 개발가능지를 추출하고 용도별 토지수요를
# 전망하는 한편 토지 수요를 충족하기 위한 계획의 방향 설정과 시가지화
# 할 지역과 보전할 지역을 구분
# 기반시설
#  도시기반시설의 정비와 확충방안, 분야별 현황분석과 전망을 통한
# 개선 목표와 전략을 강구
#  광역가로망 개선 및 체계적인 가로망 구축으로 도시간 연결성 강화
# 도심 및
# 주거환경
#  도심-구도심 간 지역균형발전을 도모하고 주거환경을 개선하여 원
# 도심 활성화전략 수립
#  도시재생전략계획의 방향을 제시해 줄 수 있도록 도시재생전략 및
# 정책방향 제시
# 환경보전
# 및 관리
#  주요환경부문에 대한 검토와 분석을 통하여 쾌적하고 효율적인 도시
# 공간 조성
#  에너지이용 효율화, 신재생에너지 사용유도 등을 통해 저탄소녹색도시
# 구현
# 경관 및
# 미관
#  도시경관과 미관조성에 대한 구체적인 방안과 지침을 제시하여 오산
# 시의 경관을 선진화하고 경관형성을 통한 오산시의 정체성을 확립
# 공원 및
# 녹지
#  수변축, 녹지축 등 보전축과 연계한 광역녹지체계 구축
#  장기미집행시설 해소와 더불어 규제완화를 통해 실행가능한 계획수립
# < 내용적 범위 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 17, 'page_label': '18'}
# Split 7:------------------------------------
# page_content='5
# 구 분 계획내용
# 부
# 문
# 별
# 계
# 획
# 방재 및
# 안전
#  기후변화에 대비한 종합적 도시재해 예방대책 수립
#  도시정보시스템을 통해 종합적 재해･재난 관리 컨트롤타워 구축
#  범죄예방환경설계(CPTED) 기법 도입을 통해 일상생활 속 안전기반
# 확충
# 경제･사회
# ･
# 문화
#  시민참여를 독려함으로써 주민자치 보편화･일상화 유도
#  수요자 중심의 시민안전망을 구축하고 통합적 복지체계 운영
# (표 계속)
# 3. 공간적 범위
# v 오산시 행정구역 면적 : 42.71㎢' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 18, 'page_label': '19'}
# Split 8:------------------------------------
# page_content='6
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
#  계획수립의 기본원칙
# v 계획의 종합성 제고
# - 토지이용・교통・환경 등 물적 공간구조와 경제・사회, 행정・재정 등 비물리적
# 분야 포함
# - 부문별 기초조사결과를 토대로 장래의 전망을 예측하여 창의적인 구상 수립
# - 시행의 과정과 여건변화에 탄력적으로 대응할 수 있도록 포괄적이며 개략적으로 수립
# v 관련계획간의 연계와 조화
# - 국토종합계획・광역도시계획 등 상위계획의 내용을 수용하고, 도시관리계획・
# 지구단위계획 등 하위계획의 수립 고려
# - 도시관리계획을 수립할 때 토지용도 분류의 지침이 되도록 용도지역의 지정에
# 필요한 기준 제시
# v 환경친화적 계획 수립
# - 환경적으로 건전하고 지속가능한 도시개발이 이루어질 수 있도록 자연환경・
# 경관・생태계・녹지공간 등의 정비・개량・보호 및 확충과 도시간의 연담화
# 방지 및 환경오염에 주력하여 계획
# - 자원절약형 개발 및 관리를 위하여 한계자원인 토지・물・에너지의 소비를 최소화
# 하거나 효율적으로 이용될 수 있도록 계획
# - 녹지축・생태계・우량농지, 임상이 양호한 임야, 양호한 자연환경과 수변지역 등
# 환경적으로 보전가치가 높고 경관이 뛰어난 지역은 보전
# v 계획의 차등화・단계화
# - 인구밀도, 토지이용 특성 및 주변환경 등을 종합적으로 고려하여 지역별로 차등화
# - 기반시설의 배치계획, 토지용도 등은 지역간 서로 연계되어 계획・관리될 수
# 있도록 계획
# - 각 부문별계획은 목표연도 및 단계별 최종연도로 작성하고 인구 및 주변 환경의
# 변화에 따라 탄력적으로 도시관리계획에 반영될 수 있도록 계획' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 19, 'page_label': '20'}
# Split 9:------------------------------------
# page_content='7
#  계획수립의 과정
# 1. 계획수립 절차
# ■ 계획수립 근거 : 「국토의 계획 및 이용에 관한 법률」 제18조
# ⦁도시현황 조사
# ⦁상위 및 관련계획 검토
# ⦁잠재력 및 제약조건 분석
# SWOT분석·도시잠재력 도출
# 도시미래상 정립 ⦁도시정책시민참여단 운영
# - 2016.9~2017.1 (4회)
# - 미래상·추진전략 제시
# ⦁단계별 지표전망 및 설정 도시지표 설정
# ⦁공간구조 대안설정
# ⦁기본방향, 발전전략 도시공간구조 구상·생활권 재편
# 부문별계획 국토계획평가 협의회
# (기준 및 방법 설정)
# ⦁인구배분계획
# ⦁토지이용계획
# ⦁도심 및 주거환경
# ⦁기반시설계획
# ⦁환경보전 및 관리
# ⦁경관·미관계획 국토계획평가 요청서
# 작성
# ⦁공청회, 주민공람
# ⦁시의회의견청취
# ⦁시 도시계획위원회 자문
# 시민의견 수렴 및 계획(안) 조정
# 도시기본계획(안) 작성
# 도시기본계획 승인신청 국토계획평가 요청서
# 제출
# ⦁관계 행정기관 협의
#   (경기도 및 중앙부처) 국토정책위원회 심의
# 경기도 도시계획위원회 심의
# (경기도지사)
# 도시기본계획 승인
# 도시기본계획 공고·열람
# (오산시청)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 20, 'page_label': '21'}
# Split 10:------------------------------------
# page_content='8
# 제1장 계획의 기조
# Ⅰ. 계획의 개요
# 2. 추진경위
# v 2016. 06. 23. : 2035년 오산 도시기본계획 수립용역 착수
# v 2016. 11. 26. : 오산 도시정책 시민참여단 1차 회의
# v 2016. 12. 10. : 오산 도시정책 시민참여단 2차 회의
# v 2017. 01. 07. : 오산 도시정책 시민참여단 3차 회의
# v 2017. 01. 21. : 오산 도시정책 시민참여단 4차 회의
# v 2018. 01. 25. : 2035년 오산도시기본계획 수립(안) 중간보고 1차
# v 2018. 02. 01. : 1차 국토계획평가협의회
# v 2018. 03. 16. : 2차 국토계획평가협의회
# v 2018. 03. 27. : 2035년 오산도시기본계획 수립(안) 중간보고 2차
# v 2018. 04. 06. : 시 도시계획위원회 사전자문
# v 2018. 04. 16. ~ 20. : 시 의회의견 청취
# v 2018. 09. 04. : 공청회 - 전문가 및 주민의견 청취
# v 2018. 10. 01. ~ 10. : 시 관련부서 협의
# v 2018. 11. 09. : 오산시 도시계획위원회 자문
# v 2019. 04. 03. : 국토계획평가요청서 제출(오산시→국토교통부)
# v 2019. 05. 27. : 2035년 오산도시기본계획(안) 승인 신청(오산시→경기도)
# v 2019. 06. 03.~ 10. 10. : 경기도 관련부서 및 관계기관 협의
# v 2019. 07. 12. : 국토계획평가 국토정책위원회 국토계획평가분과위원회 심의
# v 2019. 12. 20. : 제17회 경기도 도시계획위원회 심의
# v 2020. 02. 07. : 제1회 도시기본계획 인구･토지이용 사전검토 소위원회 심의
# v 2020. 05. 08. : 제8회 경기도 도시계획위원회 심의
# v 2020. 06. 19. : 제17회 경기도 도시계획위원회 재심의
# v 2020. 09. 01. : 2035년 오산도시기본계획 승인' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 21, 'page_label': '22'}
# Split 11:------------------------------------
# page_content='Ⅱ
# 지역의 특성과 현황' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 22, 'page_label': '23'}
# Split 12:------------------------------------
# page_content='11
# Ⅱ. 지역의 특성과 현황
#  도시연혁
# 1. 시․군의 역사
# v 오산시는 600년경 고구려의 매홀군으로 불리었다는 기록이 남아있으며 그 이전의
# 원삼국시대와 선사시대에 관한 기록은 없음
# v 청동기 시대를 거쳐 원삼국시대에는 마한이 영토, 백제 근초고왕(346~375) 때에
# 백제의 영토가 되었다가 고구려 장수왕(394~491) 때 한강연안 및 경기도 전 지역이
# 고구려 남쪽의 영토가 됨
# v 18세기 말 이래 수원군 청호면, 성호면, 오산면 등으로 불리다가 1949년 화성군
# 오산면으로 행정구역이 바뀐 후 오산읍으로 거쳐 1989년 오산시로 승격
# v 1995년 평택군 진위면의 갈곶리, 고현리, 청호리 일부 편입을 통해 현재에 이름
# 연     대 연                      혁
# 600년대  고구려 매홀군
# 757년  신라 수성군(경덕왕 16년)
# 1310년  고려 수원부(충선왕 2년)
# 1899. 2. 1  수원부 4개면(청호, 문시, 산성, 초평)
# 1914. 4. 1  수원군 성호면
# 1941.10. 1  수원군 오산면(소화 16년 10. 1.)
# 1949. 8.15  수원군 오산면(24개리) [대통령령 제161호]
# 1960. 1. 1  화성군 오산읍으로 승격 [법률 제1175호]
# 1987. 1. 1  화성군 동탄면 금곡3리 편입 (45개리) [대통령령 제12007호]
# 1989. 1. 1  오산시로 승격 (6개동) [법률 제4050호]
# 1995. 4.20  평택군 진위면 갈곶, 고현, 청호리 일부편입
#  [대통령령 제14629호]
# 자료 :  오산시 통계연보, 2019
# < 오산시 연혁 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 24, 'page_label': '25'}
# Split 13:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 12
# 2. 행정구역 변천
# 가. 연도별 행정구역 변화추이
# v 오산시는 6개 행정동, 24개의 법정동으로 형성되어 있으며, 총면적 42.71㎢ 임
# 년별과 동별 면적(㎢) 행정동 법정동 통 반 소재지 비 고
# 2011 42.77 6 24(8) 271 1,837
# 2012 42.74 6 24(8) 280 1,848
# 2013 42.73 6 24(8) 287 1,908
# 2014 42.73 6 24(8) 287 1,908
# 2015 42.73 6 24(8) 287 1,908
# 2016 42.73 6 24(8) 289 1,918
# 2017 42.73 6 24(8) 303 2,081
# 2018 42.72 6 24(8) 326 2,214
# 2019 42.71 6 24(8) 326 2,214
# 중앙동 3.66 1 3 58 374 경기대로 307
# 대원동 6.20 1 6 93 610 오산로132번길 28
# 남촌동 6.05 1 7 43 240 청학로 55-5
# 신장동 7.02 1 5 75 604 문헌공로 45
# 세마동 13.31 1 5 36 252 독산성로 419
# 초평동 6.47 1 6 33 207 발안로 1308-9
# 주 :  법정동의 ( )는 중복 동수임
# 자료 : 2020년도 지방자치단체 행정구역 및 인구 현황(2019.12.31.)
# < 연도별 행정구역 현황 >
# 오산동 부산동 원동 궐동 청학동 가장동 금암동 수청동
# 은계동 내삼미동 외삼미동 양산동 세교동 지곶동 서랑동 서동
# 벌음동 두곡동 탑동 누읍동 가수동 고현동 청호동 갈곶동
# < 법정동(24개동) >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 25, 'page_label': '26'}
# Split 14:------------------------------------
# page_content='13
# 나. 행정동 경계
# v 오산시의 총면적은 42.71㎢로 우리나라 국토(100,295.35㎢)의 0.04%이고 경기도
# 면적(10,175.34㎢)의 0.42%를 차지
# 행 정 구 역 명
# 행정구역면적(㎢) 구성비(%) 비    고
# 시, 구, 군 읍, 면, 동
# 오산시
# 소    계 42.71 100.0
# 중 앙 동 3.66 8.6
# 대 원 동 6.20 14.5
# 남 촌 동 6.05 14.2
# 신 장 동 7.02 16.4
# 세 마 동 13.31 31.2
# 초 평 동 6.47 15.1
# 자료 : 2020년도 지방자치단체 행정구역 및 인구 현황(2019.12.31.)
# < 행정구역 >
# < 행정구역도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 26, 'page_label': '27'}
# Split 15:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 14
# 3. 도시계획 연혁
# 가. 도시계획구역 변천과정
# v 2013년 ‘2020년 오산도시기본계획 재수립’의 경기도 승인 이후 오산시의 도시계획면적은
# 42.76㎢임
# 구  분 고   시   번   호 내              용
# 1965년 건・고 제1825호  계획구역 결정(면적 : 22.975㎢)
# 1968년 건・ 고 제488호  도시계획 일부변경
# 1970년 건・고 제7호  도시계획구역 변경
# 1971년 건・ 고 제669호  도시계획구역 변경(면적 : 51.585㎢)
# 1972년 건・ 고 제231호  도시계획변경 결정
# 1973년 건・ 고 제214호  토지구획정리사업에 관한 계획결정
# 1975년 건・고 제2호  도시계획구역 변경결정(면적 : 10.62㎢)
# 1976년 건・ 고 제194호  도시계획구역 재정비(면적 : 10.654㎢)
# 1986년 건・ 고 제133호  도시계획재정비
# 1993년 건 ・고 제59호  도시계획재정비(용도지역 결정)
# 1994년 건교부 승인  2011년 도시기본계획 승인(28.675㎢)
# 1995년 대통령령 제14629호  행정구역개편(평택군 진위면 갈곶, 고현, 청호리
# 오산시 편입)
# 1995년 건 ・고 제96-116호  도시계획재정비 결정(28.675㎢)
# 1995년 오산시고 95-36호  오산도시계획지적고시(28.675㎢)
# 2000년 건교부 승인  2016년 도시기본계획 승인(42.757㎢)
# 2002년 건 ・고 제2002-203호  도시계획구역 변경
# 2003년 건 ・고 제2003-129호  오산도시관리계획(재정비) 결정(도 권한사항)
# 2003년 오・ 고 제2003-43호  오산도시관리계획(재정비) 결정(시 권한사항)
# 2007년 오 ・공 제2007-753호  2020년 도시기본계획 승인
# 2009년 오 ・공 제2009-286호  2020년 도시기본계획(변경) 승인
# 2009년 오・ 고 제2009-41호  2015년 도시관리계획(재정비) 결정(시 권한사항)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 27, 'page_label': '28'}
# Split 16:------------------------------------
# page_content='2009년 오 ・공 제2009-286호  2020년 도시기본계획(변경) 승인
# 2009년 오・ 고 제2009-41호  2015년 도시관리계획(재정비) 결정(시 권한사항)
# 2009년 경 ・고 제2009-456호  2015년 도시관리계획(재정비) 결정(도 권한사항)
# 2013년 오 ・공 제2013-548호  2020년 도시기본계획 재수립 승인
# (면적 : 42.757㎢)
# 2016년 오・ 고 제2016-23호  2020년 관리계획(재정비)결정(시 권한사항)
# 2017년 경・ 고 제2017-19호  2020년 관리계획(재정비)결정(도 권한사항)
# 2017년 오・ 고 제2017-1303호  2020년 기본계획 일부변경 승인
# < 도시계획연혁 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 27, 'page_label': '28'}
# Split 17:------------------------------------
# page_content='15
#  도시의 세력권
# 1. 지리적 위치
# v 수도권 서남부에 위치한 오산시는 동쪽으로는 화성시 동탄동, 서쪽으로는 화성시
# 정남면, 남쪽으로는 평택시 진위면, 북쪽으로는 화성시 병점동에 접하고 있음
# v 지형은 북동과 서남으로 폭이 짧고, 서북과 남동으로 폭이 길며 도청소재지인 수원과
# 16.9Km 떨어져있으며 철도, 고속도로, 국도가 통과하는 산업, 교통의 요충지임
# 시청소재지 단 경도와 위도의 극점 연 장 거 리
# 지 명 극 점
# 경기도 오산시
# 성호대로 141
# 동단 오산시 원동 북위 37° 08' 24"
# 동경 127° 06' 21"
# 동서간 9.8㎞
# 남북간 8.2㎞
# 서단 오산시 서랑동 북위 37° 10' 24"
# 동경 126° 59' 07"
# 남단 오산시 갈곶동 북위 37° 07' 27"
# 동경 127° 04' 00"
# 북단 오산시 양산동 북위 37° 11' 55"
# 동경 127° 01' 12"
# 자료 : 오산시 통계연보, 2019
# < 경・위도상 위치 >
# < 지리적 위치도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 28, 'page_label': '29'}
# Split 18:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 16
# 2. 도시 세력권
# 가. 행정권
# v 일반 행정권이 미치는 범위는 오산시 행정구역 전 지역(42.71㎢)으로서,  6개 행정동
# (24개 법정동)으로 구성되어 있음
# v 도시계획의 수립 및 집행으로 관리하는 행정권역 역시 행정구역(42.71㎢)과 동일함
# 나. 경제권
# v 출퇴근 고용인구, 공급원료, 소비상품, 시장이용권 등 유통 및 상업시설, 금융시설
# 이용권이 해당
# v 오산을 중심으로 반경 10㎞ 권내에 입지하고 있는 수원, 화성, 평택, 용인시 등이 속함
# 다. 사회․문화권
# v 학교, 병원, 도서관, 박물관 등 문화시설, 체육시설 등 생활서비스 시설을 이용하는
# 지역적 범위인 사회적 영향권역
# v 경제권과 비슷한 영역을 나타내고 있으며, 상품소비권은 화성, 수원에 의존도가
# 강함
# v 오산시를 포함하여 화성시 병점동, 동탄동, 정남면, 평택시 진위면, 용인시 남사면
# 일원을 사회문화권으로 설정
# 라. 환경권
# v 자연환경 보전을 위한 녹지축, 수계축을 중심으로 오산시 주변의 화성시, 평택시,
# 용인시를 환경권으로 설정
# - 녹지축 : 노적봉~양산봉~여계산~반월봉~필봉으로 이어지는 녹지축과 여계산에서
# 수목원과 중앙공원으로 연계되는 녹지축 설정
# - 수계축 : 맑은 물 공급과 생태환경 보전을 위하여 황구지천의 물줄기가 흐르는
# 화성시, 오산천의 상류인 수원시를 범위로 포함' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 29, 'page_label': '30'}
# Split 19:------------------------------------
# page_content='17
#  도시의 현황과 특성
# 1. 자연환경
# 가. 지형 및 경사도
# v 오산시는 대체로 서고동저지형으로 도시형태는 비교적 낮은 산세에 의한 소분지와
# 소평야 지대를 형성하고 있음
# v 오산천을 중심으로 동측으로는 평탄지, 서측으로 평탄지와 얕은 구릉지를 형성
# 하고 있으며, 북측으로는 반월봉(118m), 양산봉(180m), 세마대(208m)를 중심
# 으로 구릉지를 형성하고 있음
# v 표고는 50m이하가 계획구역 면적 42.71㎢ 중 72.1％(30.81㎢)를 점유
# (단위 : ㎢, %)
# 구    분 계 50m 이하 50~70m 70~100m 100m 이상
# 면    적 42.71 30.81 6.76 3.69 1.45
# 구 성 비 100.0 72.1 15.8 8.7 3.4
# 주 : 1/25,000상에서 구적, GIS분석
# < 표고분석 >
#                < 표고분석도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 30, 'page_label': '31'}
# Split 20:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 18
# v 경사는 전체적으로 완만하며 경사도 10％이하의 지역이 63.8%를 차지하고 있어
# 계획구역의 개발잠재력은 풍부하다고 판단
# (단위 : ㎢, %)
# 구    분 계 10% 이하 10~20% 20~30% 30% 이상
# 면    적 42.71 27.26 8.53 3.98 2.94
# 구 성 비 100.0 63.8 20.0 9.3 6.9
# 주 : 1/25,000상에서 구적, GIS분석
# < 경사분석 >
#              < 경사분석도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 31, 'page_label': '32'}
# Split 21:------------------------------------
# page_content='19
# 나. 수계
# v 오산시는 지정하천 총 20개소(L=30.125km)가 위치하고 있으며, 그 중 국가하천
# 2개소 L=8.26km, 지방하천 3개소 L=5.40km, 소하천 15개소16.465km로 구성되
# 어 있음
# v 오산천은 북동방향에서 오산시로 유입하여 기존 시가지 중심을 남북으로 관통하여
# 원동천, 역말천, 금암천, 궐동천, 죽미령천, 대호천, 작은말천, 가서천, 부산천,
# 서동천, 가장천을 유입하여 남서방향으로 유하하면서 평택시의 진위천과 합류함
# v 황구지천은 오산시 서북측과 화성시를 경계부로 관류하면서 삼미천, 문시천, 외삼미천,
# 양산1천, 양산2천, 서랑천 및 지곶천 등을 유입하여 상위 하천인 진위천과 합류
#   < 수계분석도 >
# 자료 : 오산시 자연재해저감종합계획, 2019. 12' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 32, 'page_label': '33'}
# Split 22:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 20
# 하천
# 등급 하천명
# 구  간 하천
# 연장
# (㎞)
# 유로
# 연장
# (㎞)
# 유역
# 면적
# (㎢)
# 비고기 점 종 점
# 총계(20개소) 53.195
# <30.125> 113.23 463.13
# 국가
# 하천
# 오산천 경기도 용인시 기흥구,
# 화성시 동탄면 경계
# 경기도 평택시 서탄면
# 진위천(국가) 합류점
# 15.03
# <4.36> 30.44 150.52
# 황구
# 지천
# 경기도 화성시 황계동
# 신대황교 지점
# 경기도 평택시
# 서탄면
# 진위천
# (국가) 합류점
# 16.30
# <3.90> 35.12 259.70
# 소  계 31.33
# <8.26> 65.56 610.22
# 지방
# 하천
# 삼미천 경기도 오산시
# 양산동
# 경기도 화성시 병점동
# 황구지천(국가) 합류점 1.04 5.01 9.38
# 가장천 경기도 오산시
# 서동
# 경기도 오산시 누읍동
# 오산천(국가) 합류점 2.73 5.38 6.75
# 궐리천 경기도 오산시
# 수청동
# 경기도 오산시 귈동
# 오산천(국가) 합류점 1.63 4.79 6.37
# 소  계 5.40 15.18 22.50
# 자료 : < >는 오산시 관내 하천연장 및 기·종점 측점
# 주 : 오산시 소하천종합계획, 2017. 7
# < 국가·지방하천 현황 및 개요 >
# v 소하천은 15개소로 총연장은 16.465㎞로서 지방하천으로 합류하나 양산 1, 2천,
# 서랑천 등은 국가하천인 황구지천으로 유입하며, 대호천, 부산천, 원동천, 역말천
# 등은 오산천으로 유입함
# 하천
# 등급 하천명
# 구  간 하천
# 연장
# (㎞)
# 유로
# 연장
# (㎞)
# 유역
# 면적
# (㎢)
# 비고
# 기 점 종 점
# 소
# 하
# 천
# 금암천 오산시 금암동 236-14오산시 수청동 282-140.657 2.66 3.03
# 대호천 오산시 궐동 575-10 오산시 궐동 578 0.376 2.57 1.87
# 부산천 오산시 부산동 764 오산시 부산동 160-2 1.465 2.32 0.99
# 원동천 오산시 원동 729-2 오산시 원동 729-11 1.173 2.26 2.05
# 역말천 오산시 원동 706-4 오산시 원동 121-6 1.112 2.07 1.21' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 33, 'page_label': '34'}
# Split 23:------------------------------------
# page_content='원동천 오산시 원동 729-2 오산시 원동 729-11 1.173 2.26 2.05
# 역말천 오산시 원동 706-4 오산시 원동 121-6 1.112 2.07 1.21
# 서동천 오산시 서동 549 오산시 서동 637-4 1.061 1.83 0.94
# 문시천 오산시 외삼미동 609 오산시 양산동 5 2.872 3.64 6.42
# 외삼미천 오산시 외삼미동 545-21 오산시 외삼미동 492-6 0.811 1.68 1.32
# 양산1천 오산시 양산동 산19-3 오산시 양산동 490-119 1.000 1.17 0.58
# 양산2천 오산시 양산동 662 오산시 양산동 662-3 0.700 1.28 0.46
# 서랑천 오산시 서랑동 산23-2 오산시 서랑동 289-20 1.487 5.02 4.97
# 지곶1천 오산시 지곶동 534-10 오산시 지곶동 534-1 1.649 2.73 3.4
# 지곶2천 오산시 지곶동 534-26 오산시 지곶동 387-6 0.714 1.02 1.32
# 지곶3천 오산시 지곶동 534-21 오산시 지곶동 534-17 0.549 0.97 0.49
# 내삼미천 오산시 내삼미동 704-3 오산시 내삼미동 708-8 0.839 1.27 1.36
# 소  계 16.465 32.49 30.41
# 자료 : 오산시 소하천종합계획, 2017. 7
# < 소하천 현황 및 개요 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 33, 'page_label': '34'}
# Split 24:------------------------------------
# page_content='21
# 다. 기후
# v 경기도 중남부의 내륙 중심지에 위치하여 대륙성 기후의 영향을 받아 비교적 온화한
# 기후 분포를 형성하고 있으며, 한서의 차가 적은 지역으로 농업에 적합한 기후조건임
# v 과거 10년간(09~18년) 평균기온은 12.6℃이며 '18년 월별 최고기온은 8월의 33.
# 5℃이며 최저기온은 1월의 –7.8℃이며, 과거 10년간(09~18년) 평균일조시간은
# 2,346.8시간으로 나타남
# v 과거 10년간(09~18년) 연평균강수량은 1,340.1㎜이고 '18년 기준 강수량은 1,293.1㎜
# 로 전년대비 낮은 강수량을 보이고 있음
# v 주풍향은 북서풍으로 평균 풍속은 1.8m/sec 임
#   구분
# 년도
# 기    온 (℃) 강수량
# (㎜)
# 상대
# 습도
# 평균
# (%)
# 일조
# 시간
# (hr)
# 최심
# 적설
# (㎝)
# 천 기 일 수 (일) 평균
# 풍속
# (m/
# sec)
# 평균 최고 최저 맑음 흐림 비 눈
# 2009 12.6 17.9 8.0 1,541.2 71 2,282.8 7.2 107 86 87 18 1.7
# 2010 12.2 17.1 7.9 1,470.6 73 2,027.9 19.5 93 123 130 29 1.8
# 2011 11.8 16.8 7.4 1,975.9 70 2,146.5 9.2 110 108 108 23 1.7
# 2012 12.1 17.2 7.7 1,748.3 69 2,291.6 10.5 96 84 110 29 1.8
# 2013 12.3 17.5 7.8 1,240.1 72 2,310.2 7.8 107 88 115 26 1.7
# 2014 13.1 18.6 8.5 1,029.1 68 2,372.7 5.5 103 90 97 27 2.1
# 2015 13.5 19.0 8.8 751.1 68 2,450.3 8.2 101 86 107 28 1.8
# 2016 13.6 19.1 9.0 1,023.4 68 2,367.2 3.7 77 86 101 35 1.8
# 2017 12.6 18.3 7.8 1,328.6 67 2,606.1 7.1 122 77 109 28 1.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 34, 'page_label': '35'}
# Split 25:------------------------------------
# page_content='2017 12.6 18.3 7.8 1,328.6 67 2,606.1 7.1 122 77 109 28 1.8
# 2018 12.7 18.5 7.9 1,293.1 67 2,605.5 7.9 112 81 145 21 1.8
# 평균 12.6 18.0 8.08 1,340.1 69.3 2,346.8 8.6 102.8 90.9 110.9 26.4 1.8
# 자료 : 오산시 통계연보, 2019
# < 기상개황 및 천기일수 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 34, 'page_label': '35'}
# Split 26:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 22
# 구 분
# 기    온 (℃)
# 강수량
# (㎜)
# 상대
# 습도
# 평균
# (%)
# 일조
# 시간
# (hr)
# 최심
# 적설
# (㎝)
# 천 기 일 수 (일) 평균
# 풍속
# (m/
# sec)평균 최고 최저 맑음 흐림 비 눈
# 1월 -3.6 1.3 -7.8 7.9 57 194.1 6.4 11 5 8 7 1.8
# 2월 -1.6 4.3 -6.8 29.1 54 201.3 7.9 11 3 7 6 2.0
# 3월 7.9 14.2 2.9 86.0 69 212.2 1.6 8 6 12 1 2.1
# 4월 12.6 19.3 6.8 128.8 65 219.2 - 11 10 13 - 2.0
# 5월 17.9 23.7 12.6 196.4 73 219.3 - 8 10 19 - 2.0
# 6월 22.6 28.7 17.9 107.0 72 229.2 - 4 12 13 - 1.9
# 7월 27.5 32.5 23.5 222.7 75 255.2 - 8 7 17 - 1.8
# 8월 28.4 33.5 24.6 218.6 72 234.8 - 5 8 18 - 2.1
# 9월 21.1 26.2 16.8 61.7 71 212.3 - 9 8 13 - 1.9
# 10월 12.6 19.1 7.2 132.7 73 240.8 - 12 3 12 - 1.4
# 11월 7.7 14.2 2.6 78.1 71 186.7 2.4 13 6 6 1 1.3
# 12월 -0.3 5.2 -5.1 24.1 56 200.4 4.9 12 3 7 6 1.7
# 자료 : 오산시 통계연보, 2019
# < 월평균 기상개황 및 천기일수 현황(′18) >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 35, 'page_label': '36'}
# Split 27:------------------------------------
# page_content='23
# 라. 생태/식생
# 1) 국토환경성평가지도
# 자료 : 국토환경성평가지도(https://ecvam.neins.go.kr), 2019년 기준
# < 국토환경성평가지도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 36, 'page_label': '37'}
# Split 28:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 24
# 2) 생태자연도
# 자료 : 환경공간정보서비스(https://egis.me.go.kr ), 2019년 기준
# < 생태자연도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 37, 'page_label': '38'}
# Split 29:------------------------------------
# page_content='25
# 2. 인구현황
# 가. 인구변화추이
# 1) 성별인구 및 가구
# v 2018년 12월말 기준으로 오산시의 총인구는 233,730명으로 경기도 인구(2018년
# 기준 약 13,490,000명)의 약 1.7%를 차지하고 있음
# v 2018년 12월말 기준으로 오산시 가구수는 89,860가구(세대)로 2009년 62,410가구
# (세대)의 약 1.4배로 증가하였으며, 가구당 구성원은 2.60인/가구(세대)로 나타남
# v 인구밀도는 54.7인/㏊며, 행정동별로 살펴보면 대원동이 110.6인/㏊로 가장 높으며,
# 중앙동 100.2인/㏊, 신장동 89.7인/㏊, 남촌동 44.3인/㏊, 초평동이 25.3인/㏊이
# 며, 세마동이 19.1인/㏊으로 가장 낮음
# v 오산시의 인구변화추이는 과거 10년간('09∼'18) 연평균 4.8%씩 증가추세를 보이고 있음
# 구 분
# 인 구 (인)
# 가구(호)합계 내국인 외국인남 여
# 2009 163,448 81,570 78,164 3,714 62,410
# 2010 186,382 93,054 89,462 3,866 70,714
# 2011 198,514 98,983 94,909 4,622 74,807
# 2012 205,900 102,396 97,895 5,609 77,951
# 2013 211,559 105,145 100,315 6,099 79,951
# 2014 216,230 106,843 101,722 7,665 81,146
# 2015 216,524 105,966 100,862 9,696 81,033
# 2016 219,294 107,056 101,600 10,638 82,581
# 2017 225,309 109,620 103,817 11,872 85,445
# 2018 233,730 113,237 106,833 13,660 89,860
# 중앙동 35,771 16,778 16,484 2,509 12,751
# 대원동 67,161 32,882 31,220 3,059 25,245
# 남촌동 26,250 11,937 8,723 5,590 12,891' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 38, 'page_label': '39'}
# Split 30:------------------------------------
# page_content='대원동 67,161 32,882 31,220 3,059 25,245
# 남촌동 26,250 11,937 8,723 5,590 12,891
# 신장동 61,888 30,295 30,101 1,492 23,191
# 세마동 26,184 13,178 12,410 596 9,553
# 초평동 16,476 8,167 7,895 414 6,229
# 연평균증가율 4.8% 4.9%
# 인구밀도 54.7인/ha
# 가구당 인구 2.60인/가구
# 자료 : 오산시 통계연보, 2019 / 행정안전부 외국인 통계자료
# < 연도별 인구 및 가구 추이 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 38, 'page_label': '39'}
# Split 31:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 26
# 2) 연령별 및 성별 인구구조
# v 2018년도 오산시 인구는 남자가 여자에 비해 약 6.4천명 가까이 많아 남녀의 성비는
# 106.0%를 보임
# v 0~59세까지의 인구에서는 남자가 여자에 비해 많았으나 60세 이상의 인구에서는 여자가
# 남자에 비해 더 많은 인구가 거주하고 있음
# v 35~39세의 인구가 10.8%로 가장 많은 비율을 차지하고 있음
# v 0~14세 인구 38,679인(17.6%)와 65세 이상 인구 18,589인(8.4%)의 비생산 연령층은
# 전체인구의 26%를 차지하고 있으며 경제활동가능인구는 전체인구의 74%임
# 5   세
# 계급별
# 인 구 구 성 비
# 남 여 남 여
# 총계 220,070 113,237 106,833 100.0 100.0 100.0
# 0세~4세 11,896 6,116 5,780 5.4 5.4 5.4
# 5세~9세 14,246 7,315 6,931 6.5 6.5 6.5
# 10세~14세 12,537 6,453 6,084 5.7 5.7 5.7
# 15세~19세 12,471 6,435 6,036 5.7 5.7 5.6
# 20세~24세 13,668 7,116 6,552 6.2 6.3 6.1
# 25세~29세 15,225 8,322 6,903 6.9 7.3 6.5
# 30세~34세 16,730 8,780 7,950 7.6 7.8 7.4
# 35세~39세 23,768 12,495 11,273 10.8 11.0 10.6
# 40세~44세 20,867 11,126 9,741 9.5 9.8 9.1
# 45세~49세 19,854 10,470 9,384 9.0 9.2 8.8
# 50세~54세 16,148 8,361 7,787 7.3 7.4 7.3
# 55세~59세 14,094 7,275 6,819 6.4 6.4 6.4
# 60세~64세 9,977 4,940 5,037 4.5 4.4 4.7
# 65세~69세 6,144 2,949 3,195 2.8 2.8 3.0
# 70세~74세 4,799 2,199 2,600 2.2 1.9 2.4' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 39, 'page_label': '40'}
# Split 32:------------------------------------
# page_content='65세~69세 6,144 2,949 3,195 2.8 2.8 3.0
# 70세~74세 4,799 2,199 2,600 2.2 1.9 2.4
# 75세~79세 3,884 1,613 2,271 1.8 1.4 2.1
# 80세이상 3,762 1,272 2,490 1.7 1.1 2.3
# 자료 : 오산시 통계연보, 2019
# 주 : 외국인 제외
# < 연령별(5세 계급) 및 성별 인구 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 39, 'page_label': '40'}
# Split 33:------------------------------------
# page_content='27
# 3) 인구이동 및 전출․전입
# v 2018년 말 기준 오산시의 전입인구는 38,577인, 전출인구는 33,151인으로 나타남
# v 최근 10년간 인구의 전입·전출률을 비교해 보면 2009년 전입·전출률이 각각
# 23.8%, 19.1%였으나 2018년 전입·전출률은 23.8%, 20.5%로 전입률은 유사하나
# 전출률은 높아졌으며 2018년까지는 전입인구가 전출인구보다 많은 것으로 나타났지만
# 2015년에는 전출인구가 많은 것으로 나타남
# (단위 : 인)
# 구 분 총 이동 시군내
# 이 동
# 시군간 이동(도내) 시도간 이동 순이동전 입 전 출 전 입 전 출 전 입 전 출
# 2009 38,553 30,998 9,745 17,755 13,395 11,053 7,858 7,555
# 2010 52,285 32,405 11,924 28,499 12,461 11,862 8,020 19,880
# 2011 41,302 32,561 11,160 19,393 12,824 10,749 8,577 8,741
# 2012 33,373 29,539 8,625 14,546 12,505 10,202 8,409 3,834
# 2013 33,296 30,280 10,013 14,496 12,339 8,787 7,928 3,016
# 2014 30,527 29,673 9,346 12,627 12,451 8,554 7,876 854
# 2015 28,913 32,629 8,165 12,216 16,920 8,532 7,544 -3,716
# 2016 27,623 27,507 7,391 11,697 12,769 8,535 7,347 116
# 2017 32,136 28,682 9,535 13,809 12,209 8,792 6,938 3,454
# 2018 38,577 33,151 11,695 17,353 14,492 9,529 6,964 5,426
# 자료 : 오산시 통계연보, 2019
# 주 : 주민등록전출,입 신고에 의한 자료이며 시도내 이동은 전입인구 기준, 국외이동은 제외
# < 인구이동 >
# 4) 인구밀도' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 40, 'page_label': '41'}
# Split 34:------------------------------------
# page_content='자료 : 오산시 통계연보, 2019
# 주 : 주민등록전출,입 신고에 의한 자료이며 시도내 이동은 전입인구 기준, 국외이동은 제외
# < 인구이동 >
# 4) 인구밀도
# v 지난 10년간 오산시의 면적은 거의 변화가 없는 반면 인구는 1.4배의 증가를 보여
# 오산시의 인구밀도도 2009년 3,824인/㎢에서 2018년 5,471인/㎢로 큰 폭의
# 상승을 보임
# 구 분 면적(㎢) 인구(인) 인구밀도(인/㎢)
# 2009 42.77 163,498         3,824
# 2010 42.77 186,382         4,358
# 2011 42.77 198,714         4,646
# 2012 42.74 205,900         4,818
# 2013 42.73 211,559         4,951
# 2014 42.73 216,230         5,060
# 2015 42.73 216,524         5,067
# 2016 42.73 219,294         5,132
# 2017 42.73 225,309         5,273
# 2018 42.72 233,730         5,471
# 자료 : 오산시 통계연보, 2019
# < 인구밀도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 40, 'page_label': '41'}
# Split 35:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 28
# 3. 토지이용 현황
# 가. 지목별 현황
# v 지목별로는 임야가 전체의 24.4%인 10,409천㎡를 차지하고 있어 가장 큰 비율을 보이고
# 있으며 그 뒤로 대지가 19.2%인 8,215천㎡, 답이 13.0%인 5,539천㎡, 도로가
# 12.4%인 5,291천㎡, 전이 8.4%인 3,604㎡의 면적을 차지하는 것으로 나타남
# v 2010년 이후 토지이용변화를 살펴보면 전, 답, 임야 등의 면적은 감소하였으나
# 대지, 공장용지, 도로, 공원 등의 면적은 증가하는 추세를 보임
# (단위 : 천㎡)
# 구 분 합 계 전 답 과수원 목장용지 임 야 대 지
# 2010 42,770 5,327 8,412 243 112 13,326 5,692
# 2011 42,770 4,803 7,382 235 108 12,696 5,902
# 2012 42,737 4,151 6,778 235 104 11,676 6,873
# 2013 42,732 3,895 6,371 218 101 11,416 7,298
# 2014 42,734 3,844 6,137 224 101 11,139 7,311
# 2015 42,731 3,816 6,083 220 101 11,034 7,383
# 2016 42,727 3,813 6,000 215 110 10,978 7,469
# 2017 42,726 3,760 5,849 203 99 10,900 7,668
# 2018 42,722 3,724 5,713 202 99 10,662 7,908
# 2019 42,707 3,604 5,539 192 97 10,409 8,215
# 오산동 2,182 72 150 7 2 12 813
# 부산동 2,379 265 364 6 - 655 476
# 원 동 3,834 255 398 - - 915 1,135
# 궐 동 2,130 195 312 5- 493 574
# 청학동 1,105 54 151 - - 279 92
# 가장동 2,044 111 93 -1 449 154
# 금암동 2,086 63 73 - - 378 521' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 41, 'page_label': '42'}
# Split 36:------------------------------------
# page_content='청학동 1,105 54 151 - - 279 92
# 가장동 2,044 111 93 -1 449 154
# 금암동 2,086 63 73 - - 378 521
# 수청동 1,603 67 31 - - 135 508
# 은계동 545 19 7- - 122 179
# 내삼미동 2,488 234 232 11 - 656 514
# 외삼미동 2,424 154 386 1 2 432 596
# 양산동 3,694 351 535 - 3 1,776 337
# 세교동 2,306 192 322 - 3 247 591
# 지곶동 3,458 349 419 9 15 1,615 298
# 서랑동 1,856 188 169 - 26 800 71
# 서 동 2,050 306 473 1 25 668 204
# 벌음동 931 303 198 22 2 172 81
# 두곡동 706 94 239 -3 215 68
# 탑 동 631 65 209 - 14 109 63
# 누읍동 1,277 75 197 1 1 42 169
# 가수동 967 76 251 - - 159 149
# 고현동 433 39 42 20 - 19 143
# 청호동 442 16 141 4 - 4 178
# 갈곶동 1,136 61 147 105 - 57 301
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 41, 'page_label': '42'}
# Split 37:------------------------------------
# page_content='29
# (단위 : 천㎡)
# 구 분 공장용지 학교용지 주차장 주유소용지 창고용지 도로 철도용지
# 2010 1,920 683 58 57 201 2,966 315
# 2011 1,880 707 71 60 276 4,324 547
# 2012 1,878 824 117 60 277 4,783 547
# 2013 1,842 862 148 66 328 4,984 542
# 2014 2,226 862 161 64 337 5,101 547
# 2015 2,285 862 167 67 338 5,122 546
# 2016 2,293 862 169 66 338 5,133 546
# 2017 2,293 876 167 73 339 5,160 545
# 2018 2,305 890 183 74 351 5,224 545
# 2019 2,409 894 188 76 355 5,291 545
# 오산동 127 61 11 6 62 333 99
# 부산동 27 41 4 4 93 290 -
# 원 동 138 118 14 8 44 593 -
# 궐 동 71 24 10 -8 274 36
# 청학동 122 235 - 1 - 77 6
# 가장동 733 - 8 1 14 224 -
# 금암동 - 70 6 - - 345 -
# 수청동 7 63 35 8 - 297 65
# 은계동 - - - - 3 59 -
# 내삼미동 57 14 10 11 8 448 77
# 외삼미동 119 11 78 22 363 156
# 양산동 18 126 12 1 4 286 -
# 세교동 155 43 36 4 2 321 88
# 지곶동 208 20 4 2 3 326 -
# 서랑동 18 - - - 1 250 -
# 서 동 46 - 9 2 3 91 -
# 벌음동 26 - 3 5 4 58 -
# 두곡동 8 - 16 2 1 43 -
# 탑 동 - - - - 1 84 -
# 누읍동 254 12 1 1 19 153 -
# 가수동 118 28 - 4 - 68 -
# 고현동 43 15 1 1 - 92 -
# 청호동 4 - - 1 1 67 -
# 갈곶동 110 13 1 6 62 149 18
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 42, 'page_label': '43'}
# Split 38:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 30
# (단위 : 천㎡)
# 구 분 하천 제방 구거 유지 양어장 수도용지 공원
# 2010 879 166 743 240 - 11 259
# 2011 877 163 733 237 - 11 308
# 2012 875 161 692 237 - 24 1,099
# 2013 867 161 681 258 - 24 1,240
# 2014 160 867 667 270 - 24 1,298
# 2015 864 160 660 270 - 24 1,298
# 2016 862 164 653 270 - 24 1.303
# 2017 864 163 648 292 - 24 1.324
# 2018 863 163 646 289 - 24 1.369
# 2019 872 163 644 289 - 24 1,417
# 오산동 149 25 30 - - - 21
# 부산동 9 2 44 3 - - 48
# 원 동 - 2 82 21 - - 48
# 궐 동 22 3 25 - - 8 24
# 청학동 37 9 - - - - -
# 가장동 - - 11 16 - 3 152
# 금암동 1 - 9 - - - 423
# 수청동 41 - 4 14 - - 178
# 은계동 93 15 23 - - 1 1
# 내삼미동 2 2 16 8 - - 130
# 외삼미동 1 3 12 1 - - 57
# 양산동 108 22 64 1 - - 33
# 세교동 2 - 38 6 - 12 189
# 지곶동 1 1 71 17 - - 64
# 서랑동 84 23 59 130 - - -
# 서 동 18 6 49 50 - - -
# 벌음동 11 1 20 - - - -
# 두곡동 3 - 9 - - - -
# 탑 동 29 - 14 18 - - -
# 누읍동 177 28 19 4 - - 14
# 가수동 53 20 7 - - - 2
# 고현동 - - 3 - - - 11
# 청호동 1 - 13 - - - 9
# 갈곶동 30 1 22 - - - 13
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 43, 'page_label': '44'}
# Split 39:------------------------------------
# page_content='31
# (단위 : 천㎡)
# 구 분 체육용지 유원지 종교용지 사적지 묘 지 잡종지 미복구
# 2010 135 - 100 - 145 780 -
# 2011 132 305 100 - 142 771 -
# 2012 132 305 108 - 124 766 -
# 2013 135 305 113 - 120 766 -
# 2014 126 305 117 - 118 728 -
# 2015 126 305 118 - 118 764 -
# 2016 126 305 120 - 118 795 -
# 2017 126 305 125 - 118 796 -
# 2018 126 305 129 - 118 801 -
# 2019 129 305 133 - 117 800 -
# 오산동 70 - 8 - - 124 -
# 부산동 17 - 1 - 1 29 -
# 원 동 1 - 13 - - 49 -
# 궐 동 - - 16 - 2 28 -
# 청학동 - - 12 - - 30 -
# 가장동 - - 2 - 20 52 -
# 금암동 - 171 3 - 23 - -
# 수청동 3 134 5 - - 8 -
# 은계동 7 - 5 - - 11 -
# 내삼미동 - - 5 - 7 46 -
# 외삼미동 23 - 14 - 7 49 -
# 양산동 - - 3 - - 14 -
# 세교동 8 - 7 - 9 31 -
# 지곶동 - - 5 - 19 12 -
# 서랑동 - - - - - 37 -
# 서 동 - - 3 - 2 94 -
# 벌음동 - - 5 - 6 14 -
# 두곡동 - - - - - 5 -
# 탑 동 - - 1 - 21 3 -
# 누읍동 - - 2 - - 108 -
# 가수동 - - - - - 32 -
# 고현동 - - - - - 4 -
# 청호동 - - - - - 3 -
# 갈곶동 - - 23 - - 17 -
# 자료 : 오산시 내부자료, 2019년 기준
# < 지목별 면적 – 계속 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 44, 'page_label': '45'}
# Split 40:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 32
# < 지목별 토지이용 현황 >
#                    자료 : 오산시 자연재해저감종합계획, 2019. 12' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 45, 'page_label': '46'}
# Split 41:------------------------------------
# page_content='33
# 나. 용도지역·지구 현황
# v 오산시는 전제면적 42.75㎢ 1) 중 28.23㎢(66.0%)가 녹지지역으로 지정되어 있어
# 가장 큰 비중을 차지하고 있으며, 주거지역이 11.07㎢(25.9%), 공업지역이 2.37㎢
# (5.5%), 상업지역이 1.08㎢(2.5%)를 차지하고 있음
# v 오산시의 주거지역은 넓어지고 있으나 녹지지역은 점차 감소하고 공업지역과 상업
# 지역은 거의 변화가 없음
# v 용도지구 현황을 살펴보면 오산시는 현재 고도지구가 0.56㎢, 자연취락지구가 0.69
# ㎢, 특정용도제한지구가 0.12㎢ 지정되어 있음
# (단위 : ㎢)
# 구 분
# 계 획
# 구 역
# 면 적
# 용  도  지  역
# 합 계
# 주  거  지  역
# 소 계
# 전용주거지역 일반주거지역
# 준주거
# 1종전용 2종전용 1종주거 2종주거 3종주거
# 2018 42.75 42.75 11.07 0.15 - 3.08 3.58 3.25 1.01
# 자료 : 오산시 통계연보, 2019
# < 용도지역별 면적 >
# (단위 : ㎢)
# 구 분
# 용  도  지  역
# 상 업 지 역 공 업 지 역 녹 지 지 역
# 미
# 지정소계 중심
# 상업
# 일반
# 상업
# 근린
# 상업
# 유통
# 산업
# 소계 전용
# 공업
# 일반
# 공업
# 준
# 공업 소계 보전
# 녹지
# 자연
# 녹지
# 생산
# 녹지
# 2018 1.08 - 1.03 0.05 - 2.37 - 2.30 0.07 28.23 4.28 20.76 3.19 -
# 자료 : 오산시 통계연보, 2019
# < 용도지역별 면적 – 계속 >
# (단위 : ㎢)
# 구 분 합 계 고도지구 특정용도
# 제한지구
# 취 락 지 구
# 소 계 자 연 집 단
# 2018 1.37 0.56 0.12 0.69 0.69 -
# 자료 : 오산시 통계연보, 2019
# < 용도지구별 면적 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 46, 'page_label': '47'}
# Split 42:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 34
#
# < 용도지역 현황도 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 47, 'page_label': '48'}
# Split 43:------------------------------------
# page_content='35
# 4. 도시생활 현황
# 가. 주택
# 1) 유형별 주택현황
# v 2018년 말 기준 오산시의 주택수는 총 94,402호이며, 이 중 단독주택 24,778호,
# 아파트 61,907호, 연립주택 2,140호, 다세대주택 5,577호로 나타남
# v 주택 수는 전체적으로 증가하는 추세임.
# (단위 : 호수)
# 구 분 합 계 단 독 주 택 아파트 연립주택 다세대주택 비거주용 건물내
# 주택다가구주택
# 2014 76,753 20,288 17,151 51,182 1,941 3,342 -
# 2015 78,848 21,366 18,152 51,405 2,013 4,064 -
# 2016 80,798 22,660 19,306 51,447 2,038 4,653 -
# 2017 87,149 23,860 20,435 55,993 2,086 5,210 -
# 2018 94,402 24,778 21,268 61,907 2,140 5,577 -
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 국토교통부 추계자료로 작성
#      2) 국토해양부 새로운 산정방식 적용, 다가구 단독주택 산정방식이 변경(동→호)
#      3) 2013년 서식변경(비거주용 건물내주택 항목 삭제)
#      4) 단독주택은 영업겸용단독 및 비거주용건물내 주택을 포함
# < 유형별 주택 현황 >
# 2) 규모별 주택현황
# (단위 : 호수)
# 구 분 합 계 단독주택 아파트 연립주택 다세대주택 비거주용
# 건물내
# 2018년 74,893 5,095 60,089 1,562 7,602 545
# 20㎡이하 2,517 21 590 - 1,892 14
# 20~40㎡ 8,632 133 5,346 59 3,072 22
# 40~60㎡ 25,076 390 21,511 1,089 2,027 59
# 60~85㎡ 27,396 844 25,499 387 580 86
# 85~100㎡ 1,700 441 1,170 - 25 64
# 100~130㎡ 5,729 528 5,054 27 - 120
# 130~165㎡ 1,337 590 659 -6 82' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 48, 'page_label': '49'}
# Split 44:------------------------------------
# page_content='85~100㎡ 1,700 441 1,170 - 25 64
# 100~130㎡ 5,729 528 5,054 27 - 120
# 130~165㎡ 1,337 590 659 -6 82
# 165~230㎡ 779 463 260 - - 56
# 230㎡초과 1,727 1,685 - - - 42
# 자료 : 오산시 통계연보, 2019
# 주 : 2007년 계량단위  표준화 방침에 의거 평 → ㎡로 환산표기(㎡ * 0.3025=평)
# < 규모별 주택 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 48, 'page_label': '49'}
# Split 45:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 36
# 3) 무주택가구
# v 2018년 통계청 주택소유통계 기준으로 오산시의 총가구수는 83,469가구이며, 주택
# 소유가구수는 42,126가구, 무주택가구수는 41,343가구로 조사됨
# (단위 : 가구)
# 구 분 총가구(일반가구) 주택소유 가구 무주택 가구
# 전국 19,979,188 11,233,906 8,745,282
# 경기도 4,751,497 2,642,084 2,109,413
# 오산시 83,469 42,126 41,343
# 자료 : 통계청 주택소유통계, 2018
# 주 :  1) 2018년 기준
#      2) 일반가구 - 가족으로 이루어진 가구, 가족과 5인이하의 남남이 함께 사는 가구, 1인가구, 가족이 아닌
# 남남끼리 사는 5인 이하의 가구
# < 주택소유 및 무주택 가구수현황 >
# 4) 주택보급률
# v 2018년말 기준 오산시의 주택보급률은 102.6%로 나타남
# v 최근 5년간 주택보급률을 살펴보면, 2014년 92.4%를 보인 이후 점차 증가 추세를
# 보임
# (단위 : 세대, 호수, %)
# 구 분 가구수 주택수 보급률
# 2014 83,096 76,753 92.4
# 2015 82,980 78,848 95.0
# 2016 84,565 80,798 95.6
# 2017 87,498 87,149 99.6
# 2018 97,497 94,402 102.6
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 일반가구를 대상으로 집계(비혈연가구, 1인가구 포함)
#      단, 집단가구(6인이상 비혈연가구, 기숙사, 사회시설 등) 및 외국인 가구는 제외
#      참고사항 : 국토해양부 새로운 산정방식 적용, 다가구 단독주택 산정방식이 변경(동 →호), 2005년부터~
# 게재
#      자료 : 통계청「인구주택총조사보고서」, 국토해양부 추계자료(기타년도)
# < 주택 보급률 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 49, 'page_label': '50'}
# Split 46:------------------------------------
# page_content='37
# 나. 공원·녹지
# 1) 공원
# 가) 공원현황
# v 2016년 12월 기준으로 오산시는 113개소의 공원이 도시계획시설로 결정되었으며
# 이 중 소공원은 13개소, 어린이공원 55개소, 근린공원 25개소, 주제공원 20개소 등
# 총면적 3.19㎢임
# v 2020도시기본계획상 공원 총면적이 4.06㎢로 계획되었으나, 2016년 기준 오산 도
# 시관리계획 결정(변경)을 반영하여 공원면적이 3.19㎢로 감소됨
# v 오산시행정구역 42.71㎢ 중 공원이 도시계획시설로 결정되어 있는 면적은 7.5%를
# 차지함
# v 2016년 오산시 인구(216,524명)를 기준으로 1인당 공원면적 기준은 14.75㎡이나
# 향후 도시기본계획 완공시점인 2020년 기준 302,000인 일 때 1인당 공원면적은
# 감소할 것으로 예상됨
# (단위 : 개소, ㎢)
# 구 분
# 2020도시기본계획(변경) 2016년 공원지정현황
# 개소 면적 개소 면적
# 총 계 111 4.06 113 3.19
# 소공원 9 0.02 13 0.03
# 어린이공원 50 0.14 55 0.15
# 근린공원 38 2.16 25 1.42
# 주제공원 13 1.09 20 1.59
# 중앙공원 1 0.65 - -
# 인구 302,000인 216,524인
# 1인당
# 공원면적(㎡) 13.44㎡ 14.75㎡
# 자료 : 2020년 오산 공원녹지 기본계획(변경), 도시공원 통계(2018.12)
# 주 : 2016년 인구(외국인은 행정안전부 2016년 기준 인구)
# < 공원지정현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 50, 'page_label': '51'}
# Split 47:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 38
# 나) 공원조성현황
# v 2016년 기준으로 오산시는 113개소의 공원이 도시계획시설로 결정되었으며 이중
# 소공원은 13개소, 어린이공원 55개소, 근린공원 25개소, 주제공원 20개소 등 총면적
# 3,193,151㎡임
# v 1인당 공원면적은 도시공원 전체면적 기준 14.75㎡/인으로 「도시공원 및 녹지 등에
# 관한 법률」상 도시지역 안의 도시공원 확보기준 면적 6㎡/인을 상회함
# v 2020오산도시관리계획(재정비) 결정사항을 반영하여 2020도시기본계획상 총면적
# 4,056,979㎡에서 3,193,151㎡로 감소함
# v 또한, 결정된 도시공원 면적의 64.9%(2,071,147㎡)가 조성되어, 조성된 도시공원
# 기준 1인당 공원면적은 9.57㎡/인으로 나타남
# - 도시기본계획 수립 시 고려하지 않는 소공원과 어린이공원 제외 시 결정 공원 기준
# 1인당 공원면적은 13.89㎡/인이며, 조성된 공원 기준 8.71㎡/인임
# (단위 : ㎡, %)
# 규  모
# 결정 공원 조성 공원
# 비  고
# 시설수 면  적 구성비 시설수 면  적 조성률
# 계 113 3,193,151 100.0 106 2,071,147 64.9
# 근린공원 25 1,421,953 44.5 21 1,171,844 82.4
# 어린이공원 55 152,885 4.8 55 152,885 100.0
# 소공원 13 33,084 1.0 13 33,084 100.0
# 역사공원 5 1,095,976 34.3 4 325,506 29.7
# 문화공원 3 251,080 7.9 2 161,865 64.5
# 수변공원 9 166,490 5.2 9 166,490 100.0
# 체육공원 3 71,683 2.3 2 59,473 83.0
# 1인당
# 공원면적
# (216,524인)
# 14.75㎡/인 9.57㎡/인 도 시 공 원  전 체
# 13.89㎡/인 8.71㎡/인 소 공 원･어 린 이
# 공 원  제 외
# 자료 : 2020 오산도시관리계획 보고서(2016)
# < 공원지정 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 51, 'page_label': '52'}
# Split 48:------------------------------------
# page_content='39
# 2) 녹지
# 가) 녹지현황
# v 오산시의 녹지현황은 완충녹지 190개소 850,347㎡, 경관녹지 23개소, 48,822㎡,
# 연결녹지 2개소, 18,620㎡로 도시계획시설이 결정되어 있음
# (단위 : ㎡, %)
# 녹지구분
# 결정 녹지 조성 녹지
# 비  고
# 시설수 면  적 구성비 시설수 면  적 조성률
# 계 215 917,789 100.0 206 655,711 71.4
# 완충녹지 190 850,347 92.7 181 588,269 69.2
# 경관녹지 23 48,822 5.3 23 48,822 100.0
# 연결녹지 2 18,620 2.0 2 18,620 100.0
# 자료 : 2020 오산 도시관리계획 보고서(2016)
# < 녹지지정 현황 >
# 다. 상·하수도
# 1) 상수도
# v 2018년 말 오산시 상수도현황을 보면 급수지역내 인구에 대한 보급률은 100.0%로
# 나타남
# v 1일 급수량은 70,421㎥/일이며 1인1일 급수량은 307.0ℓ의 수준으로 나타남
# v 시설용량은 2018년 기준 ‘오산시 수도정비기본계획(변경), 2018.01‘ 상 133,000㎥/일임
# 구 분 급수 도시 내
# 총인구 급수인구 보급률
# (%)
# 시설용량
# (㎥/일)
# 급수량
# (㎥/일)
# 1일1인당
# 급수량(ℓ)
# 2014 215,819 215,008 99.6 86,000 64,008 298
# 2015 214,909 214,909 100.0 133,000 64,747 301
# 2016 216,699 216,699 100.0 133,000 65,072 300
# 2017 221,865 221,865 100.0 133,000 66,240 299
# 2018 229,520 229,520 100.0 133,000 70,421 307
# 자료 : 오산시 수도정비기본계획(변경), (오산시 고시 제 2018-7호)
# < 상수도 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 52, 'page_label': '53'}
# Split 49:------------------------------------
# page_content='제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 40
# 2) 하수도
# v 2018년 기준 총인구 229,520인이며, 하수처리인구는 225,248인으로 하수도 보급률은
# 98.1%임
# v 하수처리시설로는 현재 오산 제1 하수처리장(76,000㎥/일), 오산 제2 하수처리장
# (64,000㎥/일), 세마하수처리장(8,300㎥/일)이 있음
# 구 분 총인구 하수처리인구 하수처리구역
# 외 인구 보급률(%) 비고
# 2014 215,819 212,930 2,889 98.7
# 2015 214,909 212,471 2,438 98.9
# 2016 216,699 214,287 2,412 98.9
# 2017 221,865 219,388 2,477 98.9
# 2018 229,520 225,248 4,272 98.1
# 자료 : 오산시 통계연보, 2019
# 주 : 1) 2015년 전체서식 변경   2) 총인구(주민등록+외국인)
# < 하수도 현황 >
# 라. 의료․보건․사회복지
# v 오산시에는 2018년 기준 종합병원 3곳, 병원 6곳, 의원 101곳, 특수병원 1곳, 요
# 양병원 5곳, 치과병(의)원 69곳, 한의원 33곳, 보건소 1곳의 의료시설이 있음
# v 오산시에는 한국병원이 가장 큰 규모의 병원으로 나타남
# (단위 : 개소)
# 구 분 합계 종합병원 병원 의원 특수병원요양병원 치과병
# (의)원 한의원 보건소
# 병원수 219 3 6 101 1 5 69 33 1
# 병상수 2,807 682 512 223 464 867 - 18 -
# 자료 : 오산시 통계연보, 2019
# 주1 : 병원 중 군인병원 제외
# 주2 : 특수병원에 정신병원, 결핵병원, 나병원 포함
# 주3 : 요양병원 중 노인전문병원은 제외
# < 의료시설 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 53, 'page_label': '54'}
# Split 50:------------------------------------
# page_content='41
# v 오산시 사회복지시설은 총 439개소로 보육시설이 262개소로 가장 많으며, 노인
# 복지시설 133개소, 아동청소년 복지시설이 18개소, 장애인 복지시설이 15개소,
# 가정 복지시설이 3개소, 기타 복지시설 8개소가 있음
# (단위 : 개소, 인)
# 구 분 계 노인 장애인 아동
# 청소년 보육 가정 기타
# 시설수 439 133 15 18 262 3 8
# 자료 : 오산시 시정기본현황, 2016 / 제3기 지역사회복지계획(2015~2018, 오산시), 2014
# < 사회복지시설 현황 >
# 마. 교육·문화
# ...
# Split 500:------------------------------------
# page_content='444
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
#  재정 및 투자부문
# 1. 재정현황
# 가. 재정운영 여건
# v 세입여건은 신규주택 건설 및 인구증가에 따른 지방세 증가가 예상되며, 국세 증
# 가에 따른 이전재원 증가가 전망됨
# v 세출여건은 시민중심 행복도시 구현을 위한 역량 집중, 복지정책 확대에 따른 지
# 방비 부담 등 큰 폭의 재정수요가 증가될 전망임
# 나. 재정규모
# v 오산시 세입은 9,282억 원, 세출은 5,673억 원이며, 잉여액은 3,609억원임
# v 연평균 증가율은 세입 18.6%, 세출 12.2%로 나타남
# (단위 : 억 원)
# 구분
# 예산현액 세 입(A) 세 출(B) 잉 여(A-B)
# 계 일반 특별 계 일반 특별 계 일반 특별 계 일반 특별
# 2013년 4,396 3,433 963 4,815 3,853 962 3,521 2,969 552 1,294 884 410
# 2014년 4,776 3,876 900 4,908 4,023 885 3,428 3,002 426 1,480 1,021 459
# 2015년 5,597 4,547 1,050 5,785 4,673 1,112 3,965 3,461 504 1,820 1,212 608
# 2016년 6,408 5,221 1,187 6,613 5,324 1,290 4,401 3,873 528 2,212 1,451 761
# 2017년 7,752 6,297 1,455 7,983 6,453 1,530 4,563 3,991 572 3,420 2,461 958
# 2018년 9,020 7,152 1,868 9,282 7,275 2,007 5,674 4,895 779 3,608 2,380 1,228
# 자료 : 오산시 통계연보, 2019
# < 재정규모 추이 >
# 다. 일반회계 세입구조
# v 일반회계 세입은 총 7,275억 원으로 보조금 1,538억 원, 지방세 1,317억 원이며, 연평균
# 증가율 17.8%로 증가한 것으로 조사됨
# (단위 : 백만원)
# 구분 합 계 지방세 세외수입 지방교부세 조정교부금
# (재정보전금) 보조금 지방채 보전수입 등
# 내부거래' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 457, 'page_label': '458'}
# Split 501:------------------------------------
# page_content='증가율 17.8%로 증가한 것으로 조사됨
# (단위 : 백만원)
# 구분 합 계 지방세 세외수입 지방교부세 조정교부금
# (재정보전금) 보조금 지방채 보전수입 등
# 내부거래
# 2013년 385,357  88,349 123,939 53,382 25,631 94,056 - -
# 2014년 402,356 95,960 21,076 58,041 31,122 106,186 - 89,971
# 2015년 467,266 103,642 33,806 67,741 40,926 116,270 - 104,880
# 2016년 532,392 118,261 26,273 83,842 47,831 132,801 - 123,384
# 2017년 645,262 130,034 31,342 104,020 65,574 166,175 - 148,117
# 2018년 727,508 131,721 32,083 90,246 70,446 153,801 - 249,211
# 자료 : 오산시 통계연보, 2019
# < 일반회계 세입구조 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 457, 'page_label': '458'}
# Split 502:------------------------------------
# page_content='445
# 라. 일반회계 세출구조
# v 일반회계 세출은 총 4,895억 원으로 그 중 사회복지와 수송 및 교통이 각각 1,846억 원,
# 736억 원으로 가장 크게 나타남
# (단위 : 백만원)
# 구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 합계 296,936 300,167 346,094 387,294 399,120 489,459
# 일반공공행정 31,229 31,006 37,915 39,953 32,275 38,709
# 공공질서
# 및안전 8,679 7,135 5,724 9,904 7,453 10,997
# 교육 11,788 13,977 13,205 15,698 18,748 26,215
# 문화및관광 19,719 16,623 12,604 17,176 24,415 23,393
# 환경보호 30,135 22,777 28,331 26,750 22,226 43,311
# 사회복지 107,741 117,940 147,710 153,803 151,161 184,577
# 보건 7,778 8,956 10,675 10,635 11,958 12,689
# 농림해양수산 3,827 4,206 3,532 3,666 5,071 5,813
# 산업,중소기업 2,522 1,504 2,063 2,819 4,056 2,862
# 수송및교통 33,261 31,150 36,947 48,749 62,867 73,586
# 국토및
# 지역개발 3,590 5,328 5,582 11,941 11,743 15,112
# 과학기술 - - - - - -
# 예비비 - - - - - -
# 기타 36,667 39,565 41,805 46,201 47,148 52,195
# 자료 : 오산시 통계연보, 2019
# < 일반회계 세출구조 >
# 마. 특별회계 현황
# v 특별회계 규모는 총 1,868억 원으로 공기업특별회계 1,219억 원, 기타특별회계 649억
# 원으로 나타남
# (단위 : 백만원)
# 구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 예 산 96,332  89,988 105,016 118,706 145,531 186,806' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 458, 'page_label': '459'}
# Split 503:------------------------------------
# page_content='구 분 2013년 2014년 2015년 2016년 2017년 2018년
# 예 산 96,332  89,988 105,016 118,706 145,531 186,806
# 세 입 96,188 88,468 111,240 128,952 153,042 200,670
# 세 출 55,224 42,597 50,406 52,819 57,224 77,855
# 자료 : 오산시 통계연보, 2019
# < 특별회계 결산 현황 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 458, 'page_label': '459'}
# Split 504:------------------------------------
# page_content='446
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# 2. 재정계획
# 가. 기본방향
# ■ 국가재정운영계획과의 연계성 확보
# v 국가재정운용계획에서 제시하는 중･장기 중점재원 투자방향, 주요 사업계획을
# 반영하여 국가와 시의 재정적 연계성 확보
# v 국가정책방향 하에서 오산시의 실정과 특성에 부합하는 비전과 정책을 실현할 수
# 있도록 재정운용계획을 수립
# ■ 시정방향과 충실히 연계
# v 교육, 복지, 일자리 등 주민숙원사업, 핵심사업, 계속사업 등을 충실히 반영한 계획 수립
# ■ 자주재원 확충 및 합리적인 재원배분 등의 자구노력 강화
# v 한정된 재원을 효율적으로 활용하기 위하여 합리적으로 재원을 배분하고,
# 채무전액 상환, 복지예산 등 재정수요 증가에 따라 이전재원, 자주재원 확충
# 등의 자구노력 강화
# v 재정투자사업에 대한 사전심사강화로 효율성이 낮은 사업 사전차단
# ■ 지방예산･회계의 투명성 및 효율성 확보
# v 경상적 경비 절약 및 증가 억제를 통한 절감 재원을 투자 사업에 배분
# v 행사･축제예산 및 민간 이전경비에 대한 성과평가를 통하여 사업지원 여부 검토
# 나. 재정여건 전망
# 1) 세입규모추정
# v 오산시의 세입규모는 「오산시 통계연보(2016)」의 추계와 「오산시 중기지방재
# 정계획(2018-2022)」상 세입전망(연평균 1.73%)를 적용하여 목표연도인 2035
# 년 세입규모는 897,411백만원에 이를 것으로 전망됨
# v 각종 개발계획 등에 따른 시너지효과로 인구유입 증가 등 지방세수 확대가 예상
# v 총 재정수입 중 자체재원은 317,780백만원(35.4%), 의존재원은 444,366백만원
# (49.5%)이 될 것으로 예상됨' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 459, 'page_label': '460'}
# Split 505:------------------------------------
# page_content='447
# (단위: 백만원, %)
# 구 분 2018년 2019년 2020년 2021년 2022년 2023년 2024년 2025년 2026년
# 계 671,655684,037667,457691,581718,114730,532743,166756,017769,091
# 자
# 체
# 재
# 원
# 소계 212,307 219,007 227,360 240,553 254,290 258,687 263,161 267,711 272,341
# 지방세 132,921 137,658 142,581 147,687 152,991 155,637 158,329 161,066 163,852
# 세외수입 79,386 81,349 84,779 92,866 101,299 103,050 104,832 106,645 108,489
# 의
# 존
# 재
# 원
# 소계 328,256 351,877 339,180 347,293 355,584 361,733 367,989 374,353 380,826
# 지방교부세 110,348 118,656 124,937 127,306 129,722 131,965 134,247 136,569 138,930
# 조정교부금 60,287 61,493 62,723 63,977 65,257 66,385 67,534 68,701 69,889
# 국고보조금 100,473 108,880 109,760 111,836 114,886 116,873 118,894 120,950 123,042
# 지특보조금 8,387 9,073 1,303 2,738 3,263 3,320 3,377 3,436 3,495
# 기금보조금 7,988 10,834 789 794 800 814 828 842 857
# 도비보조금 40,773 42,941 39,668 40,642 41,656 42,376 43,109 43,855 44,613
# 보전수입 등 131,092 113,153 100,917 103,735 108,240 110,112 112,016 113,953 115,924
# 자료 : 2018~2022 오산시 중기지방재정계획
# < 세입추정 >' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 506:------------------------------------
# page_content='자료 : 2018~2022 오산시 중기지방재정계획
# < 세입추정 >
# 구 분 2027년 2028년 2029년 2030년 2031년 2032년 2033년 2034년 2035년 구성비
# 계 782,391795,920809,684823,686837,930852,420867,160882,156897,411 100.0
# 자
# 체
# 재
# 원
# 소계 277,051 281,842 286,716 291,674 296,717 301,849 307,068 312,378 317,780 35.4
# 지방세 166,685 169,568 172,500 175,483 178,517 181,605 184,745 187,940 191,190 21.3
# 세외수입 110,366 112,274 114,216 116,191 118,200 120,244 122,323 124,438 126,590 14.1
# 의
# 존
# 재
# 원
# 소계
# 387,412 394,111 400,926 407,859 414,913 422,087 429,387 436,812 444,366 49.5
# 지방교부세 141,333 143,777 146,263 148,793 151,366 153,983 156,646 159,355 162,111 18.0
# 조정교부금 71,098 72,327 73,578 74,850 76,145 77,462 78,801 80,164 81,550 9.1
# 국고보조금 125,170 127,334 129,536 131,776 134,055 136,373 138,731 141,130 143,571 16.0
# 지특보조금 3,555 3,617 3,679 3,743 3,808 3,873 3,941 4,009 4,078 0.5
# 기금보조금 871 887 902 917 933 949 966 982 999 0.1
# 도비보조금 45,385 46,169 46,968 47,780 48,606 49,447 50,302 51,172 52,057 5.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 507:------------------------------------
# page_content='도비보조금 45,385 46,169 46,968 47,780 48,606 49,447 50,302 51,172 52,057 5.8
# 보전수입 등 117,928 119,967 122,042 124,153 126,230 128,484 130,705 132,966 135,265 15.1
# 자료 : 2018~2022 오산시 중기지방재정계획
# (표 계속)
# 2) 세출규모추정
# v 목표연도의 일반회계 세출규모는 기존 분야별 투자 수요의 개략적 비율을 적용
# 하되, 각종 개발사업 등을 고려하여 추정
# v 오산시의 세출규모는 「오산시 중기지방재정계획(2018-2022)」상 세출전망(연평균
# 1.73%)를 적용하여 2035년 세출규모는 897,411백만원에 이를 것으로 전망됨' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 460, 'page_label': '461'}
# Split 508:------------------------------------
# page_content='448
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# v 일반공공행정, 공공질서 및 안전, 교육에 대한 투자수요는 지속적으로 감소될
# 것으로 전망됨
# (단위: 백만원, %)
# 구 분 2018년 2019년 2020년 2021년 2022년 2023년 2024년 2025년 2026년
# 계 671,655684,036667,456691,582718,115730,534743,168756,017769,091
# 일반공공행정 62,369 69,722 61,475 51,077 45,116 45,896 46,690 47,497 48,319
# 공공질서 및 안전 20,302 28,470 19,890 15,947 16,397 16,680 16,969 17,262 17,561
# 교육 26,905 22,725 25,835 29,783 22,907 23,303 23,706 24,116 24,533
# 문화 및 관광 26,821 34,613 22,329 28,449 34,339 34,933 35,537 36,151 36,776
# 환경보호 102,219 96,338 101,430 109,618 117,567 119,600 121,669 123,773 125,913
# 사회복지 190,842 193,502 201,778 206,309 203,586 207,107 210,688 214,332 218,038
# 보건 14,845 15,011 15,209 15,444 15,685 15,957 16,233 16,513 16,799
# 농림해양수산 5,106 5,150 5,257 5,429 5,525 5,621 5,718 5,817 5,917
# 산업·중소기업 2,278 2,068 2,229 2,485 2,505 2,548 2,592 2,637 2,682
# 수송 및 교통 98,160 88,372 73,539 78,510 87,540 89,054 90,594 92,160 93,754
# 국토 및 지역개발 24,455 28,056 11,782 12,466 13,390 13,621 13,857 14,096 14,340' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 509:------------------------------------
# page_content='국토 및 지역개발 24,455 28,056 11,782 12,466 13,390 13,621 13,857 14,096 14,340
# 예비비 40,664 40,831 64,053 69,210 83,209 84,648 86,112 87,601 89,116
# 기타 56,689 59,178 62,650 66,855 70,349 71,566 72,803 74,062 75,343
# 자료 : 2018~2022 오산시 중기지방재정계획
# < 세출추정 >
# 구 분 2027년 2028년 2029년 2030년 2031년 2032년 2033년 2034년 2035년 구성비
# 계 782,389795,918809,684823,685837,930852,421867,162882,155897,413100.0
# 일반공공행정 49,154 50,004 50,869 51,749 52,644 53,554 54,480 55,422 56,381 6.3
# 공공질서 및 안전17,864 18,173 18,488 18,807 19,133 19,463 19,800 20,142 20,491 2.3
# 교육 24,957 25,388 25,827 26,274 26,728 27,191 27,661 28,139 28,626 3.2
# 문화 및 관광 37,412 38,059 38,717 39,387 40,068 40,761 41,466 42,183 42,912 4.8
# 환경보호 128,090 130,305 132,559 134,851 137,183 139,555 141,969 144,424 146,921 16.3
# 사회복지 221,808 225,644 229,546 233,516 237,554 241,662 245,841 250,092 254,417 28.3
# 보건 17,089 17,385 17,685 17,991 18,302 18,619 18,941 19,268 19,602 2.2
# 농림해양수산 6,020 6,124 6,230 6,337 6,447 6,559 6,672 6,787 6,905 0.8' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 510:------------------------------------
# page_content='농림해양수산 6,020 6,124 6,230 6,337 6,447 6,559 6,672 6,787 6,905 0.8
# 산업·중소기업 2,729 2,776 2,824 2,873 2,922 2,973 3,024 3,077 3,130 0.3
# 수송 및 교통 95,375 97,024 98,702 100,409 102,145 103,912 105,709 107,537 109,396 12.2
# 국토및지역개발 14,588 14,840 15,097 15,358 15,624 15,894 16,169 16,448 16,733 1.9
# 예비비 90,657 92,225 93,820 95,442 97,093 98,772 100,480 102,217 103,985 11.6
# 기타 76,646 77,971 79,320 80,691 82,087 83,506 84,950 86,419 87,914 9.8
# 자료 : 2018~2022 오산시 중기지방재정계획
# (표 계속)' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 461, 'page_label': '462'}
# Split 511:------------------------------------
# page_content='449
# 다. 도시재정 증진을 위한 재원조달 방안
# 1) 민간참여를 유도하여 시의 재정 보완
# v 자치단체의 재정과 국고보조만으로 시민복지를 위한 도시기반시설 투자가 어려우
# 므로 민간부문을 적극 활용하여 지역개발의 재원수요 절감
# v 개발사업에 따른 이익을 합리적·적극적으로 환수하여 재원조달을 제고하고, 민간
# 개발사업 시 인센티브 제공을 통해 세수의 적극적 유치
# v 관(官)과 민(民)이 특정사업에 소요되는 비용을 공동 분담하여 관의 행정력과 민의
# 창의력으로 투자효과를 극대화하는 제3섹터 활성화
# 2) 세외수입의 발굴
# v 상하수도, 대중교통, 병원, 폐기물처리 등 일반행정방식에 의해 운영되고 있는 단
# 위기업적 성격의 사업을 수익자 부담원칙에 의한 독립채산 경영방식으로 전환
# v 지역 내 관광자원의 사업화를 통해 세수입 증대
# 3) 유사·중복사업의 통·폐합
# v 지방재정의 책임성을 확보하고 건전한 운용을 위하여 부서·유관기관간 협의를 통해
# 유사·중복사업은 통·폐합하는 등의 방법 강구
# v 사업 및 집행이 확정된 사업들을 검토하여 향후 투자가 중단되지 않고 사업이
# 마무리되도록 유도
# 4) 재정구조 개편을 통한 자주재원 확충
# v 지방세수 확충을 위해 지방세원(지방세, 세외수입) 발굴 연구, 국세·지방세 개편을
# 위한 중·장기 실행계획 수립 및 추진
# v 공무원 및 민간전문가로 구성된 체납징수 총괄반 구성, 체납징수 공무원 사법권한
# 강화, 국세 및 지방세 관리프로그램간 연계 추진 등 체납 징수 총괄(지방세, 세외
# 수입) 전담반 운영
# v 장기적 채무관리계획(일반채무, 우발채무 등) 수립 및 중장기 투자 계획과 연계한
# 지방채 발행 등 지방채·통합관리기금 투자자금 확충
# v 재정사업들의 정기 및 수시점검을 통한 예산낭비 방지를 위해 공무원 및 민간
# 전문가로 구성된 예산낭비방지센터 운영' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 462, 'page_label': '463'}
# Split 512:------------------------------------
# page_content='450
# 제3장 부문별 계획
# Ⅹ. 계획의 실행
# 3. 실천전략
# 가. 합리적인 세원관리
# v 재산세제는 과세표 현실화를 감안 과세시가표준액을 현실과 일치하도록 조정
# v 국고보조금 및 도비보조금의 확대를 위하여 오산시 정책을 국가정책에 맞춰 상호
# 보완
# 나. 민간자본의 적극유치를 통한 재정 보완
# v 도로·교량사업, 주택지개발사업, 산업단지개발사업, 도시재생활성화사업, 관광지·
# 유원지 개발사업 등 공익성과 수익성을 동시에 갖고 사업에 대한 민간자본 참여
# 적극 유도
# v 민간투자법에 의한 사회기반시설(도로, 철도, 수자원, 정보통신, 에너지, 환경·문
# 화·관광·체육, 교육, 주택시설 등)에 대한 민간투자 적극 유치
# 다. 시민참여 예산제 운영
# v 홍보강화, 예산학교 운영 등을 통해 행정의 일방적 주도가 아닌 시민과의 긍정적
# 협력관계 형성
# v 자체적인 심의기준을 통한 우선순위 사업 선정과 사업 검토로 자체역량 강화
# v 예산 제안의 다양화 및 참여계층 확대(청소년, 여성 참여 확대)
# 라. 투자방식의 변화 유도
# v 공공서비스에 대한 가격보조를 지양하고 지원이 필요한 계층에 대해서는 직접지원
# 방식으로 전환
# v 사회적 일자리 지원을 통하여 고령화에 따른 복지지출의 과도한 증가는 방지하고
# 근로연계복지로의 체계로 전환하여 근로친화적인 환경 조성
# 마. 재정운영의 건전성 도모
# v 단계별 투자 우선순위를 합리적으로 선정하여 재정운영을 개선
# v 중기지방재정계획과 예산사전배분제도의 정착으로 재정운영의 책임성과 투명성을
# 제고' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 463, 'page_label': '464'}
# Split 513:------------------------------------
# page_content='451
# 4. 단계별 투자계획
# 가. 투자우선의 원칙
# v 도시미래상과 목표에 부합하며, 지역개발의 파급효과가 큰 사업을 전략사업으로
# 정하여 우선적으로 투자
# v 전략사업의 원활한 시행 및 국비지원 가능성 증대를 위해 정부정책과 부합 및
# 연계성이 큰 사업을 우선적으로 투자
# v 지역주민의 삶의 질 향상과 지역주민의 요구에 부합하는 사업에 투자
# v 오산시의 신･구도심간 불균형을 해소하기 위한 상생발전 및 주변도시와 상생발전
# 할 수 있는 사업에 투자
# v 부정적인 영향을 최소화하고, 긍정적인 시너지효과를 극대화 할 수 있는 사업에 투자
# v 도시공간구조의 효율적 개편과 관련이 큰 사업에 투자
# v 도시규모에 비해 절대적으로 부족한 기반시설사업에 우선적 투자
# < 투자 우선순위 결정을 위한 고려사항 >
# 나. 재원배분 계획
# v 도시기본계획에서 제시되는 정책 및 전략사업에 대한 재원배분계획이 필요한 바,
# 공공성과 수익성의 정도에 따라 공공성과 민간의 역할 설정
# v 민간부문의 참여가 강조될 경우, 공공은 민간참여를 유인할 수 있는 방식을 선택하여
# 재원을 투자
# v 오산시의 세입구조로는 2035년까지 투자해야 할 주요 핵심사업의 재원 확보에 한계가
# 있는 바, 공공과 민간의 역할을 설정하고 민자유치, 국비 및 도비 등의 다각적 재원
# 확충방안을 모색하되, 부족액에 대해서는 기채를 방행하는 방안 강구
# v 재원 확보를 통한 전략사업의 원활한 수행을 도모하고 단계별 대응전략 수립' metadata={'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'page': 464, 'page_label': '465'}

# %%
print(seoul_splits[50].page_content) # 50페이지 
print('----------------------')
print(seoul_splits[51].page_content) # 51페이지
# Out:
# 공  공
# 공연장
# 민  간
# 공연장
# 영  화
# 상영관
# 미술관 화랑 시민
# 회관
# 복지
# 회관
# 청소년
# 회  관
# 문화원 국악원 전 수
# 회 관
# 개소 1 - 2 1 - - - - 1 - -
# 자료 : 오산시 통계연보, 2019
# < 문화공간 >
# ----------------------
# 제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 42
#  상위 및 관련계획 검토
# 1. 제5차 국토종합계획(2020 ~ 2040)
# 가. 계획의 비전
# ■ 현재와 미래 세대 모두를 위한 국토의 백년대계 실현을 지향하며 「모두를 위한
# 국토, 함께 누리는 삶터」를 비전으로 설정
# ■ 모두를 위한 국토
# v 다양한 세대와 계층, 지역이 소외되거나 차별받지 않는 포용국가 기반을 갖추고,
# 좋은 일자리와 안전하고 매력적인 정주환경을 갖춰 글로벌 경쟁력이 있는 지속
# 가능한 국토를 조성
# ■ 함께 누리는 삶터
# v 삶의 질, 건강 등 우리 국민이 중요시하는 가치를 주거공간, 생활공간, 도시
# v 공간 등 다양한 국토공간에서 구현하고, 깨끗하고 품격있는 국토 경관 조성과
# v 산지, 해양, 토지 등 국토자원의 효율적인 이용․관리로 행복한 삶터를 구현
# < 계획의 기조: 비전, 목표, 전략 >

# %%
for i in range(len(seoul_splits) - 1):
    seoul_splits[i].page_content += "\n"+ seoul_splits[i + 1].page_content[:100]

print(seoul_splits[50].page_content)
print('----------------------')
print(seoul_splits[51].page_content)

# 제1절 서울의 변화진단33-노인여가복지시설 역시 확충되고 있으나, 노령화의 속도를 따라잡지 못해 2020년에는 노인 천 명당 2.1개소로 2010년에 비해 0.9개소 감소Ÿ다양한 
# ----------------------
# 제1절 서울의 변화진단33-노인여가복지시설 역시 확충되고 있으나, 노령화의 속도를 따라잡지 못해 2020년에는 노인 천 명당 2.1개소로 2010년에 비해 0.9개소 감소Ÿ다양한 생활서비스 시설의 양적 공급은 긍정적이지만, 지역 수요에 알맞은 생활서비스 시설을 도입하여 질적으로 서비스를 개선할 수 있도록 해야 한다.
# Out:
# 공  공
# 공연장
# 민  간
# 공연장
# 영  화
# 상영관
# 미술관 화랑 시민
# 회관
# 복지
# 회관
# 청소년
# 회  관
# 문화원 국악원 전 수
# 회 관
# 개소 1 - 2 1 - - - - 1 - -
# 자료 : 오산시 통계연보, 2019
# < 문화공간 >
# 제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 42
#  상위 및 관련계획 검토
# 1. 제5차 국토종합계획(2020 ~ 2040)
# 가. 계획의 비전
# ■ 현재와 미래 세대 모두를 위한 국
# ----------------------
# 제1장 계획의 기조
# Ⅱ. 지역의 특성과 현황
# 42
#  상위 및 관련계획 검토
# 1. 제5차 국토종합계획(2020 ~ 2040)
# 가. 계획의 비전
# ■ 현재와 미래 세대 모두를 위한 국토의 백년대계 실현을 지향하며 「모두를 위한
# 국토, 함께 누리는 삶터」를 비전으로 설정
# ■ 모두를 위한 국토
# v 다양한 세대와 계층, 지역이 소외되거나 차별받지 않는 포용국가 기반을 갖추고,
# 좋은 일자리와 안전하고 매력적인 정주환경을 갖춰 글로벌 경쟁력이 있는 지속
# 가능한 국토를 조성
# ■ 함께 누리는 삶터
# v 삶의 질, 건강 등 우리 국민이 중요시하는 가치를 주거공간, 생활공간, 도시
# v 공간 등 다양한 국토공간에서 구현하고, 깨끗하고 품격있는 국토 경관 조성과
# v 산지, 해양, 토지 등 국토자원의 효율적인 이용․관리로 행복한 삶터를 구현
# < 계획의 기조: 비전, 목표, 전략 >
# 43
# 나. 계획의 목표
# ■ 어디서나 살기 좋은 균형국토
# v 국토균형발전 정책에 대한 성과와 체감도를 높이는 한편, 인구 감소와 저성장
# 시대에 체계적으로 대비하여 어디서나 살기좋은

# %%
print(len(all_splits))
all_splits.extend(seoul_splits)
print(len(all_splits))
# Out:
# 513
# 1026

# %%
# OpenAI 연동 및 ChromaDB 설치
# %pip install openai==1.75.0
# %pip install langchain-openai==0.3.19 langchain-chroma==0.2.0
# Out:
# Collecting openai==1.75.0
#   Downloading openai-1.75.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (2.13.3)
# Requirement already satisfied: sniffio in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from openai==1.75.0) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from anyio<5,>=3.5.0->openai==1.75.0) (3.13)
# Requirement already satisfied: certifi in c:\Users\a\LLM\ch09venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.75.0) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\a\LLM\ch09venv\Lib\site-packages (from httpx<1,>=0.23.0->openai==1.75.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.75.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.75.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.75.0) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from pydantic<3,>=1.9.0->openai==1.75.0) (0.4.2)
# Requirement already satisfied: colorama in c:\Users\a\LLM\ch09venv\Lib\site-packages (from tqdm>4->openai==1.75.0) (0.4.6)
# Downloading openai-1.75.0-py3-none-any.whl (646 kB)
#    ---------------------------------------- 0.0/647.0 kB ? eta -:--:--
#    ---------------------------------------- 647.0/647.0 kB 9.0 MB/s  0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 2.34.0
#     Uninstalling openai-2.34.0:
#       Successfully uninstalled openai-2.34.0
# Successfully installed openai-1.75.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 1.2.1 requires openai<3.0.0,>=2.26.0, but you have openai 1.75.0 which is incompatible.
# Collecting langchain-openai==0.3.19
#   Downloading langchain_openai-0.3.19-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-chroma==0.2.0
#   Using cached langchain_chroma-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-core<1.0.0,>=0.3.63 (from langchain-openai==0.3.19)
#   Using cached langchain_core-0.3.84-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from langchain-openai==0.3.19) (1.75.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\Users\a\LLM\ch09venv\Lib\site-packages (from langchain-openai==0.3.19) (0.12.0)
# Collecting chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0 (from langchain-chroma==0.2.0)
#   Using cached chromadb-0.5.23-py3-none-any.whl.metadata (6.8 kB)
# Collecting fastapi<1,>=0.95.2 (from langchain-chroma==0.2.0)
#   Using cached fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting numpy<2.0.0,>=1.26.2 (from langchain-chroma==0.2.0)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\a\LLM\ch09venv\Scripts\python.exe C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35\vendored-meson\meson\meson.py setup C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35 C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35\.mesonpy-zkn996py -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35\.mesonpy-zkn996py\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35
#       Build dir: C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35\.mesonpy-zkn996py
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `cc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `gcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `clang-cl /?` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#       Running `pgcc --version` gave "[WinError 2] 吏\x80\xec젙\xeb맂 \xed뙆\xec씪\xec쓣 李얠쓣 \xec닔 \xec뾾\xec뒿\xeb땲\xeb떎"
#
#       A full log can be found at C:\Users\a\AppData\Local\Temp\pip-install-921p_24h\numpy_f433e45ef2844139ae34ebd1fd2dae35\.mesonpy-zkn996py\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from langchain_openai import OpenAIEmbeddings 
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

embedding = OpenAIEmbeddings(model='text-embedding-3-large', api_key=OPENAI_API_KEY)
v = embedding.embed_query("뉴욕의 온실가스 저감 정책은 뭐야?")
print(v)
print(len(v))
# Out:
# [-0.00536346435546875, -0.049530029296875, -0.01250457763671875, 0.00847625732421875, -0.040069580078125, -0.0104217529296875, 0.0063018798828125, 0.025421142578125, -0.049774169921875, -0.0123291015625, -0.0019893646240234375, -0.017822265625, 0.026275634765625, -0.0010824203491210938, 0.00240325927734375, -0.0182342529296875, -0.0389404296875, -0.043182373046875, 0.07275390625, -0.012054443359375, 0.0494384765625, -0.0147857666015625, -0.0191192626953125, 0.0059967041015625, -0.0328369140625, 0.0169830322265625, 0.0250396728515625, 0.02020263671875, -0.004241943359375, 0.037750244140625, 0.035736083984375, 0.03057861328125, 0.0175628662109375, -0.00931549072265625, -0.0178985595703125, 0.01371002197265625, 0.06256103515625, -0.03033447265625, 0.04901123046875, -0.00263214111328125, -0.0274200439453125, 0.0129241943359375, -0.032989501953125, -0.00745391845703125, 0.0195770263671875, -0.0031528472900390625, 0.01071929931640625, -0.03094482421875, -0.0082550048828125, -0.0054779052734375, -0.024871826171875, -0.0088348388671875, -0.0113067626953125, -0.020599365234375, 0.0257720947265625, 0.0069580078125, -0.0169219970703125, 0.00980377197265625, 0.0026988983154296875, -0.021636962890625, 0.031463623046875, 0.013916015625, 0.007488250732421875, -0.02130126953125, 0.000858306884765625, -0.029266357421875, 0.0278778076171875, 0.0237274169921875, -0.006927490234375, 0.01471710205078125, 0.0139007568359375, 0.0175323486328125, -0.01366424560546875, -0.034759521484375, 0.049346923828125, -0.01032257080078125, 0.01070404052734375, -0.0189056396484375, 0.0156402587890625, -0.006015777587890625, 0.01377105712890625, -0.01544189453125, -0.0164794921875, -0.021453857421875, -0.006252288818359375, 0.00882720947265625, -0.0095367431640625, -0.0295562744140625, 0.0198822021484375, -0.0350341796875, 0.05126953125, -0.005596160888671875, -0.0653076171875, -0.0307769775390625, 0.0138092041015625, 0.0330810546875, 0.0258026123046875, -0.00971221923828125, -0.0212249755859375, 0.0157928466796875, -0.0219879150390625, 0.01061248779296875, 0.021453857421875, 0.036773681640625, -0.0151214599609375, 0.026641845703125, -0.0250396728515625, -0.006122589111328125, -0.0193023681640625, 0.06005859375, 0.004642486572265625, -0.00803375244140625, 0.00428009033203125, 0.019012451171875, -0.0207672119140625, -0.022979736328125, -0.003002166748046875, 0.0058746337890625, 0.024749755859375, 0.029296875, 0.014190673828125, -0.0233001708984375, 0.036712646484375, -0.0027866363525390625, -0.01306915283203125, -0.01461029052734375, 0.005401611328125, -0.0277862548828125, 0.011566162109375, -0.0178070068359375, -0.017486572265625, 0.052215576171875, 0.0423583984375, -0.03131103515625, -0.007114410400390625, -0.01263427734375, 0.0694580078125, -0.01209259033203125, -0.0207366943359375, -0.029937744140625, -0.044464111328125, 0.0002415180206298828, 0.006809234619140625, -0.00829315185546875, -0.0562744140625, -0.0204010009765625, 0.006992340087890625, 0.01299285888671875, -0.02288818359375, -0.00649261474609375, 0.0047149658203125, -0.0022449493408203125, 0.01763916015625, -0.0163421630859375, -0.0001399517059326172, -0.0033512115478515625, 0.0012159347534179688, -0.0010776519775390625, 0.01434326171875, 0.007549285888671875, -0.0118560791015625, 0.02099609375, 0.00992584228515625, 0.04742431640625, 0.00396728515625, 0.017578125, -0.0142974853515625, 0.01267242431640625, 0.001918792724609375, 0.0005974769592285156, 0.0008778572082519531, -0.032958984375, 0.00496673583984375, -0.01381683349609375, -0.01224517822265625, 0.0227813720703125, 0.0081024169921875, -0.01070404052734375, 0.040313720703125, 0.0194244384765625, 0.034454345703125, 0.0183563232421875, 0.0015611648559570312, -0.0019407272338867188, -0.02099609375, 0.01078033447265625, 0.0173797607421875, -0.0240020751953125, 0.01715087890625, -0.034210205078125, 0.043914794921875, 0.03863525390625, -0.0135955810546875, -0.00620269775390625, -0.0025424957275390625, 0.0250091552734375, 0.00720977783203125, -0.05084 ...
# 3072

# %%
from langchain_chroma import Chroma
import os

persist_directory = 'C:/Users/a/LLM/ch09/chroma_store'	

# 저장된 크로마 DB가 없다면 새로 만들기
if not os.path.exists(persist_directory):
    print("Creating new Chroma store")
    vectorstore = Chroma.from_documents(
        documents=all_splits,
        embedding=embedding,
        persist_directory=persist_directory
    )

else:
    print("Loading existing Chroma store")
    vectorstore = Chroma(		
        persist_directory=persist_directory, 
        embedding_function=embedding
    )
# Out:
# Creating new Chroma store

# %%
retriever = vectorstore.as_retriever(k=3)
docs = retriever.invoke("오산시 환경 정책에 대해 궁금해")

for d in docs:
    print(d)
    print('------')
# Out:
# page_content='273
# 다. 오산시 환경보전계획(2018~2027)
# v 「환경정책기본법」 제19조 및 「오산 환경기본 조례」 제10조에 근거하여 오산시의
# 지역적 특성을 고려하여 당해 오산시에서 수립･시행하는 법정계획
# < 오산시 환경보전계획 비전 및 목표 >
# 구분 항목 단위 현황
# (2017년 기준)
# 목표연도
# 2022 2027
# 자연환경
# 오산시 생태정보 시스템 구축 - - 구축완료 운영
# 생태통로 조성 개소 2 3 4
# 대기환경
# 미세먼지 농도(PM10) ㎍/㎥ 53 40 40
# 초미세먼지 농도(PM2.5) ㎍/㎥ 29 20 20
# 이산화질소(NO2) ppb 32 30 30
# 수환경 오산천 수질(BOD) - 약간좋음(Ⅱ) 약간좋음(Ⅱ) 약간좋음(Ⅱ)
# 빗물이용시설 개소 0 5 10
# 토양⋅지하수 클린주유소 설치 1) 개소 3 6 9
# 소음⋅진동 소음도 저감 dB(A) 45.1 45 45
# 자원순환
# 재활용률3) % 62 65 68
# 배출원단위
# 3)
# ㎏/인·일 0.61 0.60 0.59
# 환경보건관리 실내공기질 관리 확대
# (법정규모 미만 시설) 개소 85 100 120
# 에너지관리
# (기후변화)
# 신재생에너지 보급사업4) 개소 11 20 30
# 에너지자립마을4) 개소 1 3 15
# 주1) : 환경부(2017) 클린주유소 지정현황
# 주2) : 2017년 1월 말 기준
# 주3) : 생활계 폐기물 기준
# 주4) : 오산시 에너지 자립 실행계획 지표 기준
# < 오산시 환경보전계획 지표설정 >
# 274
# 제3장 부문별 계획
# Ⅳ. 환경의 보전과 관리계획
# 3. 현황 및 문제점
# 가. 국내외 여건분석
# 1) 기후변화 국제공조 강화, 온실가스 감축 부담 증가
# v ‘15. 12월 파리에' metadata={'total_pages': 466, 'page_label': '287', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'page': 286, 'creator': 'pdftk 2.02 - www.pdftk.com', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00'}
# ------
# page_content='287
# 2. 기본방향
# ■ 지역특성을 반영한 세부기준마련
# v 오산시 현황은 국내 및 경기도 기준에 비해 낮은 수치로 나타나 있지만, 친환경
# 도시로서의 이미지 제고를 위한 기준을 마련하여 대기환경 개선
# ■ 강화되고 있는 환경기준의 지속적 달성
# v 체계적인 조사와 관리로 각 지역별 오염 부하량과 각종 배출규제의 근거를 마련하고,
# 오염특성에 적합한 현실적인 대기오염 관리대책 모색
# ■ 장기적인 대기오염물질 배출 저감을 위한 관리 강화
# v 청정연료 및 저유황유 보급 확대 등
# v 대기오염 물질에 대한 개선 및 관리대책 수립
# ■ 환경정보관리시스템의 개발을 통한 대기환경 관리
# v 체계적인 관리시스템을 통해 대기질 정화 및 쾌적한 도시환경 조성
# ■ 맑은 공기 쾌적한 환경보전
# v 대중교통 활성화 및 녹색교통 수단 확대
# v 대기오염에 대한 자정능력 향상을 위한 녹지공간 확충
# ■ 엄격한 기준과 관리시스템을 통한 미세먼지 대책마련
# v WHO권고수준 이하의 기준을 수립한 지속적인 감소대책 마련
# v 예·경보 시스템을 활용한 관리를 통해 실시간 정보제공 및 체계마련
# 3. 실천전략
# 가. 미세먼지 저감대책 수립
# 1) 사업장 및 도로 미세먼지 관리 강화
# v 신규 택지조성 및 재개발 등 대형 개발사업에 따른 건설장비 및 트럭의 통행으로
# 인한 공사현장 및 도로의 비산먼지 효율적인 관리 체계 마련' metadata={'total_pages': 466, 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'page_label': '301', 'page': 300, 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'creator': 'pdftk 2.02 - www.pdftk.com'}
# ------
# page_content='287
# 2. 기본방향
# ■ 지역특성을 반영한 세부기준마련
# v 오산시 현황은 국내 및 경기도 기준에 비해 낮은 수치로 나타나 있지만, 친환경
# 도시로서의 이미지 제고를 위한 기준을 마련하여 대기환경 개선
# ■ 강화되고 있는 환경기준의 지속적 달성
# v 체계적인 조사와 관리로 각 지역별 오염 부하량과 각종 배출규제의 근거를 마련하고,
# 오염특성에 적합한 현실적인 대기오염 관리대책 모색
# ■ 장기적인 대기오염물질 배출 저감을 위한 관리 강화
# v 청정연료 및 저유황유 보급 확대 등
# v 대기오염 물질에 대한 개선 및 관리대책 수립
# ■ 환경정보관리시스템의 개발을 통한 대기환경 관리
# v 체계적인 관리시스템을 통해 대기질 정화 및 쾌적한 도시환경 조성
# ■ 맑은 공기 쾌적한 환경보전
# v 대중교통 활성화 및 녹색교통 수단 확대
# v 대기오염에 대한 자정능력 향상을 위한 녹지공간 확충
# ■ 엄격한 기준과 관리시스템을 통한 미세먼지 대책마련
# v WHO권고수준 이하의 기준을 수립한 지속적인 감소대책 마련
# v 예·경보 시스템을 활용한 관리를 통해 실시간 정보제공 및 체계마련
# 3. 실천전략
# 가. 미세먼지 저감대책 수립
# 1) 사업장 및 도로 미세먼지 관리 강화
# v 신규 택지조성 및 재개발 등 대형 개발사업에 따른 건설장비 및 트럭의 통행으로
# 인한 공사현장 및 도로의 비산먼지 효율적인 관리 체계 마련
# 288
# 제3장 부문별 계획
# Ⅳ. 환경의 보전과 관리계획
# ■ 공사장 비산먼지 저감
# v 관내 대형 건설사업장의 세륜장치에 스프링클러 추가설치로 먼지 저감 강화
# v 방진막, 토사 방진덮' metadata={'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'page': 300, 'total_pages': 466, 'creationdate': '2020-11-19T22:05:21-09:00', 'creator': 'pdftk 2.02 - www.pdftk.com', 'page_label': '301'}
# ------
# page_content='273
# 다. 오산시 환경보전계획(2018~2027)
# v 「환경정책기본법」 제19조 및 「오산 환경기본 조례」 제10조에 근거하여 오산시의
# 지역적 특성을 고려하여 당해 오산시에서 수립･시행하는 법정계획
# < 오산시 환경보전계획 비전 및 목표 >
# 구분 항목 단위 현황
# (2017년 기준)
# 목표연도
# 2022 2027
# 자연환경
# 오산시 생태정보 시스템 구축 - - 구축완료 운영
# 생태통로 조성 개소 2 3 4
# 대기환경
# 미세먼지 농도(PM10) ㎍/㎥ 53 40 40
# 초미세먼지 농도(PM2.5) ㎍/㎥ 29 20 20
# 이산화질소(NO2) ppb 32 30 30
# 수환경 오산천 수질(BOD) - 약간좋음(Ⅱ) 약간좋음(Ⅱ) 약간좋음(Ⅱ)
# 빗물이용시설 개소 0 5 10
# 토양⋅지하수 클린주유소 설치 1) 개소 3 6 9
# 소음⋅진동 소음도 저감 dB(A) 45.1 45 45
# 자원순환
# 재활용률3) % 62 65 68
# 배출원단위
# 3)
# ㎏/인·일 0.61 0.60 0.59
# 환경보건관리 실내공기질 관리 확대
# (법정규모 미만 시설) 개소 85 100 120
# 에너지관리
# (기후변화)
# 신재생에너지 보급사업4) 개소 11 20 30
# 에너지자립마을4) 개소 1 3 15
# 주1) : 환경부(2017) 클린주유소 지정현황
# 주2) : 2017년 1월 말 기준
# 주3) : 생활계 폐기물 기준
# 주4) : 오산시 에너지 자립 실행계획 지표 기준
# < 오산시 환경보전계획 지표설정 >' metadata={'creator': 'pdftk 2.02 - www.pdftk.com', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'moddate': '2020-12-22T16:22:25+09:00', 'page': 286, 'creationdate': '2020-11-19T22:05:21-09:00', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'page_label': '287'}
# ------

# %%
# 사용자가 질문하면 리트리버를 이용하여 관련 내용을 찾고 이를 바탕으로 언어 모델을 사용해 답변을 생성하는 기능 추가
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder 
# ChatPromptTemplate 언어모델에 전달할 프롬프트를 정의하는 템플릿 클래스(역할, 메시지 설정)
# MessagesPlaceholder 사용자 메시지와 같은 동적 데이터를 프롬프트에 삽입하기 위해 사용하는 클래스(여러 메시지 입력 처리용)
# 신형 코드로 변경 from langchain.chains.combine_documents import create_stuff_documents_chain 
# 여러 텍스트를 결합해 답변 생성 체인을 만드는 함수 (기존 프롬프트를 기반으로 언어 모델을 통해 최종 답변 제공)
from langchain_openai import ChatOpenAI 
# chat이라는 객체 생성용 (져럼한 gpt-4o-mini 사용 예정 )

chat = ChatOpenAI(model="gpt-4o-mini") 

# ④ 답변을 생성할 때 사용할 프롬프트 템플릿 생성
question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        ( # ⑤ 시스템에 역할 지정
            "system",
            "사용자의 질문에 대해 아래 context에 기반하여 답변하라.:\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"), # ⑥ 자리자 표시자로 설정 나눈 메시지를 동적으로 삽입함.
        # 이를 통해 사용자가 한 질문을 바탕으로 답변을 생성한다.
    ]
)

# 구형 방식 : document_chain = create_stuff_documents_chain(chat, question_answering_prompt) 
# 최신 방식 체인 (create_stuff_documents_chain 대신)
document_chain = question_answering_prompt | chat
# 검색된 문서 청크와 사용자 질문을 바탕으로 언어 모델을 호출하고 답변을 생성하는 역할을 한다.

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory

chat_history = InMemoryChatMessageHistory()

chat_history.add_user_message("오산시의 온실가스 저감 정책에 대해 알려줘.") 


answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

chat_history.add_ai_message(answer) 

print(answer)
# Out:
# content='오산시는 온실가스 감축을 위한 다양한 정책을 추진하고 있습니다. 주요 내용은 다음과 같습니다:\n\n1. **신재생에너지 보급사업**: 오산시는 신재생에너지의 보급을 확대하고 있으며, 이를 통해 에너지 자립을 추진하고 있습니다. 이는 장기적으로 온실가스 배출을 줄이는 데 기여합니다.\n\n2. **에너지자립마을**: 에너지 자립을 위한 마을 조성을 통해 지역 단위에서 에너지를 자급자족하고, 재생 가능 에너지를 활용하여 온실가스 저감에 기여하고 있습니다.\n\n3. **친환경 교통수단 활성화**: 대중교통을 강화하고 녹색교통 수단을 확대하여 자동차 의존도를 줄이고, 이로 인한 온실가스 배출을 감소시키고자 합니다.\n\n4. **구체적인 대기환경 관리**: 대기오염물질의 배출 저감을 위해 청정 연료 및 저유황유의 보급을 확대하고, 대기오염 물질에 대한 관리 대책을 수립하였습니다.\n\n5. **체계적인 조사 및 관리**: 각 지역의 오염 부하량을 체계적으로 조사하고 이를 기반으로 현실적인 대기오염 관리 대책을 마련하였습니다.\n\n이와 같은 정책들을 통해 오산시는 친환경 도시 이미지 제고와 함께 온실가스 감소를 위한 적극적인 노력을 기울이고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 324, 'prompt_tokens': 2706, 'total_tokens': 3030, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_43b64008fd', 'id': 'chatcmpl-DbzHoE32yFp58MjbLQZzS0I2UENtc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019df5d8-61eb-7320-aa2d-f1f792c7c908-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2706, 'output_tokens': 324, 'total_tokens': 3030, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
for m in chat_history.messages: # 저장된 대화 기록을 출력해 본다.
    print(m)
# Out:
# content='오산시의 온실가스 저감 정책에 대해 알려줘.' additional_kwargs={} response_metadata={}
# content='오산시는 온실가스 감축을 위한 다양한 정책을 추진하고 있습니다. 주요 내용은 다음과 같습니다:\n\n1. **신재생에너지 보급사업**: 오산시는 신재생에너지의 보급을 확대하고 있으며, 이를 통해 에너지 자립을 추진하고 있습니다. 이는 장기적으로 온실가스 배출을 줄이는 데 기여합니다.\n\n2. **에너지자립마을**: 에너지 자립을 위한 마을 조성을 통해 지역 단위에서 에너지를 자급자족하고, 재생 가능 에너지를 활용하여 온실가스 저감에 기여하고 있습니다.\n\n3. **친환경 교통수단 활성화**: 대중교통을 강화하고 녹색교통 수단을 확대하여 자동차 의존도를 줄이고, 이로 인한 온실가스 배출을 감소시키고자 합니다.\n\n4. **구체적인 대기환경 관리**: 대기오염물질의 배출 저감을 위해 청정 연료 및 저유황유의 보급을 확대하고, 대기오염 물질에 대한 관리 대책을 수립하였습니다.\n\n5. **체계적인 조사 및 관리**: 각 지역의 오염 부하량을 체계적으로 조사하고 이를 기반으로 현실적인 대기오염 관리 대책을 마련하였습니다.\n\n이와 같은 정책들을 통해 오산시는 친환경 도시 이미지 제고와 함께 온실가스 감소를 위한 적극적인 노력을 기울이고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 324, 'prompt_tokens': 2706, 'total_tokens': 3030, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_43b64008fd', 'id': 'chatcmpl-DbzHoE32yFp58MjbLQZzS0I2UENtc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019df5d8-61eb-7320-aa2d-f1f792c7c908-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 2706, 'output_tokens': 324, 'total_tokens': 3030, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# 질의 확장 구현하기
# 서울시 온실가스 저감 정책에 관한 대회에 이어서 뉴욕은? 질문시 해결법
# 이를 처리하려면 질문을 문맥에 맞게 확장하여 관련된 청크를 검색하고 답변을 생성해야 한다. -> 질의 확장
from langchain_core.output_parsers import StrOutputParser # 문자열 출력 파서를 불러옵니다.

# %%
query_for_nyc = "도쿄는??"

# query augmentation 
# 기존 대화 내용을 활용해 query_augmentation 수행
query_augmentation_prompt = ChatPromptTemplate.from_messages(
    [
        MessagesPlaceholder(variable_name="messages"), # 기존 대화 내용
        (
            "system",
            "기존의 대화 내용을 활용하여 사용자의 아래 질문의 의도를 파악하여 명료한 한 문장의 질문으로 변환하라. 대명사나 이, 저, 그와 같은 표현을 명확한 명사로 표현하라. :\n\n{query}",
        ),
    ]
)

# %%
query_augmentation_chain = query_augmentation_prompt | chat | StrOutputParser()

# %%
augmented_query = query_augmentation_chain.invoke({
    "messages": chat_history.messages,
    "query": query_for_nyc  
})

print(augmented_query)
# Out:
# 도쿄의 온실가스 저감 정책은 무엇인가요?

# %%
docs = retriever.invoke(augmented_query)

for d in docs:
    print(d)
    print('------')
# Out:
# page_content='279
# 4. 기본방향
# v 온실가스 배출 감축을 위한 시민참여 확대, 녹색교통수단 도입 등 기후변화에
# 대비한 저탄소 녹색도시 조성
# v 신규 개발사업, 도시재생 등에 환경친화적인 개발 유도로 도심지내 녹지공간을
# 확충하고 도시환경을 개선
# v 탄소 흡수원 확충을 위한 공원녹지조성, 탄소 배출억제, 산업구조 개선 및 신재생
# 에너지 확대를 통한 미래지향적 탄소감축 방안제시
# 5. 실천전략
# 가. 온실가스 감축
# 1) 시민참여 확대 및 자발적 감축문화 확산
# v 시민이 기후변화의 심각성을 인식하여 직접 온실가스 감축활동 참여토록 유도
# v 산업부문에 치중해온 온실가스 감축정책을 가정 등 비산업 부문까지 확대
# v 가정･상업시설 등 비산업분야 온실가스 감축을 위해 주부, 직장인 등 각계 각층이
# 참여하는 온실가스 줄이기 실천운동 추진
# 2) 녹색교통수단확대 및 이용 활성화 유도
# v 자전거 이용 활성화로 온실가스 감축을 통한 저탄소녹색 교통문화 정착(지속적인
# 자전거 타기 행사 개최, 자전거도로 확충 등)
# v 경유자동차에서 배출되는 대기오염물질 저감을 위하여 저감장치 부착 및 노후차량
# 조기폐차 사업을 통한 대기질 개선
# v 대기환경을 개선하기 위한 저공해화 사업으로 천연가스자동차 및 저공해경유자동차를
# 보급하여 자동차 배출가스 개선
# 3) 지표설정
# ■ 온실가스 감축목표 설정
# v 오산시 온실가스 인벤토리(2017년 기준, 한국환경공단)을 적용하여 단계별 인구
# 계획에 적용하여 산정
# v 2030 국가온실가스 감축목표 37%를 고려하여 온실가스 저감목표를 30%로 설정
# 하고, 오산시 국가1인당 온실가스 총 배출량을 5.7톤CO2eq/명으로 설정' metadata={'total_pages': 466, 'page_label': '293', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'page': 292, 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'creationdate': '2020-11-19T22:05:21-09:00', 'creator': 'pdftk 2.02 - www.pdftk.com'}
# ------
# page_content='279
# 4. 기본방향
# v 온실가스 배출 감축을 위한 시민참여 확대, 녹색교통수단 도입 등 기후변화에
# 대비한 저탄소 녹색도시 조성
# v 신규 개발사업, 도시재생 등에 환경친화적인 개발 유도로 도심지내 녹지공간을
# 확충하고 도시환경을 개선
# v 탄소 흡수원 확충을 위한 공원녹지조성, 탄소 배출억제, 산업구조 개선 및 신재생
# 에너지 확대를 통한 미래지향적 탄소감축 방안제시
# 5. 실천전략
# 가. 온실가스 감축
# 1) 시민참여 확대 및 자발적 감축문화 확산
# v 시민이 기후변화의 심각성을 인식하여 직접 온실가스 감축활동 참여토록 유도
# v 산업부문에 치중해온 온실가스 감축정책을 가정 등 비산업 부문까지 확대
# v 가정･상업시설 등 비산업분야 온실가스 감축을 위해 주부, 직장인 등 각계 각층이
# 참여하는 온실가스 줄이기 실천운동 추진
# 2) 녹색교통수단확대 및 이용 활성화 유도
# v 자전거 이용 활성화로 온실가스 감축을 통한 저탄소녹색 교통문화 정착(지속적인
# 자전거 타기 행사 개최, 자전거도로 확충 등)
# v 경유자동차에서 배출되는 대기오염물질 저감을 위하여 저감장치 부착 및 노후차량
# 조기폐차 사업을 통한 대기질 개선
# v 대기환경을 개선하기 위한 저공해화 사업으로 천연가스자동차 및 저공해경유자동차를
# 보급하여 자동차 배출가스 개선
# 3) 지표설정
# ■ 온실가스 감축목표 설정
# v 오산시 온실가스 인벤토리(2017년 기준, 한국환경공단)을 적용하여 단계별 인구
# 계획에 적용하여 산정
# v 2030 국가온실가스 감축목표 37%를 고려하여 온실가스 저감목표를 30%로 설정
# 하고, 오산시 국가1인당 온실가스 총 배출량을 5.7톤CO2eq/명으로 설정
# 280
# 제3장 부문별 계획
# Ⅳ. 환경의 보전과 관리계획
# ■ 오산시 온실가스 배출량 전망
# 구 분 2017년 배출량 2035년 배출예상량 2035년 저감목표 비 고
# 총 배출량(A) (' metadata={'page_label': '293', 'creationdate': '2020-11-19T22:05:21-09:00', 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'creator': 'pdftk 2.02 - www.pdftk.com', 'page': 292, 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)'}
# ------
# page_content='276
# 제3장 부문별 계획
# Ⅳ. 환경의 보전과 관리계획
# 5) 정부의 저탄소 녹색성장 정책방향
# v 2009년 온실가스 감축을 위한 국가 중기 온실가스 감축목표를 대내외에 발표
# v 2010년 「저탄소 녹색성장 기본법」을 시행하고 환경부에 온실가스종합정보센터를
# 설치하여 국가 온실가스 통계 개발 및 검증 등을 위한 관리체계를 구축
# v 2014년 국가 온실가스 감축목표 달성을 위한 로드맵 수립
# v 2015년 배출권거래제 시행, 각국이 결정한 기여(INDC) 제출
# - 2030년 예상배출량 대비 37% 감축
# 나. 온실가스 배출현황
# v 우리나라의 2015년 온실가스 총 배출량은 690.2 백만톤CO 2eq이며, 1990년도 총
# 배출량 292.9 백만톤CO2eq에 비해 135.7% 증가하였고 2014년도 총 배출량인 689.2
# 백만톤CO2eq보다 0.2% 증가
# 1) 분야별 온실가스 배출량
# (단위 : 백만톤 CO 2eq.)
# 구분
# 온실가스 배출량 1990년 대비
# 2015년
# 증감률
# 2014년 대비
# 2015년
# 증감률1990 2000 2010 2013 2014 2015
# 에너지 241.4 410.6 564.9 605.1 597.7 601.0 149.0% 0.6%
# 산업공정 19.8 49.9 54.0 52.8 55.2 52.2 164.0% -5.5%
# 농업 21.3 21.6 22.2 21.4 20.8 20.6 -3.2% -1.2%
# LULUCF -34.2 -58.8 -54.4 -42.7 -42.4 -44.4 29.9% 4.6%
# 폐기물 10.4 18.8 15.1 15.9 15.4 16.4 56.7% 6.4%
# 총배출량
# (LULUCF 제외) 292.9 500.9 656.2 695.2 689.2 690.2 135.7% 0.2%
# 순배출량
# (LULUCF 포함) 258.7 442.0 601.8 652.5 646.7 645.8 149.6% -0.1%
# < 분야별 온실가스 배출량 및 흡수량 >
# v 분야별로는 에너지, 폐기물 분야 배출량이 전년대비 각각 0.6%, 6.4% 증가하였으며,' metadata={'page_label': '290', 'moddate': '2020-12-22T16:22:25+09:00', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'creator': 'pdftk 2.02 - www.pdftk.com', 'page': 289, 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'creationdate': '2020-11-19T22:05:21-09:00'}
# ------
# page_content='275
# 2) 투입위주 및 자원소비형 경제구조의 지속
# v 에너지와 자원이용 생산성이 향상되었음에도 불구하고, 에너지 및 자원사용량은
# 지속적으로 증가
# v 재활용(에너지화 포함) 가능자원의 상당 부분이 폐기물로 단순매립처분되고 있어
# 자원의 낭비 및 환경오염 초래
# 3) 지속가능한 생산 및 소비체계 구축의 한계
# v 낮은 요율의 환경관련 부담금, 농업･저소득층 대상 에너지보조금 등으로 환경개선에
# 대한 경제적 유인책 부족
# v 친환경 경영 및 소비 촉진을 위한 시책이 시행 중이나, 실제 기업경영 및 생활양식
# 변화 미흡
# 4) 국제사회의 기후변화 대응
# v 1992년 유엔기후변화협약 채택(1994년 발효)
# - 개별 국가의 능력을 고려하여 선진국과 개발도상국에 다른 종류의 기후변화 대응
# 의무를 부과(우리나라 가입 : 1993. 12)
# v 1997년 (COP3) 교토의정서 채택(2005년 발효)
# - 온실가스기후변화협약을 구체적으로 이행하기 위하여 제 3차 당사국총회가 채택한
# 교토의정서는 제1차 공약기간인 2008년에서 2012년까지 선진국의 온실가스 배출량을
# 1990년도 수준에 비하여 평균 5.2% 감축하도록 규정
# v 2007년 (COP13) 발리행동계획 채택
# - 개발도상국으로 확대 적용, 탄소제 부과, 탄소배출권 거래시 2%씩 기금 마련
# - 2013년부터 온실가스의무 감축국 편입 압력
# v 2011년 더반플렛폼(COP17)
# - 교토의정서 2차 공약기간 설정(2013년 ~ 2020년)
# - 2020년 이후 모든 당사국에 적용 가능한 단일의 의정서 또는 법적 문건 채택을 위한
# 협상 개시(신기후체제)
# v 2015년 (COP21) 신 기후체제의 기반이 되는 파리협정 채택
# 276
# 제3장 부문별 계획
# Ⅳ. 환경의 보전과 관리계획
# 5) 정부의 저탄소 녹색성장 정책방향
# v 2009년 온실가스 감축을 위한 국가 중기 온실가스 감축목표를 대내외에 발표
# v 2' metadata={'creator': 'pdftk 2.02 - www.pdftk.com', 'page_label': '289', 'producer': 'itext-paulo-155 (itextpdf.sf.net-lowagie.com)', 'page': 288, 'moddate': '2020-12-22T16:22:25+09:00', 'source': 'C:/Users/a/LLM/ch09/data/osan_city_plan.pdf', 'total_pages': 466, 'creationdate': '2020-11-19T22:05:21-09:00'}
# ------

# %%
chat_history.add_user_message(query_for_nyc) # query_for_nyc에 "도쿄는??" 추가

answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer) 

print(answer)
# Out:
# content='도쿄는 기후 변화 대응과 온실가스 감축을 위한 다양한 정책과 프로그램을 시행하고 있습니다. 그 주요 내용은 다음과 같습니다:\n\n1. **저탄소 도시 계획**: 도쿄시는 "저탄소 도시 전략"을 수립하여 온실가스 배출을 2020년까지 25% 감축하고, 2030년까지 30% 감축을 목표로 하고 있습니다.\n\n2. **재생 가능 에너지 확대**: 도쿄시는 재생 가능 에너지의 사용을 늘리고, 태양광 발전 및 풍력 발전을 바탕으로 에너지 자립을 지향하고 있습니다. 건물에 대한 태양광 설치 지원 프로그램도 운영하고 있습니다.\n\n3. **친환경 교통 정책**: 대중교통 이용을 장려하며, 도로 및 자전거 인프라를 개선하여 자동차 사용을 줄이고 있습니다. 전기 자동차 및 저공해 자동차의 보급도 지원하고 있습니다.\n\n4. **청정 에너지 이용 촉진**: 건물 에너지 효율을 높이기 위한 지속적인 개선과 청정 에너지 이용을 위한 다양한 인센티브를 제공하고 있습니다. \n\n5. **시민 참여와 교육**: 시민과 기업의 참여를 유도하기 위한 환경 교육 및 캠페인을 운영하고, 시민들이 온실가스 감축을 위해 적극적으로 참여할 수 있는 기회를 제공합니다.\n\n이러한 정책들을 통해 도쿄시는 기후 변화에 대응하고 지속 가능한 도시 발전을 추구하고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 332, 'prompt_tokens': 3511, 'total_tokens': 3843, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_57133166c6', 'id': 'chatcmpl-DbzIcYwpen6A3uqe0IKgXsL4G21Vv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019df5d9-276b-7b21-97ae-09c3dd4d6d07-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 3511, 'output_tokens': 332, 'total_tokens': 3843, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
